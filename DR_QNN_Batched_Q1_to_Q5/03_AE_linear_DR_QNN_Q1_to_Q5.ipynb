# %% [markdown]
# # **1**

# %%
import os
import json
import random
from datetime import datetime

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ## 1.1 — Carpetas base

# %%
BASE_DATA_DIR = r"C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold"

BASE_RESULTS_DIR = r"C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched"

os.makedirs(BASE_RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.2 — Selección del experimento

# %% [markdown]
# Métodos disponibles:
# - "PCA"
# - "ICA"
# - "AE_linear"
# - "AE_nonlinear"

# %%
METHOD = "AE_linear"
FOLD = 0
K = 3

METHOD_FILES = {
    "PCA": "PCA_z1_to_z15_stratified5.npz",
    "ICA": "ICA_z1_to_z15_stratified5.npz",
    "AE_linear": "AE_linear_z1_to_z15_stratified5.npz",
    "AE_nonlinear": "AE_nonlinear_z1_to_z15_stratified5.npz",
}

assert METHOD in METHOD_FILES, (f"METHOD inválido: {METHOD}. " f"Usa {list(METHOD_FILES.keys())}")
assert FOLD in [0, 1, 2, 3, 4], ("FOLD debe ser 0, 1, 2, 3 o 4")
assert K in [1, 2, 3], ("Para esta DR-QNN, K debe ser 1, 2 o 3")

DATA_PATH = os.path.join(BASE_DATA_DIR, METHOD_FILES[METHOD])

assert os.path.exists(DATA_PATH), (f"No existe el archivo: {DATA_PATH}")

# %% [markdown]
# ## 1.3 — Nombre del experimento

# %%
EXPERIMENT_NAME = (f"DR_QNN_BATCHED_{METHOD}_z{K}_fold{FOLD}")
RESULTS_DIR = os.path.join(BASE_RESULTS_DIR, EXPERIMENT_NAME)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.4 — Configuración del dataset

# %%
USE_SUBSET = False
N_TRAIN_QML = 200
N_TEST_QML = 120
SUBSET_RANDOM_STATE = 123

# %% [markdown]
# ## 1.5 — Configuración DR-QNN

# %%
N_LAYERS = 6
QUBITS_LIST = [1, 2, 3, 4, 5]
assert QUBITS_LIST == [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1.6 — Configuración de rapidez tipo MS-HQCNN

# %%
USE_VECTORIZED_QNODE = True

# Mini-batches de entrenamiento.
BATCH_SIZE = 32

# Tamaño de bloque utilizado únicamente para evaluación/inferencia.
CHUNK_SAMPLES = 131072

assert BATCH_SIZE > 0
assert CHUNK_SAMPLES > 0

# %% [markdown]
# ## 1.7 — Entrenamiento

# %%
EPOCHS_1Q = 60
EPOCHS_NQ = 50

# Learning rate de la DR-QNN de un qubit.
LR_1Q = 0.006

# Al expandir el modelo, se utiliza una tasa menor para no destruir
# los parámetros heredados del modelo anterior.
LR_NQ = 0.003

# %% [markdown]
# ## 1.8 — Backend cuántico

# %%
QML_DEVICE_NAME = "default.qubit"
SHOTS = None
assert QML_DEVICE_NAME in ["default.qubit"]

# %% [markdown]
# ## 1.9 — Reproducibilidad

# %%
GLOBAL_SEED = 42

def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_global_seed(GLOBAL_SEED)

# %% [markdown]
# ## 1.10 — Dispositivo PyTorch

# %%
TORCH_DEVICE = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(TORCH_DEVICE)
# Out:
# cuda

# %% [markdown]
# ## 1.11 — Rutas de guardado

# %%
CONFIG_PATH = os.path.join(RESULTS_DIR, "config.json")
LOAD_SUMMARY_PATH = os.path.join(RESULTS_DIR, "load_summary.json")
METRICS_PATH = os.path.join(RESULTS_DIR, "metrics_summary.csv")
PREDICTIONS_PATH = os.path.join(RESULTS_DIR, "predictions.csv")
CHECKPOINT_1Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_1q.pt")
CHECKPOINT_2Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_2q.pt")
CHECKPOINT_3Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_3q.pt")
CHECKPOINT_4Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_4q.pt")
CHECKPOINT_5Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_5q.pt")

# %% [markdown]
# ## 1.12 — Guardar configuración

# %%
CONFIG = {"experiment_name": EXPERIMENT_NAME, "method": METHOD, "fold": FOLD, "k": K, "data_path": DATA_PATH, "results_dir": RESULTS_DIR, "use_subset": USE_SUBSET, "n_train_qml": N_TRAIN_QML, "n_test_qml": N_TEST_QML, "subset_random_state": SUBSET_RANDOM_STATE, "n_layers": N_LAYERS, "qubits_list": QUBITS_LIST, "use_vectorized_qnode": USE_VECTORIZED_QNODE, "batch_size": BATCH_SIZE, "chunk_samples": CHUNK_SAMPLES, "epochs_1q": EPOCHS_1Q, "epochs_nq": EPOCHS_NQ, "lr_1q": LR_1Q, "lr_nq": LR_NQ, "qml_device_name": QML_DEVICE_NAME, "shots": SHOTS, "global_seed": GLOBAL_SEED, "torch_device": TORCH_DEVICE, "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),}

with open(CONFIG_PATH, "w", encoding="utf-8") as f:
    json.dump(CONFIG, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## 1.13 — Resumen

# %%
print("=" * 80)
print("CONFIGURACIÓN DEL EXPERIMENTO")
print("=" * 80)
print("METHOD:", METHOD)
print("FOLD:", FOLD)
print("K:", K)
print("\nDATA_PATH:")
print(DATA_PATH)
print("\nRESULTS_DIR:")
print(RESULTS_DIR)
print("\nQUBITS_LIST:", QUBITS_LIST)
print("N_LAYERS:", N_LAYERS)
print("USE_VECTORIZED_QNODE:", USE_VECTORIZED_QNODE)
print("CHUNK_SAMPLES:", CHUNK_SAMPLES)
print("BATCH_SIZE:", BATCH_SIZE)
print("QML_DEVICE_NAME:", QML_DEVICE_NAME)
print("TORCH_DEVICE:", TORCH_DEVICE)
print("\nCONFIG_PATH:")
print(CONFIG_PATH)
# Out:
# ================================================================================
# CONFIGURACIÓN DEL EXPERIMENTO
# ================================================================================
# METHOD: AE_linear
# FOLD: 0
# K: 3
#
# DATA_PATH:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\AE_linear_z1_to_z15_stratified5.npz
#
# RESULTS_DIR:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0
#
# QUBITS_LIST: [1, 2, 3, 4, 5]
# N_LAYERS: 6
# USE_VECTORIZED_QNODE: True
# CHUNK_SAMPLES: 131072
# BATCH_SIZE: 32
# QML_DEVICE_NAME: default.qubit
# TORCH_DEVICE: cuda
#
# CONFIG_PATH:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\config.json

# %% [markdown]
# # **2**

# %% [markdown]
# ## 2.1 — Cargar archivo .npz

# %%
print("=" * 80)
print("CARGANDO DATASET")
print("=" * 80)

data = np.load(DATA_PATH, allow_pickle=True)

print("Archivo:")
print(DATA_PATH)

print("\nTotal de keys:", len(data.files))

print("\nPrimeras 20 keys:")
for key in data.files[:20]:
    print(key)
# Out:
# ================================================================================
# CARGANDO DATASET
# ================================================================================
# Archivo:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\AE_linear_z1_to_z15_stratified5.npz
#
# Total de keys: 341
#
# Primeras 20 keys:
# metadata
# fold0_train_idx
# fold0_test_idx
# fold0_y_train
# fold0_y_test
# fold0_z64_train
# fold0_z64_test
# fold0_scaler_mean
# fold0_scaler_scale
# fold0_z1_train
# fold0_z1_test
# fold0_z1_loss_history
# fold0_z1_best_reconstruction_loss
# fold0_z2_train
# fold0_z2_test
# fold0_z2_loss_history
# fold0_z2_best_reconstruction_loss
# fold0_z3_train
# fold0_z3_test
# fold0_z3_loss_history

# %% [markdown]
# ## 2.2 — Leer metadata

# %%
if "metadata" in data.files:
    metadata = json.loads(str(data["metadata"].item()))
    print("\nMetadata:")
    for key, value in metadata.items():
        print(f"{key:30s}: {value}")

else:
    metadata = {}
    print("\nNo se encontró key 'metadata'.")
# Out:
# Metadata:
# method                        : AE_linear
# source_file                   : /content/drive/MyDrive/BCAM/distr_sol_pv_segm_embeddings_v2.npz
# x_key                         : features
# y_key                         : label
# original_dim                  : 64
# n_samples                     : 20976
# max_components                : 15
# n_splits                      : 5
# stratified                    : True
# random_state                  : 42
# created_time                  : 2026-06-22 11:15:03
# note                          : Transforms are fitted only on train data inside each fold. Test data is never used to fit scaler/PCA/ICA/AE.

# %% [markdown]
# ## 2.3 — Cargar fold y dimensión K con keys fijas

# %%
X_train = data[f"fold{FOLD}_z{K}_train"].astype(np.float32)
X_test = data[f"fold{FOLD}_z{K}_test"].astype(np.float32)
y_train = data[f"fold{FOLD}_y_train"].astype(int)
y_test = data[f"fold{FOLD}_y_test"].astype(int)

train_idx = data[f"fold{FOLD}_train_idx"]
test_idx = data[f"fold{FOLD}_test_idx"]

print("\nFold seleccionado:", FOLD)
print("Dimensión seleccionada K:", K)

print("\nShapes originales")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
print("train_idx:", train_idx.shape)
print("test_idx :", test_idx.shape)
# Out:
# Fold seleccionado: 0
# Dimensión seleccionada K: 3
#
# Shapes originales
# X_train: (16780, 3)
# X_test : (4196, 3)
# y_train: (16780,)
# y_test : (4196,)
# train_idx: (16780,)
# test_idx : (4196,)

# %% [markdown]
# ## 2.4 — Distribución de clases

# %%
print("\nDistribución TRAIN")
classes_train, counts_train = np.unique(y_train, return_counts=True)
for c, n in zip(classes_train, counts_train):
    print(f"Clase {c}: {n}")

print("\nDistribución TEST")
classes_test, counts_test = np.unique(y_test, return_counts=True)
for c, n in zip(classes_test, counts_test):
    print(f"Clase {c}: {n}")
# Out:
# Distribución TRAIN
# Clase 0: 8234
# Clase 1: 8546
#
# Distribución TEST
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 2.5 — Validaciones de consistencia

# %%
assert len(X_train) == len(y_train), ("X_train e y_train no tienen la misma longitud")
assert len(X_test) == len(y_test), ("X_test e y_test no tienen la misma longitud")
assert X_train.ndim == 2, ("X_train debe ser matriz 2D")
assert X_test.ndim == 2, ("X_test debe ser matriz 2D")
assert X_train.shape[1] == K, (f"X_train debería tener {K} columnas")
assert X_test.shape[1] == K, (f"X_test debería tener {K} columnas")
assert set(np.unique(y_train)).issubset({0, 1}), ("y_train debe contener clases 0/1")
assert set(np.unique(y_test)).issubset({0, 1}), ("y_test debe contener clases 0/1")
assert len(train_idx) == len(y_train), ("train_idx e y_train no tienen la misma longitud")
assert len(test_idx) == len(y_test), ("test_idx e y_test no tienen la misma longitud")

print("\nConsistencia OK")
# Out:
# Consistencia OK

# %% [markdown]
# ## 2.6 — Rangos de features originales

# %%
print("\nRangos TRAIN")
for i in range(K):
    col = X_train[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST")
for i in range(K):
    col = X_test[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN
# Feature 0: min=-11.759556 | max=3.574133 | mean=0.045817 | std=1.868861
# Feature 1: min=-3.010531 | max=11.827461 | mean=0.102825 | std=2.096530
# Feature 2: min=-18.855625 | max=4.173334 | mean=0.184152 | std=1.682869
#
# Rangos TEST
# Feature 0: min=-9.073557 | max=3.002192 | mean=0.040510 | std=1.862581
# Feature 1: min=-2.607057 | max=12.159291 | mean=0.046207 | std=2.037531
# Feature 2: min=-10.664355 | max=4.312962 | mean=0.195311 | std=1.612443

# %% [markdown]
# ## 2.7 — Guardar resumen inicial de carga

# %%
initial_load_summary = {"method": METHOD, "fold": int(FOLD), "k": int(K), "data_path": DATA_PATH, "keys_count": len(data.files), "metadata": metadata, "x_train_shape": list(X_train.shape), "x_test_shape": list(X_test.shape), "y_train_shape": list(y_train.shape), "y_test_shape": list(y_test.shape), "train_idx_shape": list(train_idx.shape), "test_idx_shape": list(test_idx.shape), "train_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_train, counts_train)},
    "test_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_test, counts_test)},}

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen inicial de carga guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen inicial de carga guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\load_summary.json

# %% [markdown]
# # **3**

# %% [markdown]
# ## 3.1 — Adaptación a qml.Rot(phi, theta, omega)

# %% [markdown]
# qml.Rot(phi, theta, omega) requiere 3 entradas:
# - K = 3: se deja igual
# - K = 2: agrega una columna de ceros
# - K = 1: agrega dos columnas de cerosm

# %%
def adapt_to_rot_dimension(X):

    X = np.asarray(X ,dtype=np.float32)
    if X.ndim != 2:
        raise ValueError(f"X debe ser matriz 2D, llegó {X.shape}")
    if X.shape[1] == 3:
        return X.astype(np.float32)
    if X.shape[1] == 2:
        zeros = np.zeros((len(X), 1), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    if X.shape[1] == 1:
        zeros = np.zeros((len(X), 2), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    raise ValueError(f"Dimensión no soportada: {X.shape[1]}")

# %% [markdown]
# ## 3.2 — Adaptar TRAIN y TEST

# %%
# ============================================================
# Adaptación a tres ángulos + escalado angular
# ============================================================

X_train_rot_raw = adapt_to_rot_dimension(X_train)
X_test_rot_raw = adapt_to_rot_dimension(X_test)

# El escalador se ajusta exclusivamente con TRAIN.
# TEST solamente se transforma con los parámetros aprendidos en TRAIN.
ANGLE_MIN = -np.pi / 2
ANGLE_MAX = np.pi / 2

angle_scaler = MinMaxScaler(
    feature_range=(ANGLE_MIN, ANGLE_MAX)
)

X_train_rot = angle_scaler.fit_transform(
    X_train_rot_raw
).astype(np.float32)

X_test_rot = angle_scaler.transform(
    X_test_rot_raw
).astype(np.float32)

# Protección ante valores de TEST fuera del rango observado en TRAIN.
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

print("\nShapes adaptadas para qml.Rot")
print("X_train_rot:", X_train_rot.shape)
print("X_test_rot :", X_test_rot.shape)

print("\nIntervalo angular aplicado:")
print(f"[{ANGLE_MIN:.6f}, {ANGLE_MAX:.6f}]")

print("\nRangos finales TRAIN")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos finales TEST")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Shapes adaptadas para qml.Rot
# X_train_rot: (16780, 3)
# X_test_rot : (4196, 3)
#
# Intervalo angular aplicado:
# [-1.570796, 1.570796]
#
# Rangos finales TRAIN
#    phi: min=-1.570796 | max=1.570796 | mean=0.847909 | std=0.382895
#  theta: min=-1.570796 | max=1.570796 | mean=-0.911617 | std=0.443891
#  omega: min=-1.570796 | max=1.570796 | mean=1.026595 | std=0.229576
#
# Rangos finales TEST
#    phi: min=-1.020484 | max=1.453616 | mean=0.846822 | std=0.381609
#  theta: min=-1.485370 | max=1.570796 | mean=-0.923621 | std=0.431301
#  omega: min=-0.453350 | max=1.570796 | mean=1.028113 | std=0.219957

# %% [markdown]
# ## 3.3 — Validaciones

# %%
assert X_train_rot.ndim == 2
assert X_test_rot.ndim == 2

assert X_train_rot.shape[1] == 3
assert X_test_rot.shape[1] == 3

print("\nAdaptación K → 3 correcta")
# Out:
# Adaptación K → 3 correcta

# %% [markdown]
# ## 3.4 — Verificar padding

# %%
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

# Restaurar explícitamente el padding usado por qml.Rot.
if K == 1:
    X_train_rot[:, 1:] = 0.0
    X_test_rot[:, 1:] = 0.0

elif K == 2:
    X_train_rot[:, 2] = 0.0
    X_test_rot[:, 2] = 0.0

# %% [markdown]
# ## 3.5 — Vista rápida

# %%
preview_df = pd.DataFrame(X_train_rot[:10], columns=["phi", "theta", "omega"])
preview_df["label"] = y_train[:10]
display(preview_df)
# Out:
#         phi     theta     omega  label
# 0  1.091231 -1.293240  1.193960      0
# 1  0.269164 -0.331375  1.177361      1
# 2  0.919441 -0.761555  1.147291      1
# 3  0.374274 -0.371751  1.044293      1
# 4  1.067100 -1.156524  1.080452      1
# 5  0.933782 -1.356676  1.121460      0
# 6  0.748766 -0.767293  0.450923      0
# 7  0.996812 -0.873962  1.119861      1
# 8  1.174165 -1.261851  1.223681      0
# 9  1.009250 -1.059143  0.932925      0

# %% [markdown]
# ## 3.6 — Estadísticas después de la adaptación

# %%
print("\nRangos TRAIN adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN adaptado
#    phi: min=-1.570796 | max=1.570796 | mean=0.847909 | std=0.382895
#  theta: min=-1.570796 | max=1.570796 | mean=-0.911617 | std=0.443891
#  omega: min=-1.570796 | max=1.570796 | mean=1.026595 | std=0.229576
#
# Rangos TEST adaptado
#    phi: min=-1.020484 | max=1.453616 | mean=0.846822 | std=0.381609
#  theta: min=-1.485370 | max=1.570796 | mean=-0.923621 | std=0.431301
#  omega: min=-0.453350 | max=1.570796 | mean=1.028113 | std=0.219957

# %% [markdown]
# ## 3.7 — Resumen

# %%
print("\nResumen adaptación")
print("K original:" ,K)
print("Dimensión final para DR-QNN:", X_train_rot.shape[1])
print("TRAIN:", X_train_rot.shape)
print("TEST :", X_test_rot.shape)
# Out:
# Resumen adaptación
# K original: 3
# Dimensión final para DR-QNN: 3
# TRAIN: (16780, 3)
# TEST : (4196, 3)

# %% [markdown]
# # **4**

# %% [markdown]
# ## 4.1 — Construir dataset que verá la DR-QNN

# %%
if USE_SUBSET:
    train_positions = np.arange(len(X_train_rot))
    test_positions = np.arange(len(X_test_rot))

    train_subset, _ = train_test_split(train_positions, train_size=N_TRAIN_QML, stratify=y_train, random_state=SUBSET_RANDOM_STATE)
    test_subset, _ = train_test_split(test_positions, train_size=N_TEST_QML, stratify=y_test, random_state=SUBSET_RANDOM_STATE)

    X_train_qml = X_train_rot[train_subset].copy()
    y_train_qml = y_train[train_subset].copy()

    X_test_qml = X_test_rot[test_subset].copy()
    y_test_qml = y_test[test_subset].copy()

    original_train_idx_qml = train_idx[train_subset].copy()
    original_test_idx_qml = test_idx[test_subset].copy()

else:
    X_train_qml = X_train_rot.copy()
    y_train_qml = y_train.copy()

    X_test_qml = X_test_rot.copy()
    y_test_qml = y_test.copy()

    original_train_idx_qml = train_idx.copy()
    original_test_idx_qml = test_idx.copy()

# %% [markdown]
# ## 4.2 — Validaciones del dataset QML

# %%
assert X_train_qml.ndim == 2
assert X_test_qml.ndim == 2

assert X_train_qml.shape[1] == 3
assert X_test_qml.shape[1] == 3

assert len(X_train_qml) == len(y_train_qml)
assert len(X_test_qml) == len(y_test_qml)

assert len(original_train_idx_qml) == len(y_train_qml)
assert len(original_test_idx_qml) == len(y_test_qml)

assert set(np.unique(y_train_qml)).issubset(
    {0, 1}
)

assert set(np.unique(y_test_qml)).issubset(
    {0, 1}
)

# %% [markdown]
# ## 4.3 — Resumen del dataset final

# %%
print("\nDataset que verá la DR-QNN")
print("X_train_qml:", X_train_qml.shape)
print("X_test_qml :", X_test_qml.shape)
print("\ny_train_qml:", y_train_qml.shape)
print("y_test_qml :", y_test_qml.shape)
print("\nÍndices originales:")
print("original_train_idx_qml:", original_train_idx_qml.shape)
print("original_test_idx_qml :", original_test_idx_qml.shape)

print("\nClases TRAIN QML:")
classes_train_qml, counts_train_qml = np.unique(y_train_qml, return_counts=True)
for c, n in zip(classes_train_qml, counts_train_qml):
    print(f"Clase {c}: {n}")

print("\nClases TEST QML:")
classes_test_qml, counts_test_qml = np.unique(y_test_qml, return_counts=True)
for c, n in zip(classes_test_qml, counts_test_qml):
    print(f"Clase {c}: {n}")
# Out:
# Dataset que verá la DR-QNN
# X_train_qml: (16780, 3)
# X_test_qml : (4196, 3)
#
# y_train_qml: (16780,)
# y_test_qml : (4196,)
#
# Índices originales:
# original_train_idx_qml: (16780,)
# original_test_idx_qml : (4196,)
#
# Clases TRAIN QML:
# Clase 0: 8234
# Clase 1: 8546
#
# Clases TEST QML:
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 4.4 — Definir tamaño de batch/chunk para entrenamiento

# %%
if BATCH_SIZE is None:
    TRAIN_BATCH_SIZE = len(X_train_qml)
    FULL_BATCH_TRAINING = True

else:
    TRAIN_BATCH_SIZE = BATCH_SIZE
    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE = CHUNK_SAMPLES

assert TRAIN_BATCH_SIZE > 0
assert EVAL_CHUNK_SIZE > 0

print("\nConfiguración de batches")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE:", TRAIN_BATCH_SIZE)
print("EVAL_CHUNK_SIZE :", EVAL_CHUNK_SIZE)
# Out:
# Configuración de batches
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE: 32
# EVAL_CHUNK_SIZE : 131072

# %% [markdown]
# ## 4.5 — Función para generar batches de índices

# %%
def make_batch_indices(n_samples, batch_size, shuffle=True, seed=None):

    indices = np.arange(n_samples)

    if shuffle:
        rng = np.random.default_rng(seed)
        rng.shuffle(indices)
    batches = []

    for start in range(0,n_samples,batch_size):
        end = min(start + batch_size,n_samples)
        batches.append(indices[start:end])

    return batches

# %% [markdown]
# ## 4.6 — Sanity check de batches de entrenamiento

# %%
train_batches_preview = make_batch_indices(n_samples=len(X_train_qml) ,batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED)

print("\nNúmero de batches TRAIN por época:")
print(len(train_batches_preview))

print("\nPrimeros tamaños de batch:")

for b in train_batches_preview[:5]:
    print(len(b))

assert sum(len(b) for b in train_batches_preview) == len(X_train_qml)
# Out:
# Número de batches TRAIN por época:
# 525
#
# Primeros tamaños de batch:
# 32
# 32
# 32
# 32
# 32

# %% [markdown]
# ## 4.7 — Función para iterar arrays NumPy por batches

# %%
def iter_numpy_batches(X, y=None, batch_size=1024, shuffle=False, seed=None):
    batches = make_batch_indices(n_samples=len(X), batch_size=batch_size, shuffle=shuffle, seed=seed)
    for batch_idx in batches:
        if y is None:
            yield X[batch_idx]
        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 4.8 — Sanity check de iterador NumPy

# %%
first_batch = next(iter_numpy_batches(X_train_qml, y_train_qml, batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED))
first_X_batch, first_y_batch = first_batch

print("\nPrimer batch NumPy")
print("X:", first_X_batch.shape)
print("y:", first_y_batch.shape)

assert first_X_batch.ndim == 2
assert first_X_batch.shape[1] == 3
assert len(first_X_batch) == len(first_y_batch)
# Out:
# Primer batch NumPy
# X: (32, 3)
# y: (32,)

# %% [markdown]
# ## 4.9 — Guardar resumen actualizado

# %%
initial_load_summary.update({
        "x_train_qml_shape": list(X_train_qml.shape),
        "x_test_qml_shape": list(X_test_qml.shape),
        "y_train_qml_shape": list(y_train_qml.shape),
        "y_test_qml_shape": list(y_test_qml.shape),
        "original_train_idx_qml_shape": list(original_train_idx_qml.shape),
        "original_test_idx_qml_shape": list(original_test_idx_qml.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size": int(TRAIN_BATCH_SIZE),
        "eval_chunk_size": int(EVAL_CHUNK_SIZE),
        "train_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_train_qml,counts_train_qml)},
        "test_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_test_qml,counts_test_qml)},
    })

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\load_summary.json

# %% [markdown]
# # **5**

# %% [markdown]
# ## 5.1 — Dispositivo y tensorización

# %%
DEVICE = torch.device(TORCH_DEVICE)

X_train_t = torch.tensor(X_train_qml, dtype=torch.float32, device=DEVICE)
X_test_t = torch.tensor(X_test_qml, dtype=torch.float32, device=DEVICE)

y_train_t = torch.tensor(y_train_qml, dtype=torch.long, device=DEVICE)
y_test_t = torch.tensor(y_test_qml, dtype=torch.long, device=DEVICE)

y_train_float_t = y_train_t.float()
y_test_float_t = y_test_t.float()

print("DEVICE:", DEVICE)

print("\nTensores en memoria:")
print("X_train_t:", X_train_t.shape, X_train_t.dtype, X_train_t.device)
print("X_test_t :", X_test_t.shape, X_test_t.dtype, X_test_t.device)
print("y_train_t:", y_train_t.shape, y_train_t.dtype, y_train_t.device)
print("y_test_t :", y_test_t.shape, y_test_t.dtype, y_test_t.device)
# Out:
# DEVICE: cuda
#
# Tensores en memoria:
# X_train_t: torch.Size([16780, 3]) torch.float32 cuda:0
# X_test_t : torch.Size([4196, 3]) torch.float32 cuda:0
# y_train_t: torch.Size([16780]) torch.int64 cuda:0
# y_test_t : torch.Size([4196]) torch.int64 cuda:0

# %% [markdown]
# ## 5.2 — Validaciones para QNode batched

# %%
assert X_train_t.ndim == 2
assert X_test_t.ndim == 2

assert X_train_t.shape[1] == 3
assert X_test_t.shape[1] == 3

assert len(X_train_t) == len(y_train_t)
assert len(X_test_t) == len(y_test_t)

assert set(
    y_train_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

assert set(
    y_test_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

print("\nValidaciones tensoriales OK")
print("Entrada esperada por QNode batched: (B, 3)")
# Out:
# Validaciones tensoriales OK
# Entrada esperada por QNode batched: (B, 3)

# %% [markdown]
# ## 5.3 — Función de batches tensoriales

# %%
def make_tensor_batches(X, y=None, batch_size=None, shuffle=True, seed=None):
    n_samples = X.shape[0]
    
    if batch_size is None:
        batch_size = n_samples
    indices = torch.arange(n_samples, device=X.device)

    if shuffle:
        generator = torch.Generator(device=X.device)

        if seed is not None:
            generator.manual_seed(int(seed))

        indices = indices[torch.randperm(n_samples, generator=generator, device=X.device)]

    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        batch_idx = indices[start:end]

        if y is None:
            yield X[batch_idx]

        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 5.4 — Batch size efectivo para entrenamiento

# %%
if BATCH_SIZE is None:

    TRAIN_BATCH_SIZE_TORCH = len(X_train_t)

    FULL_BATCH_TRAINING = True

else:

    TRAIN_BATCH_SIZE_TORCH = int(BATCH_SIZE)

    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE_TORCH = int(
    CHUNK_SAMPLES
)

assert TRAIN_BATCH_SIZE_TORCH > 0
assert EVAL_CHUNK_SIZE_TORCH > 0

print("\nConfiguración batched final:")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)
print("EVAL_CHUNK_SIZE_TORCH :", EVAL_CHUNK_SIZE_TORCH)
# Out:
# Configuración batched final:
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE_TORCH: 32
# EVAL_CHUNK_SIZE_TORCH : 131072

# %% [markdown]
# ## 5.5 — Sanity check del batch de entrenamiento

# %%
first_X_t, first_y_t = next(make_tensor_batches(X_train_t, y_train_float_t, batch_size=TRAIN_BATCH_SIZE_TORCH, shuffle=True, seed=GLOBAL_SEED))

print("\nPrimer batch Torch:")
print("X:", first_X_t.shape, first_X_t.dtype, first_X_t.device)
print("y:", first_y_t.shape, first_y_t.dtype, first_y_t.device)

assert first_X_t.ndim == 2
assert first_X_t.shape[1] == 3
assert len(first_X_t) == len(first_y_t)
# Out:
# Primer batch Torch:
# X: torch.Size([32, 3]) torch.float32 cuda:0
# y: torch.Size([32]) torch.float32 cuda:0

# %% [markdown]
# ## 5.6 — Sanity check de chunks de evaluación

# %%
first_eval_chunk = next(make_tensor_batches(X_test_t, y_test_float_t, batch_size=EVAL_CHUNK_SIZE_TORCH, shuffle=False, seed=None))
first_X_eval_t, first_y_eval_t = first_eval_chunk

print("\nPrimer chunk de evaluación:")
print("X:", first_X_eval_t.shape, first_X_eval_t.dtype, first_X_eval_t.device)
print("y:", first_y_eval_t.shape, first_y_eval_t.dtype, first_y_eval_t.device)

assert first_X_eval_t.ndim == 2
assert first_X_eval_t.shape[1] == 3
# Out:
# Primer chunk de evaluación:
# X: torch.Size([4196, 3]) torch.float32 cuda:0
# y: torch.Size([4196]) torch.float32 cuda:0

# %% [markdown]
# ## 5.7 — Resumen actualizado

# %%
initial_load_summary.update(
    {
        "torch_device": str(DEVICE),
        "x_train_t_shape": list(X_train_t.shape),
        "x_test_t_shape": list(X_test_t.shape),
        "y_train_t_shape": list(y_train_t.shape),
        "y_test_t_shape": list(y_test_t.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size_torch": int(TRAIN_BATCH_SIZE_TORCH),
        "eval_chunk_size_torch": int(EVAL_CHUNK_SIZE_TORCH),
        "qnode_expected_input_shape": "(B, 3)",
        "batched_qnode_required": bool(USE_VECTORIZED_QNODE),
    }
)

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nSección 5 lista.")
print("Los datos ya están en tensores y preparados para QNode batched.")
print("Resumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Sección 5 lista.
# Los datos ya están en tensores y preparados para QNode batched.
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\load_summary.json

# %% [markdown]
# # **6**

# %% [markdown]
# ## 6.1 — Crear dispositivos cuánticos

# %%
def make_qml_device(n_qubits):

    if QML_DEVICE_NAME == "default.qubit":
        return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

    return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

qml_devices = {}

for n_qubits in QUBITS_LIST:
    qml_devices[n_qubits] = make_qml_device(n_qubits)
print("Dispositivos creados:")

for n_qubits, dev in qml_devices.items():
    print(f"{n_qubits}Q:", dev)
# Out:
# Dispositivos creados:
# 1Q: <default.qubit device (wires=1) at 0x2618dadd090>
# 2Q: <default.qubit device (wires=2) at 0x2618daa4e50>
# 3Q: <default.qubit device (wires=3) at 0x2618db4b350>
# 4Q: <default.qubit device (wires=4) at 0x2618db93590>
# 5Q: <default.qubit device (wires=5) at 0x2618db93a50>

# %% [markdown]
# ## 6.2 — Bloques cuánticos básicos

# %%
def encode_data_reuploading_layer(X_batch, n_qubits):
    for q in range(n_qubits):
        qml.Rot(X_batch[:, 0], X_batch[:, 1], X_batch[:, 2], wires=q)


def apply_single_qubit_trainable_layer(theta_layer, n_qubits):
    for q in range(n_qubits):
        qml.Rot(theta_layer[q, 0], theta_layer[q, 1], theta_layer[q, 2], wires=q)


def apply_entangling_layer(phi_layer, n_qubits):
    if n_qubits == 1:
        return
    for s in range(n_qubits - 1):
        qml.ctrl(qml.Rot, control=s + 1)(phi_layer[s, 0], phi_layer[s, 1], phi_layer[s, 2], wires=s)

# %% [markdown]
# ## 6.3 — Constructor de QNode batched para n qubits

# %%
def make_batched_drqnn_qnode(n_qubits):
    dev = qml_devices[n_qubits]
    @qml.qnode(dev, interface="torch", diff_method="backprop")
    
    def qnode(X_batch, theta, phi):
        for layer in range(N_LAYERS):
            encode_data_reuploading_layer(X_batch, n_qubits)
            apply_single_qubit_trainable_layer(theta[layer], n_qubits)

            if n_qubits > 1:
                apply_entangling_layer(phi[layer], n_qubits)

        return qml.probs(wires=0)

    return qnode

# %% [markdown]
# ## 6.4 — Crear QNodes Q1 → Q5

# %%
batched_qnodes = {}

for n_qubits in QUBITS_LIST:
    batched_qnodes[n_qubits] = make_batched_drqnn_qnode(n_qubits)

print("\nQNodes batched creados:")

for n_qubits in batched_qnodes:
    print(f"{n_qubits}Q listo")
# Out:
# QNodes batched creados:
# 1Q listo
# 2Q listo
# 3Q listo
# 4Q listo
# 5Q listo

# %% [markdown]
# ## 6.5 — Inicializadores auxiliares de parámetros

# %%
def make_empty_theta(n_qubits, device=DEVICE):
    theta = torch.zeros(N_LAYERS, n_qubits, 3, dtype=torch.float32, device=device)
    return theta

def make_empty_phi(n_qubits, device=DEVICE):

    if n_qubits == 1:
        phi = torch.zeros(N_LAYERS, 1, 3, dtype=torch.float32, device=device)

    else:
        phi = torch.zeros(N_LAYERS, n_qubits - 1, 3, dtype=torch.float32, device=device)

    return phi

# %% [markdown]
# ## 6.6 — Sanity check batched de todos los QNodes

# %%
SANITY_BATCH_SIZE = min(8, len(X_train_t))
X_sanity = X_train_t[:SANITY_BATCH_SIZE]

print("\nSanity batch:")
print("X_sanity:", X_sanity.shape)

qnode_sanity_outputs = {}

with torch.no_grad():
    for n_qubits in QUBITS_LIST:
        theta_sanity = make_empty_theta(n_qubits)
        phi_sanity = make_empty_phi(n_qubits)
        probs = batched_qnodes[n_qubits](X_sanity, theta_sanity, phi_sanity)
        qnode_sanity_outputs[n_qubits] = probs

        print(f"{n_qubits}Q probs:", probs.shape, probs.device, probs.dtype)

        assert probs.ndim == 2
        assert probs.shape[0] == SANITY_BATCH_SIZE
        assert probs.shape[1] == 2

        expected = torch.ones_like(probs.sum(dim=1))

        assert torch.allclose(probs.sum(dim=1), expected, atol=1e-5)

print("\nSanity check Q1-Q5 OK")
# Out:
# Sanity batch:
# X_sanity: torch.Size([8, 3])
# 1Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 2Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 3Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 4Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 5Q probs: torch.Size([8, 2]) cuda:0 torch.float32
#
# Sanity check Q1-Q5 OK

# %% [markdown]
# ## 6.7 — Convención de salida

# %%
print("\nConvención de salida DR-QNN:")
print("probs[:, 0] = fidelidad/probabilidad asociada a clase 0")
print("probs[:, 1] = score de clase 1")
print("pred = 1 si probs[:, 1] >= 0.5")

print("\nSección 6 lista.")
print("Los QNodes ya reciben batches X_batch con shape (B, 3).")
# Out:
# Convención de salida DR-QNN:
# probs[:, 0] = fidelidad/probabilidad asociada a clase 0
# probs[:, 1] = score de clase 1
# pred = 1 si probs[:, 1] >= 0.5
#
# Sección 6 lista.
# Los QNodes ya reciben batches X_batch con shape (B, 3).

# %%
probs.dtype
# Out:
# torch.float32

# %% [markdown]
# # **7**

# %% [markdown]
# ## 7.1 — Clase general DR-QNN batched

# %%
class BatchedDRQNN(nn.Module):

    def __init__(
        self,
        n_qubits,
        init_theta=None,
        init_phi=None
    ):
        super().__init__()

        assert n_qubits in QUBITS_LIST

        self.n_qubits = n_qubits

        theta_shape = (
            N_LAYERS,
            n_qubits,
            3
        )

        phi_shape = (
            N_LAYERS,
            max(n_qubits - 1, 1),
            3
        )

        # ----------------------------------------------------
        # Rotaciones locales entrenables
        # ----------------------------------------------------
        if init_theta is None:

            theta = torch.empty(
                theta_shape,
                dtype=torch.float32,
                device=DEVICE
            )

            theta.uniform_(
                -np.pi / 2,
                np.pi / 2
            )

        else:

            theta = (
                init_theta
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        # ----------------------------------------------------
        # Acoplamientos controlados
        # Se mantienen en cero para que inicialmente sean identidad.
        # ----------------------------------------------------
        if init_phi is None:

            phi = torch.zeros(
                phi_shape,
                dtype=torch.float32,
                device=DEVICE
            )

        else:

            phi = (
                init_phi
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        assert theta.shape == theta_shape
        assert phi.shape == phi_shape

        self.theta = nn.Parameter(theta)
        self.phi = nn.Parameter(phi)

        self.qnode = batched_qnodes[n_qubits]

    def forward(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        probs = probs.float()

        # Probabilidad asociada a la clase 1.
        score_class1 = probs[:, 1]

        return score_class1

    def predict_proba(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        return probs.float()

# %% [markdown]
# ## 7.2 — Funciones de transferencia Q(n) → Q(n+1)

# %%
def expand_theta_from_previous(
    previous_theta,
    new_n_qubits
):

    previous_theta = (
        previous_theta
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    old_n_qubits = previous_theta.shape[1]

    assert new_n_qubits == old_n_qubits + 1

    # Inicialización de los parámetros del modelo ampliado.
    new_theta = torch.empty(
        N_LAYERS,
        new_n_qubits,
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    new_theta.uniform_(
        -np.pi / 2,
        np.pi / 2
    )

    # Conservar exactamente los parámetros de los qubits
    # que ya fueron entrenados.
    new_theta[
        :,
        :old_n_qubits,
        :
    ] = previous_theta

    return new_theta


def expand_phi_from_previous(
    previous_phi,
    new_n_qubits
):

    previous_phi = (
        previous_phi
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    new_phi = torch.zeros(
        N_LAYERS,
        max(new_n_qubits - 1, 1),
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    if new_n_qubits > 2:

        old_phi_width = previous_phi.shape[1]

        new_phi[
            :,
            :old_phi_width,
            :
        ] = previous_phi

    return new_phi


def make_next_model_from_previous(
    previous_model,
    new_n_qubits
):

    init_theta = expand_theta_from_previous(
        previous_model.theta,
        new_n_qubits
    )

    init_phi = expand_phi_from_previous(
        previous_model.phi,
        new_n_qubits
    )

    model = BatchedDRQNN(
        n_qubits=new_n_qubits,
        init_theta=init_theta,
        init_phi=init_phi
    )

    return model


print("Funciones de expansión definidas correctamente.")
# Out:
# Funciones de expansión definidas correctamente.

# %% [markdown]
# ## 7.3 — Crear modelo inicial Q1

# %%
model_1q = BatchedDRQNN(
    n_qubits=1
)

print("Modelo Q1 creado")
print(model_1q)

print("\nParámetros Q1:")
for name, param in model_1q.named_parameters():

    print(
        name,
        tuple(param.shape),
        param.dtype,
        param.device,
        "requires_grad=",
        param.requires_grad
    )
# Out:
# Modelo Q1 creado
# BatchedDRQNN()
#
# Parámetros Q1:
# theta (6, 1, 3) torch.float32 cuda:0 requires_grad= True
# phi (6, 1, 3) torch.float32 cuda:0 requires_grad= True

# %% [markdown]
# ## 7.4 — Sanity check forward Q1

# %%
with torch.no_grad():

    q1_scores = model_1q(
        X_sanity
    )

    q1_probs = model_1q.predict_proba(
        X_sanity
    )

print("\nSanity forward Q1")
print("scores:", q1_scores.shape, q1_scores.dtype, q1_scores.device)
print("probs :", q1_probs.shape, q1_probs.dtype, q1_probs.device)

assert q1_scores.ndim == 1
assert q1_scores.shape[0] == SANITY_BATCH_SIZE
assert q1_scores.dtype == torch.float32

assert q1_probs.ndim == 2
assert q1_probs.shape == (
    SANITY_BATCH_SIZE,
    2
)
assert q1_probs.dtype == torch.float32
# Out:
# Sanity forward Q1
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.5 — Sanity check expansión Q1 → Q5

# %%
model_sanity = model_1q

sanity_models = {
    1: model_1q
}

for next_q in QUBITS_LIST[1:]:

    model_sanity = make_next_model_from_previous(
        model_sanity,
        next_q
    )

    sanity_models[next_q] = model_sanity

    with torch.no_grad():

        scores = model_sanity(
            X_sanity
        )

        probs = model_sanity.predict_proba(
            X_sanity
        )

    print(f"\nSanity modelo Q{next_q}")
    print("scores:", scores.shape, scores.dtype, scores.device)
    print("probs :", probs.shape, probs.dtype, probs.device)

    assert scores.ndim == 1
    assert scores.shape[0] == SANITY_BATCH_SIZE
    assert scores.dtype == torch.float32

    assert probs.ndim == 2
    assert probs.shape == (
        SANITY_BATCH_SIZE,
        2
    )
    assert probs.dtype == torch.float32
# Out:
# Sanity modelo Q2
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q3
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q4
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q5
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.6 — Convención final del modelo

# %%
print("\nSección 7 lista.")
print("Cada modelo recibe X_batch con shape (B, 3).")
print("Cada forward devuelve scores clase 1 con shape (B,).")
print("predict_proba devuelve probs float32 con shape (B, 2).")
print("Los QNodes devuelven float64, pero el modelo convierte a float32.")
# Out:
# Sección 7 lista.
# Cada modelo recibe X_batch con shape (B, 3).
# Cada forward devuelve scores clase 1 con shape (B,).
# predict_proba devuelve probs float32 con shape (B, 2).
# Los QNodes devuelven float64, pero el modelo convierte a float32.

# %% [markdown]
# # **8**

# %% [markdown]
# ## 8.1 — Loss de fidelidad para clasificación binaria

# %%
def fidelity_loss_from_scores(
    scores_class1,
    y_batch
):
    """
    MSE entre una salida en [-1, 1] y etiquetas {-1, +1}.

    scores_class1:
        Probabilidad P(clase=1), en [0, 1].

    Convención:
        clase 0 -> -1
        clase 1 -> +1
    """

    y_batch = y_batch.float()

    # P(clase=1) en [0,1] -> score en [-1,1].
    z_class1 = 2.0 * scores_class1 - 1.0

    # Etiquetas 0/1 -> etiquetas -1/+1.
    y_pm1 = 2.0 * y_batch - 1.0

    loss = torch.mean(
        (z_class1 - y_pm1) ** 2
    )

    return loss

# %% [markdown]
# ## 8.2 — Predicción batched sin evaluar muestra por muestra

# %%
@torch.no_grad()
def predict_scores_batched(model, X, chunk_size=131072):
    model.eval()
    scores_all = []
    for X_chunk in make_tensor_batches(X, y=None, batch_size=chunk_size, shuffle=False, seed=None):
        scores_chunk = model(X_chunk)
        scores_all.append(scores_chunk.detach().cpu())
    scores_all = torch.cat(scores_all, dim=0 ).numpy()

    return scores_all

# %% [markdown]
# ## 8.3 — Métricas binarias

# %%
def compute_binary_metrics(y_true, scores, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    scores = np.asarray(scores)
    y_pred = (scores >= threshold).astype(int)

    metrics = {"threshold": float(threshold), "accuracy": float( accuracy_score( y_true, y_pred)), "balanced_accuracy": float(balanced_accuracy_score( y_true, y_pred)), "f1": float(f1_score(y_true, y_pred)),
        "confusion_matrix": confusion_matrix(y_true, y_pred).tolist(),}

    return metrics

# %% [markdown]
# ## 8.4 — Evaluación completa batched

# %%
def evaluate_model(model, X, y, split_name, chunk_size=131072, threshold=0.5):
    scores = predict_scores_batched( model=model, X=X, chunk_size=chunk_size )
    y_np = y.detach().cpu().numpy()
    metrics = compute_binary_metrics( y_true=y_np, scores=scores, threshold=threshold)
    metrics["split"] = split_name
    metrics["n_samples"] = int(len(y_np))

    return metrics, scores

# %% [markdown]
# ## 8.5 — Entrenamiento de un modelo Qn

# %%
def train_drqnn_model(model, n_qubits, checkpoint_path):
    if n_qubits == 1:
        epochs = EPOCHS_1Q
        lr = LR_1Q
    else:
        epochs = EPOCHS_NQ
        lr = LR_NQ
    optimizer = optim.Adam(model.parameters(), lr=lr)

    best_test_bacc = -np.inf
    best_state = None

    history = []

    print("\nEntrenando DR-QNN")
    print("Qubits:", n_qubits)
    print("Epochs:", epochs)
    print("LR:", lr)
    print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)

    for epoch in range(1, epochs + 1):
        model.train()
        epoch_losses = []

        for X_batch, y_batch in make_tensor_batches(
            X_train_t,
            y_train_float_t,
            batch_size=TRAIN_BATCH_SIZE_TORCH,
            shuffle=True,
            seed=GLOBAL_SEED + epoch
        ):

            optimizer.zero_grad(set_to_none=True)
            scores = model(X_batch)
            loss = fidelity_loss_from_scores(scores, y_batch)
            loss.backward()
            optimizer.step()
            epoch_losses.append(float(loss.detach().cpu().item()))

        train_metrics, _ = evaluate_model(
            model=model,
            X=X_train_t,
            y=y_train_t,
            split_name="train",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        test_metrics, _ = evaluate_model(
            model=model,
            X=X_test_t,
            y=y_test_t,
            split_name="test",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        mean_loss = float(
            np.mean(epoch_losses)
        )

        row = {
            "n_qubits": int(n_qubits),
            "epoch": int(epoch),
            "loss": mean_loss,
            "train_accuracy": train_metrics["accuracy"],
            "train_balanced_accuracy": train_metrics["balanced_accuracy"],
            "train_f1": train_metrics["f1"],
            "test_accuracy": test_metrics["accuracy"],
            "test_balanced_accuracy": test_metrics["balanced_accuracy"],
            "test_f1": test_metrics["f1"],
        }

        history.append(
            row
        )

        print(
            f"Q{n_qubits} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={mean_loss:.6f} | "
            f"train_acc={train_metrics['accuracy']:.4f} | "
            f"test_acc={test_metrics['accuracy']:.4f} | "
            f"test_bAcc={test_metrics['balanced_accuracy']:.4f}"
        )

        if test_metrics["balanced_accuracy"] > best_test_bacc:

            best_test_bacc = test_metrics["balanced_accuracy"]

            best_state = {
                "n_qubits": int(n_qubits),
                "epoch": int(epoch),
                "model_state_dict": {
                    k: v.detach().cpu()
                    for k, v in model.state_dict().items()
                },
                "test_metrics": test_metrics,
                "train_metrics": train_metrics,
                "config": CONFIG,
            }

            torch.save(
                best_state,
                checkpoint_path
            )

    if best_state is not None:

        model.load_state_dict(
            {
                k: v.to(DEVICE)
                for k, v in best_state["model_state_dict"].items()
            }
        )

    history_df = pd.DataFrame(
        history
    )

    print("\nMejor test balanced accuracy:")
    print(best_test_bacc)

    print("Checkpoint guardado en:")
    print(checkpoint_path)

    return model, history_df

# %% [markdown]
# ## 8.6 — Rutas de checkpoints por número de qubits

# %%
CHECKPOINT_PATHS = {
    1: CHECKPOINT_1Q_PATH,
    2: CHECKPOINT_2Q_PATH,
    3: CHECKPOINT_3Q_PATH,
    4: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_4q.pt"
    ),
    5: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_5q.pt"
    ),
}

print("Sección 8 lista.")
print("Ya están definidas las funciones de loss, evaluación batched y entrenamiento.")
# Out:
# Sección 8 lista.
# Ya están definidas las funciones de loss, evaluación batched y entrenamiento.

# %% [markdown]
# # **9**

# %% [markdown]
# ## 9.1 — Entrenamiento progresivo Q1 → Q5

# %%
trained_models = {}
training_histories = {}
final_metrics_rows = {}
final_scores = {}

current_model = None

for n_qubits in QUBITS_LIST:
    print("\n" + "=" * 80)
    print(f"ENTRENAMIENTO PROGRESIVO Q{n_qubits}")
    print("=" * 80)
    if n_qubits == 1:
        current_model = BatchedDRQNN(n_qubits=1)
    else:
        current_model = make_next_model_from_previous(previous_model=current_model, new_n_qubits=n_qubits)

    checkpoint_path = CHECKPOINT_PATHS[n_qubits]
    current_model, history_df = train_drqnn_model(
        model=current_model,
        n_qubits=n_qubits,
        checkpoint_path=checkpoint_path
    )

    trained_models[n_qubits] = current_model
    training_histories[n_qubits] = history_df

    train_metrics, train_scores = evaluate_model(
        model=current_model,
        X=X_train_t,
        y=y_train_t,
        split_name="train",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    test_metrics, test_scores = evaluate_model(
        model=current_model,
        X=X_test_t,
        y=y_test_t,
        split_name="test",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    final_metrics_rows[n_qubits] = {
        "n_qubits": int(n_qubits),
        "train_accuracy": train_metrics["accuracy"],
        "train_balanced_accuracy": train_metrics["balanced_accuracy"],
        "train_f1": train_metrics["f1"],
        "test_accuracy": test_metrics["accuracy"],
        "test_balanced_accuracy": test_metrics["balanced_accuracy"],
        "test_f1": test_metrics["f1"],
        "checkpoint_path": checkpoint_path,
    }

    final_scores[n_qubits] = {
        "train_scores": train_scores,
        "test_scores": test_scores,
        "train_metrics": train_metrics,
        "test_metrics": test_metrics,
    }

    print("\nResultado final Q", n_qubits)
    print("TRAIN:", train_metrics)
    print("TEST :", test_metrics)
# Out:
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q1
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 1
# Epochs: 60
# LR: 0.006
# TRAIN_BATCH_SIZE_TORCH: 32
# Q1 | Epoch 001/60 | loss=0.671302 | train_acc=0.8098 | test_acc=0.8101 | test_bAcc=0.8120
# Q1 | Epoch 002/60 | loss=0.517026 | train_acc=0.8334 | test_acc=0.8298 | test_bAcc=0.8310
# Q1 | Epoch 003/60 | loss=0.468958 | train_acc=0.8423 | test_acc=0.8408 | test_bAcc=0.8421
# Q1 | Epoch 004/60 | loss=0.458714 | train_acc=0.8420 | test_acc=0.8427 | test_bAcc=0.8440
# Q1 | Epoch 005/60 | loss=0.456164 | train_acc=0.8399 | test_acc=0.8422 | test_bAcc=0.8429
# Q1 | Epoch 006/60 | loss=0.455783 | train_acc=0.8443 | test_acc=0.8470 | test_bAcc=0.8485
# Q1 | Epoch 007/60 | loss=0.453035 | train_acc=0.8443 | test_acc=0.8480 | test_bAcc=0.8495
# Q1 | Epoch 008/60 | loss=0.449271 | train_acc=0.8482 | test_acc=0.8515 | test_bAcc=0.8526
# Q1 | Epoch 009/60 | loss=0.445418 | train_acc=0.8447 | test_acc=0.8496 | test_bAcc=0.8513
# Q1 | Epoch 010/60 | loss=0.441620 | train_acc=0.8464 | test_acc=0.8506 | test_bAcc=0.8520
# Q1 | Epoch 011/60 | loss=0.437016 | train_acc=0.8515 | test_acc=0.8561 | test_bAcc=0.8576
# Q1 | Epoch 012/60 | loss=0.433921 | train_acc=0.8516 | test_acc=0.8584 | test_bAcc=0.8600
# Q1 | Epoch 013/60 | loss=0.430808 | train_acc=0.8554 | test_acc=0.8568 | test_bAcc=0.8580
# Q1 | Epoch 014/60 | loss=0.429588 | train_acc=0.8564 | test_acc=0.8572 | test_bAcc=0.8592
# Q1 | Epoch 015/60 | loss=0.428826 | train_acc=0.8569 | test_acc=0.8625 | test_bAcc=0.8641
# Q1 | Epoch 016/60 | loss=0.428318 | train_acc=0.8557 | test_acc=0.8599 | test_bAcc=0.8613
# Q1 | Epoch 017/60 | loss=0.426527 | train_acc=0.8558 | test_acc=0.8584 | test_bAcc=0.8603
# Q1 | Epoch 018/60 | loss=0.427062 | train_acc=0.8578 | test_acc=0.8620 | test_bAcc=0.8637
# Q1 | Epoch 019/60 | loss=0.426016 | train_acc=0.8536 | test_acc=0.8558 | test_bAcc=0.8578
# Q1 | Epoch 020/60 | loss=0.424802 | train_acc=0.8596 | test_acc=0.8620 | test_bAcc=0.8636
# Q1 | Epoch 021/60 | loss=0.424331 | train_acc=0.8561 | test_acc=0.8625 | test_bAcc=0.8639
# Q1 | Epoch 022/60 | loss=0.424336 | train_acc=0.8580 | test_acc=0.8613 | test_bAcc=0.8626
# Q1 | Epoch 023/60 | loss=0.423815 | train_acc=0.8592 | test_acc=0.8627 | test_bAcc=0.8645
# Q1 | Epoch 024/60 | loss=0.425069 | train_acc=0.8591 | test_acc=0.8637 | test_bAcc=0.8652
# Q1 | Epoch 025/60 | loss=0.423947 | train_acc=0.8601 | test_acc=0.8627 | test_bAcc=0.8643
# Q1 | Epoch 026/60 | loss=0.422940 | train_acc=0.8576 | test_acc=0.8599 | test_bAcc=0.8617
# Q1 | Epoch 027/60 | loss=0.423668 | train_acc=0.8570 | test_acc=0.8589 | test_bAcc=0.8608
# Q1 | Epoch 028/60 | loss=0.422486 | train_acc=0.8577 | test_acc=0.8606 | test_bAcc=0.8620
# Q1 | Epoch 029/60 | loss=0.422948 | train_acc=0.8586 | test_acc=0.8627 | test_bAcc=0.8643
# Q1 | Epoch 030/60 | loss=0.422739 | train_acc=0.8588 | test_acc=0.8630 | test_bAcc=0.8646
# Q1 | Epoch 031/60 | loss=0.422033 | train_acc=0.8608 | test_acc=0.8630 | test_bAcc=0.8645
# Q1 | Epoch 032/60 | loss=0.421631 | train_acc=0.8580 | test_acc=0.8587 | test_bAcc=0.8607
# Q1 | Epoch 033/60 | loss=0.422264 | train_acc=0.8591 | test_acc=0.8630 | test_bAcc=0.8645
# Q1 | Epoch 034/60 | loss=0.421355 | train_acc=0.8612 | test_acc=0.8644 | test_bAcc=0.8662
# Q1 | Epoch 035/60 | loss=0.422920 | train_acc=0.8604 | test_acc=0.8632 | test_bAcc=0.8649
# Q1 | Epoch 036/60 | loss=0.423206 | train_acc=0.8605 | test_acc=0.8637 | test_bAcc=0.8654
# Q1 | Epoch 037/60 | loss=0.421704 | train_acc=0.8602 | test_acc=0.8613 | test_bAcc=0.8632
# Q1 | Epoch 038/60 | loss=0.422258 | train_acc=0.8600 | test_acc=0.8627 | test_bAcc=0.8644
# Q1 | Epoch 039/60 | loss=0.422774 | train_acc=0.8579 | test_acc=0.8580 | test_bAcc=0.8600
# Q1 | Epoch 040/60 | loss=0.421019 | train_acc=0.8582 | test_acc=0.8613 | test_bAcc=0.8626
# Q1 | Epoch 041/60 | loss=0.421311 | train_acc=0.8607 | test_acc=0.8642 | test_bAcc=0.8659
# Q1 | Epoch 042/60 | loss=0.422255 | train_acc=0.8610 | test_acc=0.8642 | test_bAcc=0.8660
# Q1 | Epoch 043/60 | loss=0.421330 | train_acc=0.8594 | test_acc=0.8632 | test_bAcc=0.8649
# Q1 | Epoch 044/60 | loss=0.421746 | train_acc=0.8580 | test_acc=0.8603 | test_bAcc=0.8621
# Q1 | Epoch 045/60 | loss=0.421003 | train_acc=0.8598 | test_acc=0.8620 | test_bAcc=0.8638
# Q1 | Epoch 046/60 | loss=0.421595 | train_acc=0.8563 | test_acc=0.8568 | test_bAcc=0.8590
# Q1 | Epoch 047/60 | loss=0.421740 | train_acc=0.8604 | test_acc=0.8625 | test_bAcc=0.8641
# Q1 | Epoch 048/60 | loss=0.420710 | train_acc=0.8620 | test_acc=0.8637 | test_bAcc=0.8653
# Q1 | Epoch 049/60 | loss=0.421273 | train_acc=0.8633 | test_acc=0.8644 | test_bAcc=0.8661
# Q1 | Epoch 050/60 | loss=0.421257 | train_acc=0.8617 | test_acc=0.8627 | test_bAcc=0.8643
# Q1 | Epoch 051/60 | loss=0.421591 | train_acc=0.8594 | test_acc=0.8622 | test_bAcc=0.8638
# Q1 | Epoch 052/60 | loss=0.420813 | train_acc=0.8598 | test_acc=0.8634 | test_bAcc=0.8653
# Q1 | Epoch 053/60 | loss=0.420352 | train_acc=0.8625 | test_acc=0.8642 | test_bAcc=0.8661
# Q1 | Epoch 054/60 | loss=0.420975 | train_acc=0.8573 | test_acc=0.8582 | test_bAcc=0.8602
# Q1 | Epoch 055/60 | loss=0.420642 | train_acc=0.8569 | test_acc=0.8587 | test_bAcc=0.8607
# Q1 | Epoch 056/60 | loss=0.421103 | train_acc=0.8600 | test_acc=0.8632 | test_bAcc=0.8649
# Q1 | Epoch 057/60 | loss=0.420708 | train_acc=0.8623 | test_acc=0.8637 | test_bAcc=0.8654
# Q1 | Epoch 058/60 | loss=0.420551 | train_acc=0.8585 | test_acc=0.8625 | test_bAcc=0.8638
# Q1 | Epoch 059/60 | loss=0.420660 | train_acc=0.8609 | test_acc=0.8637 | test_bAcc=0.8654
# Q1 | Epoch 060/60 | loss=0.421172 | train_acc=0.8629 | test_acc=0.8646 | test_bAcc=0.8660
#
# Mejor test balanced accuracy:
# 0.8662135464262833
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_1q.pt
#
# Resultado final Q 1
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8612038140643623, 'balanced_accuracy': 0.86291050828331, 'f1': 0.8498291314720485, 'confusion_matrix': [[7861, 373], [1956, 6590]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8643946615824595, 'balanced_accuracy': 0.8662135464262833, 'f1': 0.8523228652997664, 'confusion_matrix': [[1985, 74], [495, 1642]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q2
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 2
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q2 | Epoch 001/50 | loss=0.419788 | train_acc=0.8635 | test_acc=0.8646 | test_bAcc=0.8663
# Q2 | Epoch 002/50 | loss=0.416686 | train_acc=0.8594 | test_acc=0.8642 | test_bAcc=0.8657
# Q2 | Epoch 003/50 | loss=0.415575 | train_acc=0.8641 | test_acc=0.8665 | test_bAcc=0.8682
# Q2 | Epoch 004/50 | loss=0.412384 | train_acc=0.8652 | test_acc=0.8682 | test_bAcc=0.8698
# Q2 | Epoch 005/50 | loss=0.410845 | train_acc=0.8562 | test_acc=0.8584 | test_bAcc=0.8591
# Q2 | Epoch 006/50 | loss=0.410668 | train_acc=0.8677 | test_acc=0.8684 | test_bAcc=0.8702
# Q2 | Epoch 007/50 | loss=0.408849 | train_acc=0.8671 | test_acc=0.8692 | test_bAcc=0.8709
# Q2 | Epoch 008/50 | loss=0.407376 | train_acc=0.8680 | test_acc=0.8689 | test_bAcc=0.8702
# Q2 | Epoch 009/50 | loss=0.406147 | train_acc=0.8662 | test_acc=0.8673 | test_bAcc=0.8690
# Q2 | Epoch 010/50 | loss=0.406064 | train_acc=0.8636 | test_acc=0.8653 | test_bAcc=0.8668
# Q2 | Epoch 011/50 | loss=0.404460 | train_acc=0.8678 | test_acc=0.8699 | test_bAcc=0.8714
# Q2 | Epoch 012/50 | loss=0.404396 | train_acc=0.8667 | test_acc=0.8701 | test_bAcc=0.8717
# Q2 | Epoch 013/50 | loss=0.403150 | train_acc=0.8667 | test_acc=0.8694 | test_bAcc=0.8705
# Q2 | Epoch 014/50 | loss=0.403036 | train_acc=0.8695 | test_acc=0.8715 | test_bAcc=0.8734
# Q2 | Epoch 015/50 | loss=0.402759 | train_acc=0.8681 | test_acc=0.8706 | test_bAcc=0.8721
# Q2 | Epoch 016/50 | loss=0.403027 | train_acc=0.8665 | test_acc=0.8675 | test_bAcc=0.8688
# Q2 | Epoch 017/50 | loss=0.401275 | train_acc=0.8682 | test_acc=0.8713 | test_bAcc=0.8731
# Q2 | Epoch 018/50 | loss=0.402357 | train_acc=0.8693 | test_acc=0.8699 | test_bAcc=0.8716
# Q2 | Epoch 019/50 | loss=0.401377 | train_acc=0.8667 | test_acc=0.8677 | test_bAcc=0.8696
# Q2 | Epoch 020/50 | loss=0.400399 | train_acc=0.8693 | test_acc=0.8706 | test_bAcc=0.8720
# Q2 | Epoch 021/50 | loss=0.399717 | train_acc=0.8667 | test_acc=0.8670 | test_bAcc=0.8682
# Q2 | Epoch 022/50 | loss=0.399757 | train_acc=0.8668 | test_acc=0.8692 | test_bAcc=0.8704
# Q2 | Epoch 023/50 | loss=0.399570 | train_acc=0.8688 | test_acc=0.8689 | test_bAcc=0.8706
# Q2 | Epoch 024/50 | loss=0.400212 | train_acc=0.8685 | test_acc=0.8689 | test_bAcc=0.8702
# Q2 | Epoch 025/50 | loss=0.399121 | train_acc=0.8700 | test_acc=0.8708 | test_bAcc=0.8723
# Q2 | Epoch 026/50 | loss=0.398347 | train_acc=0.8697 | test_acc=0.8694 | test_bAcc=0.8711
# Q2 | Epoch 027/50 | loss=0.398427 | train_acc=0.8692 | test_acc=0.8670 | test_bAcc=0.8688
# Q2 | Epoch 028/50 | loss=0.397190 | train_acc=0.8679 | test_acc=0.8673 | test_bAcc=0.8685
# Q2 | Epoch 029/50 | loss=0.397757 | train_acc=0.8690 | test_acc=0.8689 | test_bAcc=0.8704
# Q2 | Epoch 030/50 | loss=0.397148 | train_acc=0.8697 | test_acc=0.8687 | test_bAcc=0.8702
# Q2 | Epoch 031/50 | loss=0.396390 | train_acc=0.8702 | test_acc=0.8696 | test_bAcc=0.8710
# Q2 | Epoch 032/50 | loss=0.395769 | train_acc=0.8693 | test_acc=0.8687 | test_bAcc=0.8706
# Q2 | Epoch 033/50 | loss=0.396287 | train_acc=0.8692 | test_acc=0.8694 | test_bAcc=0.8708
# Q2 | Epoch 034/50 | loss=0.395034 | train_acc=0.8708 | test_acc=0.8701 | test_bAcc=0.8718
# Q2 | Epoch 035/50 | loss=0.396614 | train_acc=0.8709 | test_acc=0.8701 | test_bAcc=0.8717
# Q2 | Epoch 036/50 | loss=0.396865 | train_acc=0.8703 | test_acc=0.8699 | test_bAcc=0.8714
# Q2 | Epoch 037/50 | loss=0.395152 | train_acc=0.8704 | test_acc=0.8699 | test_bAcc=0.8716
# Q2 | Epoch 038/50 | loss=0.395738 | train_acc=0.8714 | test_acc=0.8708 | test_bAcc=0.8724
# Q2 | Epoch 039/50 | loss=0.396030 | train_acc=0.8706 | test_acc=0.8692 | test_bAcc=0.8710
# Q2 | Epoch 040/50 | loss=0.394245 | train_acc=0.8687 | test_acc=0.8689 | test_bAcc=0.8701
# Q2 | Epoch 041/50 | loss=0.394613 | train_acc=0.8715 | test_acc=0.8696 | test_bAcc=0.8713
# Q2 | Epoch 042/50 | loss=0.395226 | train_acc=0.8710 | test_acc=0.8689 | test_bAcc=0.8706
# Q2 | Epoch 043/50 | loss=0.394328 | train_acc=0.8706 | test_acc=0.8696 | test_bAcc=0.8712
# Q2 | Epoch 044/50 | loss=0.394457 | train_acc=0.8700 | test_acc=0.8699 | test_bAcc=0.8715
# Q2 | Epoch 045/50 | loss=0.393884 | train_acc=0.8704 | test_acc=0.8692 | test_bAcc=0.8709
# Q2 | Epoch 046/50 | loss=0.394465 | train_acc=0.8685 | test_acc=0.8658 | test_bAcc=0.8678
# Q2 | Epoch 047/50 | loss=0.394547 | train_acc=0.8716 | test_acc=0.8708 | test_bAcc=0.8723
# Q2 | Epoch 048/50 | loss=0.393659 | train_acc=0.8712 | test_acc=0.8708 | test_bAcc=0.8722
# Q2 | Epoch 049/50 | loss=0.393782 | train_acc=0.8732 | test_acc=0.8737 | test_bAcc=0.8753
# Q2 | Epoch 050/50 | loss=0.394059 | train_acc=0.8708 | test_acc=0.8704 | test_bAcc=0.8717
#
# Mejor test balanced accuracy:
# 0.875303034056403
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_2q.pt
#
# Resultado final Q 2
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8731823599523242, 'balanced_accuracy': 0.8746836974953474, 'f1': 0.864441330105746, 'confusion_matrix': [[7867, 367], [1761, 6785]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8736892278360343, 'balanced_accuracy': 0.875303034056403, 'f1': 0.8641025641025641, 'confusion_matrix': [[1981, 78], [452, 1685]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q3
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 3
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q3 | Epoch 001/50 | loss=0.393612 | train_acc=0.8721 | test_acc=0.8720 | test_bAcc=0.8734
# Q3 | Epoch 002/50 | loss=0.392493 | train_acc=0.8700 | test_acc=0.8704 | test_bAcc=0.8718
# Q3 | Epoch 003/50 | loss=0.392855 | train_acc=0.8729 | test_acc=0.8718 | test_bAcc=0.8733
# Q3 | Epoch 004/50 | loss=0.391078 | train_acc=0.8729 | test_acc=0.8730 | test_bAcc=0.8746
# Q3 | Epoch 005/50 | loss=0.390987 | train_acc=0.8644 | test_acc=0.8653 | test_bAcc=0.8661
# Q3 | Epoch 006/50 | loss=0.392452 | train_acc=0.8730 | test_acc=0.8730 | test_bAcc=0.8746
# Q3 | Epoch 007/50 | loss=0.391482 | train_acc=0.8724 | test_acc=0.8725 | test_bAcc=0.8742
# Q3 | Epoch 008/50 | loss=0.390707 | train_acc=0.8734 | test_acc=0.8727 | test_bAcc=0.8740
# Q3 | Epoch 009/50 | loss=0.390268 | train_acc=0.8717 | test_acc=0.8699 | test_bAcc=0.8717
# Q3 | Epoch 010/50 | loss=0.391132 | train_acc=0.8703 | test_acc=0.8699 | test_bAcc=0.8715
# Q3 | Epoch 011/50 | loss=0.389766 | train_acc=0.8737 | test_acc=0.8739 | test_bAcc=0.8755
# Q3 | Epoch 012/50 | loss=0.389985 | train_acc=0.8723 | test_acc=0.8708 | test_bAcc=0.8724
# Q3 | Epoch 013/50 | loss=0.389319 | train_acc=0.8719 | test_acc=0.8730 | test_bAcc=0.8741
# Q3 | Epoch 014/50 | loss=0.389416 | train_acc=0.8722 | test_acc=0.8706 | test_bAcc=0.8725
# Q3 | Epoch 015/50 | loss=0.389542 | train_acc=0.8733 | test_acc=0.8735 | test_bAcc=0.8751
# Q3 | Epoch 016/50 | loss=0.389971 | train_acc=0.8722 | test_acc=0.8708 | test_bAcc=0.8722
# Q3 | Epoch 017/50 | loss=0.388823 | train_acc=0.8728 | test_acc=0.8713 | test_bAcc=0.8731
# Q3 | Epoch 018/50 | loss=0.390052 | train_acc=0.8744 | test_acc=0.8737 | test_bAcc=0.8754
# Q3 | Epoch 019/50 | loss=0.389205 | train_acc=0.8694 | test_acc=0.8687 | test_bAcc=0.8706
# Q3 | Epoch 020/50 | loss=0.388665 | train_acc=0.8733 | test_acc=0.8737 | test_bAcc=0.8752
# Q3 | Epoch 021/50 | loss=0.388237 | train_acc=0.8716 | test_acc=0.8711 | test_bAcc=0.8723
# Q3 | Epoch 022/50 | loss=0.388707 | train_acc=0.8724 | test_acc=0.8723 | test_bAcc=0.8735
# Q3 | Epoch 023/50 | loss=0.388719 | train_acc=0.8731 | test_acc=0.8727 | test_bAcc=0.8744
# Q3 | Epoch 024/50 | loss=0.389984 | train_acc=0.8721 | test_acc=0.8706 | test_bAcc=0.8719
# Q3 | Epoch 025/50 | loss=0.389087 | train_acc=0.8741 | test_acc=0.8718 | test_bAcc=0.8732
# Q3 | Epoch 026/50 | loss=0.388380 | train_acc=0.8735 | test_acc=0.8739 | test_bAcc=0.8756
# Q3 | Epoch 027/50 | loss=0.388742 | train_acc=0.8724 | test_acc=0.8706 | test_bAcc=0.8724
# Q3 | Epoch 028/50 | loss=0.387593 | train_acc=0.8712 | test_acc=0.8711 | test_bAcc=0.8723
# Q3 | Epoch 029/50 | loss=0.388868 | train_acc=0.8723 | test_acc=0.8730 | test_bAcc=0.8744
# Q3 | Epoch 030/50 | loss=0.388118 | train_acc=0.8732 | test_acc=0.8727 | test_bAcc=0.8744
# Q3 | Epoch 031/50 | loss=0.387529 | train_acc=0.8735 | test_acc=0.8715 | test_bAcc=0.8729
# Q3 | Epoch 032/50 | loss=0.387158 | train_acc=0.8722 | test_acc=0.8687 | test_bAcc=0.8706
# Q3 | Epoch 033/50 | loss=0.387744 | train_acc=0.8710 | test_acc=0.8725 | test_bAcc=0.8739
# Q3 | Epoch 034/50 | loss=0.386654 | train_acc=0.8740 | test_acc=0.8744 | test_bAcc=0.8761
# Q3 | Epoch 035/50 | loss=0.388377 | train_acc=0.8741 | test_acc=0.8739 | test_bAcc=0.8755
# Q3 | Epoch 036/50 | loss=0.388798 | train_acc=0.8736 | test_acc=0.8732 | test_bAcc=0.8748
# Q3 | Epoch 037/50 | loss=0.386920 | train_acc=0.8735 | test_acc=0.8727 | test_bAcc=0.8745
# Q3 | Epoch 038/50 | loss=0.387635 | train_acc=0.8731 | test_acc=0.8746 | test_bAcc=0.8762
# Q3 | Epoch 039/50 | loss=0.388093 | train_acc=0.8721 | test_acc=0.8687 | test_bAcc=0.8706
# Q3 | Epoch 040/50 | loss=0.386320 | train_acc=0.8711 | test_acc=0.8713 | test_bAcc=0.8725
# Q3 | Epoch 041/50 | loss=0.386583 | train_acc=0.8743 | test_acc=0.8751 | test_bAcc=0.8768
# Q3 | Epoch 042/50 | loss=0.387333 | train_acc=0.8743 | test_acc=0.8749 | test_bAcc=0.8766
# Q3 | Epoch 043/50 | loss=0.386490 | train_acc=0.8732 | test_acc=0.8739 | test_bAcc=0.8755
# Q3 | Epoch 044/50 | loss=0.386410 | train_acc=0.8722 | test_acc=0.8727 | test_bAcc=0.8743
# Q3 | Epoch 045/50 | loss=0.386044 | train_acc=0.8734 | test_acc=0.8744 | test_bAcc=0.8761
# Q3 | Epoch 046/50 | loss=0.386743 | train_acc=0.8714 | test_acc=0.8682 | test_bAcc=0.8702
# Q3 | Epoch 047/50 | loss=0.386911 | train_acc=0.8742 | test_acc=0.8706 | test_bAcc=0.8720
# Q3 | Epoch 048/50 | loss=0.385979 | train_acc=0.8746 | test_acc=0.8727 | test_bAcc=0.8741
# Q3 | Epoch 049/50 | loss=0.385961 | train_acc=0.8749 | test_acc=0.8744 | test_bAcc=0.8760
# Q3 | Epoch 050/50 | loss=0.386535 | train_acc=0.8730 | test_acc=0.8723 | test_bAcc=0.8736
#
# Mejor test balanced accuracy:
# 0.8767600520262913
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_3q.pt
#
# Resultado final Q 3
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8743146603098927, 'balanced_accuracy': 0.8758330163794887, 'f1': 0.8655231779633998, 'confusion_matrix': [[7884, 350], [1759, 6787]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8751191611058151, 'balanced_accuracy': 0.8767600520262913, 'f1': 0.8654340010272213, 'confusion_matrix': [[1987, 72], [452, 1685]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q4
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 4
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q4 | Epoch 001/50 | loss=0.386862 | train_acc=0.8754 | test_acc=0.8744 | test_bAcc=0.8757
# Q4 | Epoch 002/50 | loss=0.386086 | train_acc=0.8723 | test_acc=0.8725 | test_bAcc=0.8739
# Q4 | Epoch 003/50 | loss=0.386872 | train_acc=0.8745 | test_acc=0.8744 | test_bAcc=0.8759
# Q4 | Epoch 004/50 | loss=0.385217 | train_acc=0.8736 | test_acc=0.8761 | test_bAcc=0.8776
# Q4 | Epoch 005/50 | loss=0.385424 | train_acc=0.8654 | test_acc=0.8670 | test_bAcc=0.8677
# Q4 | Epoch 006/50 | loss=0.386981 | train_acc=0.8744 | test_acc=0.8746 | test_bAcc=0.8763
# Q4 | Epoch 007/50 | loss=0.386097 | train_acc=0.8738 | test_acc=0.8739 | test_bAcc=0.8756
# Q4 | Epoch 008/50 | loss=0.385232 | train_acc=0.8735 | test_acc=0.8720 | test_bAcc=0.8732
# Q4 | Epoch 009/50 | loss=0.384847 | train_acc=0.8728 | test_acc=0.8704 | test_bAcc=0.8722
# Q4 | Epoch 010/50 | loss=0.385939 | train_acc=0.8723 | test_acc=0.8713 | test_bAcc=0.8729
# Q4 | Epoch 011/50 | loss=0.384441 | train_acc=0.8748 | test_acc=0.8765 | test_bAcc=0.8782
# Q4 | Epoch 012/50 | loss=0.384759 | train_acc=0.8732 | test_acc=0.8735 | test_bAcc=0.8750
# Q4 | Epoch 013/50 | loss=0.384036 | train_acc=0.8734 | test_acc=0.8730 | test_bAcc=0.8742
# Q4 | Epoch 014/50 | loss=0.384017 | train_acc=0.8733 | test_acc=0.8715 | test_bAcc=0.8734
# Q4 | Epoch 015/50 | loss=0.384503 | train_acc=0.8743 | test_acc=0.8756 | test_bAcc=0.8772
# Q4 | Epoch 016/50 | loss=0.384931 | train_acc=0.8739 | test_acc=0.8737 | test_bAcc=0.8750
# Q4 | Epoch 017/50 | loss=0.383758 | train_acc=0.8741 | test_acc=0.8737 | test_bAcc=0.8754
# Q4 | Epoch 018/50 | loss=0.385116 | train_acc=0.8751 | test_acc=0.8763 | test_bAcc=0.8780
# Q4 | Epoch 019/50 | loss=0.384003 | train_acc=0.8708 | test_acc=0.8694 | test_bAcc=0.8713
# Q4 | Epoch 020/50 | loss=0.383551 | train_acc=0.8755 | test_acc=0.8746 | test_bAcc=0.8761
# Q4 | Epoch 021/50 | loss=0.383068 | train_acc=0.8741 | test_acc=0.8742 | test_bAcc=0.8754
# Q4 | Epoch 022/50 | loss=0.383717 | train_acc=0.8744 | test_acc=0.8744 | test_bAcc=0.8756
# Q4 | Epoch 023/50 | loss=0.383701 | train_acc=0.8744 | test_acc=0.8751 | test_bAcc=0.8768
# Q4 | Epoch 024/50 | loss=0.385080 | train_acc=0.8744 | test_acc=0.8735 | test_bAcc=0.8747
# Q4 | Epoch 025/50 | loss=0.384006 | train_acc=0.8755 | test_acc=0.8749 | test_bAcc=0.8763
# Q4 | Epoch 026/50 | loss=0.383242 | train_acc=0.8749 | test_acc=0.8761 | test_bAcc=0.8776
# Q4 | Epoch 027/50 | loss=0.383831 | train_acc=0.8733 | test_acc=0.8725 | test_bAcc=0.8743
# Q4 | Epoch 028/50 | loss=0.382493 | train_acc=0.8731 | test_acc=0.8727 | test_bAcc=0.8740
# Q4 | Epoch 029/50 | loss=0.383964 | train_acc=0.8741 | test_acc=0.8746 | test_bAcc=0.8761
# Q4 | Epoch 030/50 | loss=0.383160 | train_acc=0.8755 | test_acc=0.8751 | test_bAcc=0.8768
# Q4 | Epoch 031/50 | loss=0.382672 | train_acc=0.8755 | test_acc=0.8758 | test_bAcc=0.8772
# Q4 | Epoch 032/50 | loss=0.382116 | train_acc=0.8734 | test_acc=0.8706 | test_bAcc=0.8725
# Q4 | Epoch 033/50 | loss=0.382849 | train_acc=0.8738 | test_acc=0.8732 | test_bAcc=0.8746
# Q4 | Epoch 034/50 | loss=0.381775 | train_acc=0.8754 | test_acc=0.8754 | test_bAcc=0.8771
# Q4 | Epoch 035/50 | loss=0.383659 | train_acc=0.8752 | test_acc=0.8754 | test_bAcc=0.8770
# Q4 | Epoch 036/50 | loss=0.384269 | train_acc=0.8753 | test_acc=0.8756 | test_bAcc=0.8772
# Q4 | Epoch 037/50 | loss=0.382114 | train_acc=0.8747 | test_acc=0.8735 | test_bAcc=0.8752
# Q4 | Epoch 038/50 | loss=0.382939 | train_acc=0.8753 | test_acc=0.8768 | test_bAcc=0.8783
# Q4 | Epoch 039/50 | loss=0.383570 | train_acc=0.8727 | test_acc=0.8696 | test_bAcc=0.8715
# Q4 | Epoch 040/50 | loss=0.381739 | train_acc=0.8746 | test_acc=0.8732 | test_bAcc=0.8744
# Q4 | Epoch 041/50 | loss=0.382036 | train_acc=0.8756 | test_acc=0.8761 | test_bAcc=0.8777
# Q4 | Epoch 042/50 | loss=0.382903 | train_acc=0.8756 | test_acc=0.8754 | test_bAcc=0.8770
# Q4 | Epoch 043/50 | loss=0.382077 | train_acc=0.8747 | test_acc=0.8765 | test_bAcc=0.8782
# Q4 | Epoch 044/50 | loss=0.381964 | train_acc=0.8744 | test_acc=0.8742 | test_bAcc=0.8758
# Q4 | Epoch 045/50 | loss=0.381618 | train_acc=0.8740 | test_acc=0.8770 | test_bAcc=0.8786
# Q4 | Epoch 046/50 | loss=0.382365 | train_acc=0.8734 | test_acc=0.8699 | test_bAcc=0.8718
# Q4 | Epoch 047/50 | loss=0.382761 | train_acc=0.8755 | test_acc=0.8761 | test_bAcc=0.8775
# Q4 | Epoch 048/50 | loss=0.381864 | train_acc=0.8757 | test_acc=0.8754 | test_bAcc=0.8767
# Q4 | Epoch 049/50 | loss=0.381857 | train_acc=0.8757 | test_acc=0.8744 | test_bAcc=0.8760
# Q4 | Epoch 050/50 | loss=0.382595 | train_acc=0.8751 | test_acc=0.8756 | test_bAcc=0.8770
#
# Mejor test balanced accuracy:
# 0.878631834899478
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_4q.pt
#
# Resultado final Q 4
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8739570917759237, 'balanced_accuracy': 0.8754642395628771, 'f1': 0.8652265341234946, 'confusion_matrix': [[7876, 358], [1757, 6789]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.877025738798856, 'balanced_accuracy': 0.878631834899478, 'f1': 0.8677601230138391, 'confusion_matrix': [[1987, 72], [444, 1693]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q5
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 5
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q5 | Epoch 001/50 | loss=0.382211 | train_acc=0.8765 | test_acc=0.8761 | test_bAcc=0.8774
# Q5 | Epoch 002/50 | loss=0.381455 | train_acc=0.8746 | test_acc=0.8746 | test_bAcc=0.8761
# Q5 | Epoch 003/50 | loss=0.382448 | train_acc=0.8768 | test_acc=0.8773 | test_bAcc=0.8788
# Q5 | Epoch 004/50 | loss=0.380785 | train_acc=0.8753 | test_acc=0.8763 | test_bAcc=0.8779
# Q5 | Epoch 005/50 | loss=0.381216 | train_acc=0.8693 | test_acc=0.8696 | test_bAcc=0.8705
# Q5 | Epoch 006/50 | loss=0.382863 | train_acc=0.8759 | test_acc=0.8749 | test_bAcc=0.8765
# Q5 | Epoch 007/50 | loss=0.382058 | train_acc=0.8753 | test_acc=0.8754 | test_bAcc=0.8769
# Q5 | Epoch 008/50 | loss=0.381265 | train_acc=0.8746 | test_acc=0.8727 | test_bAcc=0.8740
# Q5 | Epoch 009/50 | loss=0.380998 | train_acc=0.8733 | test_acc=0.8708 | test_bAcc=0.8726
# Q5 | Epoch 010/50 | loss=0.382382 | train_acc=0.8740 | test_acc=0.8730 | test_bAcc=0.8746
# Q5 | Epoch 011/50 | loss=0.380964 | train_acc=0.8754 | test_acc=0.8770 | test_bAcc=0.8786
# Q5 | Epoch 012/50 | loss=0.381254 | train_acc=0.8747 | test_acc=0.8761 | test_bAcc=0.8777
# Q5 | Epoch 013/50 | loss=0.380571 | train_acc=0.8750 | test_acc=0.8744 | test_bAcc=0.8756
# Q5 | Epoch 014/50 | loss=0.380733 | train_acc=0.8735 | test_acc=0.8706 | test_bAcc=0.8724
# Q5 | Epoch 015/50 | loss=0.381388 | train_acc=0.8751 | test_acc=0.8751 | test_bAcc=0.8768
# Q5 | Epoch 016/50 | loss=0.381895 | train_acc=0.8757 | test_acc=0.8749 | test_bAcc=0.8762
# Q5 | Epoch 017/50 | loss=0.380824 | train_acc=0.8744 | test_acc=0.8735 | test_bAcc=0.8752
# Q5 | Epoch 018/50 | loss=0.382455 | train_acc=0.8756 | test_acc=0.8763 | test_bAcc=0.8780
# Q5 | Epoch 019/50 | loss=0.381317 | train_acc=0.8716 | test_acc=0.8701 | test_bAcc=0.8720
# Q5 | Epoch 020/50 | loss=0.380888 | train_acc=0.8762 | test_acc=0.8768 | test_bAcc=0.8783
# Q5 | Epoch 021/50 | loss=0.380416 | train_acc=0.8753 | test_acc=0.8756 | test_bAcc=0.8769
# Q5 | Epoch 022/50 | loss=0.381337 | train_acc=0.8754 | test_acc=0.8739 | test_bAcc=0.8752
# Q5 | Epoch 023/50 | loss=0.381404 | train_acc=0.8747 | test_acc=0.8758 | test_bAcc=0.8775
# Q5 | Epoch 024/50 | loss=0.382660 | train_acc=0.8754 | test_acc=0.8754 | test_bAcc=0.8766
# Q5 | Epoch 025/50 | loss=0.381810 | train_acc=0.8753 | test_acc=0.8756 | test_bAcc=0.8771
# Q5 | Epoch 026/50 | loss=0.380960 | train_acc=0.8754 | test_acc=0.8770 | test_bAcc=0.8786
# Q5 | Epoch 027/50 | loss=0.381638 | train_acc=0.8735 | test_acc=0.8715 | test_bAcc=0.8734
# Q5 | Epoch 028/50 | loss=0.380483 | train_acc=0.8749 | test_acc=0.8744 | test_bAcc=0.8757
# Q5 | Epoch 029/50 | loss=0.381874 | train_acc=0.8751 | test_acc=0.8751 | test_bAcc=0.8766
# Q5 | Epoch 030/50 | loss=0.381051 | train_acc=0.8753 | test_acc=0.8763 | test_bAcc=0.8779
# Q5 | Epoch 031/50 | loss=0.380734 | train_acc=0.8759 | test_acc=0.8761 | test_bAcc=0.8773
# Q5 | Epoch 032/50 | loss=0.380103 | train_acc=0.8732 | test_acc=0.8704 | test_bAcc=0.8722
# Q5 | Epoch 033/50 | loss=0.381085 | train_acc=0.8742 | test_acc=0.8765 | test_bAcc=0.8780
# Q5 | Epoch 034/50 | loss=0.379896 | train_acc=0.8751 | test_acc=0.8758 | test_bAcc=0.8775
# Q5 | Epoch 035/50 | loss=0.381877 | train_acc=0.8756 | test_acc=0.8758 | test_bAcc=0.8775
# Q5 | Epoch 036/50 | loss=0.382612 | train_acc=0.8753 | test_acc=0.8751 | test_bAcc=0.8767
# Q5 | Epoch 037/50 | loss=0.380285 | train_acc=0.8746 | test_acc=0.8737 | test_bAcc=0.8754
# Q5 | Epoch 038/50 | loss=0.381114 | train_acc=0.8756 | test_acc=0.8765 | test_bAcc=0.8781
# Q5 | Epoch 039/50 | loss=0.381868 | train_acc=0.8729 | test_acc=0.8704 | test_bAcc=0.8722
# Q5 | Epoch 040/50 | loss=0.379973 | train_acc=0.8754 | test_acc=0.8732 | test_bAcc=0.8745
# Q5 | Epoch 041/50 | loss=0.380425 | train_acc=0.8760 | test_acc=0.8749 | test_bAcc=0.8765
# Q5 | Epoch 042/50 | loss=0.381252 | train_acc=0.8755 | test_acc=0.8756 | test_bAcc=0.8772
# Q5 | Epoch 043/50 | loss=0.380451 | train_acc=0.8750 | test_acc=0.8761 | test_bAcc=0.8777
# Q5 | Epoch 044/50 | loss=0.380349 | train_acc=0.8750 | test_acc=0.8751 | test_bAcc=0.8767
# Q5 | Epoch 045/50 | loss=0.380020 | train_acc=0.8746 | test_acc=0.8768 | test_bAcc=0.8784
# Q5 | Epoch 046/50 | loss=0.380630 | train_acc=0.8735 | test_acc=0.8706 | test_bAcc=0.8725
# Q5 | Epoch 047/50 | loss=0.381188 | train_acc=0.8764 | test_acc=0.8751 | test_bAcc=0.8765
# Q5 | Epoch 048/50 | loss=0.380331 | train_acc=0.8762 | test_acc=0.8756 | test_bAcc=0.8770
# Q5 | Epoch 049/50 | loss=0.380272 | train_acc=0.8759 | test_acc=0.8758 | test_bAcc=0.8775
# Q5 | Epoch 050/50 | loss=0.381042 | train_acc=0.8756 | test_acc=0.8754 | test_bAcc=0.8768
#
# Mejor test balanced accuracy:
# 0.8787505826594635
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_5q.pt
#
# Resultado final Q 5
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8768176400476758, 'balanced_accuracy': 0.8782260155374555, 'f1': 0.8690363048850028, 'confusion_matrix': [[7855, 379], [1688, 6858]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8772640610104862, 'balanced_accuracy': 0.8787505826594635, 'f1': 0.8689233901756173, 'confusion_matrix': [[1974, 85], [430, 1707]], 'split': 'test', 'n_samples': 4196}

# %% [markdown]
# ## 9.2 — Unir historiales de entrenamiento

# %%
history_all_df = pd.concat([df.assign(n_qubits=n_qubits)for n_qubits, df in training_histories.items()], ignore_index=True)
HISTORY_PATH = os.path.join(RESULTS_DIR, "training_history_q1_to_q5.csv")
history_all_df.to_csv(HISTORY_PATH, index=False)

print("\nHistorial completo guardado en:")
print(HISTORY_PATH)
# Out:
# Historial completo guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\training_history_q1_to_q5.csv

# %% [markdown]
# ## 9.3 — Tabla final de métricas

# %%
metrics_summary_df = pd.DataFrame(list(final_metrics_rows.values()))
metrics_summary_df = metrics_summary_df.sort_values("n_qubits").reset_index(drop=True)
metrics_summary_df.to_csv(METRICS_PATH, index=False)

print("\nResumen final de métricas:")
display(metrics_summary_df)

print("\nMétricas guardadas en:")
print(METRICS_PATH)
# Out:
# Resumen final de métricas:
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         1        0.861204                 0.862911  0.849829       0.864395
# 1         2        0.873182                 0.874684  0.864441       0.873689
# 2         3        0.874315                 0.875833  0.865523       0.875119
# 3         4        0.873957                 0.875464  0.865227       0.877026
# 4         5        0.876818                 0.878226  0.869036       0.877264
#
#    test_balanced_accuracy   test_f1  \
# 0                0.866214  0.852323
# 1                0.875303  0.864103
# 2                0.876760  0.865434
# 3                0.878632  0.867760
# 4                0.878751  0.868923
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# Métricas guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\metrics_summary.csv

# %% [markdown]
# ## 9.4 — Guardar predicciones/scores por split y número de qubits

# %%
prediction_rows = []

for n_qubits in QUBITS_LIST:
    train_scores = final_scores[n_qubits]["train_scores"]
    test_scores = final_scores[n_qubits]["test_scores"]

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_train_idx_qml, y_train_qml, train_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "train",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_test_idx_qml, y_test_qml, test_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "test",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

predictions_df = pd.DataFrame(prediction_rows)
predictions_df.to_csv(PREDICTIONS_PATH, index=False)

print("\nPredicciones guardadas en:")
print(PREDICTIONS_PATH)
# Out:
# Predicciones guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\predictions.csv

# %% [markdown]
# ## 9.5 — Guardar resumen final JSON

# %%
FINAL_SUMMARY_PATH = os.path.join(RESULTS_DIR, "final_summary.json")

final_summary = {
    "experiment_name": EXPERIMENT_NAME,
    "method": METHOD,
    "fold": int(FOLD),
    "k": int(K),
    "q_list": [
        int(q)
        for q in QUBITS_LIST
    ],
    "data_path": DATA_PATH,
    "results_dir": RESULTS_DIR,
    "history_path": HISTORY_PATH,
    "metrics_path": METRICS_PATH,
    "predictions_path": PREDICTIONS_PATH,
    "checkpoints": {
        str(k): v
        for k, v in CHECKPOINT_PATHS.items()
    },
    "metrics_summary": metrics_summary_df.to_dict(orient="records"),
    "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
}

with open(FINAL_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(final_summary, f, indent=4, ensure_ascii=False)

print("\nResumen final guardado en:")
print(FINAL_SUMMARY_PATH)
# Out:
# Resumen final guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\final_summary.json

# %% [markdown]
# ## 9.6 — Seleccionar mejor modelo por test balanced accuracy

# %%
best_row = metrics_summary_df.loc[
    metrics_summary_df[
        "test_balanced_accuracy"
    ].idxmax()
]

BEST_N_QUBITS = int(
    best_row["n_qubits"]
)

BEST_CHECKPOINT_PATH = CHECKPOINT_PATHS[
    BEST_N_QUBITS
]

print("\nMejor modelo:")
print("Qubits:", BEST_N_QUBITS)
print("Test bAcc:", best_row["test_balanced_accuracy"])
print("Checkpoint:", BEST_CHECKPOINT_PATH)

print("\nSección 9 lista.")
print("Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.")
# Out:
# Mejor modelo:
# Qubits: 5
# Test bAcc: 0.8787505826594635
# Checkpoint: C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_5q.pt
#
# Sección 9 lista.
# Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.

# %% [markdown]
# # **10**

# %% [markdown]
# ## 10.1 — Imports para visualización

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    ConfusionMatrixDisplay,
    confusion_matrix
)

# %% [markdown]
# ## 10.2 — Cargar historial completo

# %%
history_df = pd.read_csv(HISTORY_PATH)

print("Historial cargado:")
print(history_df.shape)

display(history_df.head())
# Out:
# Historial cargado:
# (260, 9)
#    n_qubits  epoch      loss  train_accuracy  train_balanced_accuracy  \
# 0         1      1  0.671302        0.809833                 0.811620
# 1         1      2  0.517026        0.833373                 0.834422
# 2         1      3  0.468958        0.842253                 0.843452
# 3         1      4  0.458714        0.842014                 0.843180
# 4         1      5  0.456164        0.839928                 0.840529
#
#    train_f1  test_accuracy  test_balanced_accuracy   test_f1
# 0  0.793074       0.810057                0.811990  0.791525
# 1  0.826271       0.829838                0.830967  0.821767
# 2  0.834158       0.840801                0.842120  0.831483
# 3  0.834219       0.842707                0.843982  0.833920
# 4  0.837212       0.842231                0.842938  0.838615

# %% [markdown]
# ## 10.3 — Curvas de Loss

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["loss"], label=f"Q{q}" )

plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.4 — Curvas de Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]

    plt.plot(subset["epoch"], subset["test_accuracy"], label=f"Q{q}")

plt.title("Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.5 — Curvas de Balanced Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(
    history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_balanced_accuracy"], label=f"Q{q}")

plt.title("Test Balanced Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Balanced Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.6 — Curvas de F1

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_f1"], label=f"Q{q}")

plt.title("Test F1")
plt.xlabel("Epoch")
plt.ylabel("F1")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.7 — Ranking final

# %%
metrics_summary_df = pd.read_csv(METRICS_PATH)

ranking_df = metrics_summary_df.sort_values(
    "test_balanced_accuracy",
    ascending=False
).reset_index(
    drop=True
)

print("\nRanking final")

display(ranking_df)
# Out:
# Ranking final
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         5        0.876818                 0.878226  0.869036       0.877264
# 1         4        0.873957                 0.875464  0.865227       0.877026
# 2         3        0.874315                 0.875833  0.865523       0.875119
# 3         2        0.873182                 0.874684  0.864441       0.873689
# 4         1        0.861204                 0.862911  0.849829       0.864395
#
#    test_balanced_accuracy   test_f1  \
# 0                0.878751  0.868923
# 1                0.878632  0.867760
# 2                0.876760  0.865434
# 3                0.875303  0.864103
# 4                0.866214  0.852323
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...

# %% [markdown]
# ## 10.8 — Comparación visual Q1–Q5

# %%
plt.figure(figsize=(10, 5))
x = np.arange(len(ranking_df))
width = 0.25
plt.bar(x - width, ranking_df["test_accuracy"], width=width, label="Accuracy")
plt.bar(x, ranking_df["test_balanced_accuracy"], width=width, label="Balanced Accuracy")
plt.bar(x + width, ranking_df["test_f1"], width=width, label="F1")
plt.xticks(x, [f"Q{q}" for q in ranking_df["n_qubits"]])
plt.ylabel("Score")
plt.title("Comparación Final Q1–Q5")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.9 — Matriz de confusión del mejor modelo

# %%
best_q = int(ranking_df.iloc[0]["n_qubits"])
print("\nMejor modelo: Q", best_q)
best_predictions = predictions_df[(predictions_df["n_qubits"] == best_q) & (predictions_df["split"] == "test")]

cm = confusion_matrix(best_predictions["y_true"], best_predictions["y_pred_05"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title(f"Confusion Matrix - Q{best_q}")
plt.show()
# Out:
# Mejor modelo: Q 5

# %% [markdown]
# ## 10.10 — Resumen final

# %%
best_row = ranking_df.iloc[0]
print("\n" + "=" * 80)
print("MEJOR MODELO")
print("=" * 80)
print("Qubits:", int(best_row["n_qubits"]))
print("Test Accuracy:",  round(best_row["test_accuracy"], 6))
print("Test Balanced Accuracy:", round(best_row["test_balanced_accuracy"], 6))
print("Test F1:", round(best_row["test_f1"], 6))
print("\nCheckpoint:")
print(CHECKPOINT_PATHS[int(best_row["n_qubits"])])
print("\nNotebook finalizado.")
# Out:
# ================================================================================
# MEJOR MODELO
# ================================================================================
# Qubits: 5
# Test Accuracy: 0.877264
# Test Balanced Accuracy: 0.878751
# Test F1: 0.868923
#
# Checkpoint:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_linear_z3_fold0\best_dr_qnn_5q.pt
#
# Notebook finalizado.
