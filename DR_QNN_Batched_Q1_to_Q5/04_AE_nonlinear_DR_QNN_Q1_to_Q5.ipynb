# %% [markdown]
# # **1**

# %%
import os
import json
import random
from datetime import datetime

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ## 1.1 — Carpetas base

# %%
BASE_DATA_DIR = r"C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold"

BASE_RESULTS_DIR = r"C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched"

os.makedirs(BASE_RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.2 — Selección del experimento

# %% [markdown]
# Métodos disponibles:
# - "PCA"
# - "ICA"
# - "AE_linear"
# - "AE_nonlinear"

# %%
METHOD = "AE_nonlinear"
FOLD = 0
K = 3

METHOD_FILES = {
    "PCA": "PCA_z1_to_z15_stratified5.npz",
    "ICA": "ICA_z1_to_z15_stratified5.npz",
    "AE_linear": "AE_linear_z1_to_z15_stratified5.npz",
    "AE_nonlinear": "AE_nonlinear_z1_to_z15_stratified5.npz",
}

assert METHOD in METHOD_FILES, (f"METHOD inválido: {METHOD}. " f"Usa {list(METHOD_FILES.keys())}")
assert FOLD in [0, 1, 2, 3, 4], ("FOLD debe ser 0, 1, 2, 3 o 4")
assert K in [1, 2, 3], ("Para esta DR-QNN, K debe ser 1, 2 o 3")

DATA_PATH = os.path.join(BASE_DATA_DIR, METHOD_FILES[METHOD])

assert os.path.exists(DATA_PATH), (f"No existe el archivo: {DATA_PATH}")

# %% [markdown]
# ## 1.3 — Nombre del experimento

# %%
EXPERIMENT_NAME = (f"DR_QNN_BATCHED_{METHOD}_z{K}_fold{FOLD}")
RESULTS_DIR = os.path.join(BASE_RESULTS_DIR, EXPERIMENT_NAME)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.4 — Configuración del dataset

# %%
USE_SUBSET = False
N_TRAIN_QML = 200
N_TEST_QML = 120
SUBSET_RANDOM_STATE = 123

# %% [markdown]
# ## 1.5 — Configuración DR-QNN

# %%
N_LAYERS = 6
QUBITS_LIST = [1, 2, 3, 4, 5]
assert QUBITS_LIST == [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1.6 — Configuración de rapidez tipo MS-HQCNN

# %%
USE_VECTORIZED_QNODE = True

# Mini-batches de entrenamiento.
BATCH_SIZE = 32

# Tamaño de bloque utilizado únicamente para evaluación/inferencia.
CHUNK_SAMPLES = 131072

assert BATCH_SIZE > 0
assert CHUNK_SAMPLES > 0

# %% [markdown]
# ## 1.7 — Entrenamiento

# %%
EPOCHS_1Q = 60
EPOCHS_NQ = 50

# Learning rate de la DR-QNN de un qubit.
LR_1Q = 0.006

# Al expandir el modelo, se utiliza una tasa menor para no destruir
# los parámetros heredados del modelo anterior.
LR_NQ = 0.003

# %% [markdown]
# ## 1.8 — Backend cuántico

# %%
QML_DEVICE_NAME = "default.qubit"
SHOTS = None
assert QML_DEVICE_NAME in ["default.qubit"]

# %% [markdown]
# ## 1.9 — Reproducibilidad

# %%
GLOBAL_SEED = 42

def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_global_seed(GLOBAL_SEED)

# %% [markdown]
# ## 1.10 — Dispositivo PyTorch

# %%
TORCH_DEVICE = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(TORCH_DEVICE)
# Out:
# cuda

# %% [markdown]
# ## 1.11 — Rutas de guardado

# %%
CONFIG_PATH = os.path.join(RESULTS_DIR, "config.json")
LOAD_SUMMARY_PATH = os.path.join(RESULTS_DIR, "load_summary.json")
METRICS_PATH = os.path.join(RESULTS_DIR, "metrics_summary.csv")
PREDICTIONS_PATH = os.path.join(RESULTS_DIR, "predictions.csv")
CHECKPOINT_1Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_1q.pt")
CHECKPOINT_2Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_2q.pt")
CHECKPOINT_3Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_3q.pt")
CHECKPOINT_4Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_4q.pt")
CHECKPOINT_5Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_5q.pt")

# %% [markdown]
# ## 1.12 — Guardar configuración

# %%
CONFIG = {"experiment_name": EXPERIMENT_NAME, "method": METHOD, "fold": FOLD, "k": K, "data_path": DATA_PATH, "results_dir": RESULTS_DIR, "use_subset": USE_SUBSET, "n_train_qml": N_TRAIN_QML, "n_test_qml": N_TEST_QML, "subset_random_state": SUBSET_RANDOM_STATE, "n_layers": N_LAYERS, "qubits_list": QUBITS_LIST, "use_vectorized_qnode": USE_VECTORIZED_QNODE, "batch_size": BATCH_SIZE, "chunk_samples": CHUNK_SAMPLES, "epochs_1q": EPOCHS_1Q, "epochs_nq": EPOCHS_NQ, "lr_1q": LR_1Q, "lr_nq": LR_NQ, "qml_device_name": QML_DEVICE_NAME, "shots": SHOTS, "global_seed": GLOBAL_SEED, "torch_device": TORCH_DEVICE, "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),}

with open(CONFIG_PATH, "w", encoding="utf-8") as f:
    json.dump(CONFIG, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## 1.13 — Resumen

# %%
print("=" * 80)
print("CONFIGURACIÓN DEL EXPERIMENTO")
print("=" * 80)
print("METHOD:", METHOD)
print("FOLD:", FOLD)
print("K:", K)
print("\nDATA_PATH:")
print(DATA_PATH)
print("\nRESULTS_DIR:")
print(RESULTS_DIR)
print("\nQUBITS_LIST:", QUBITS_LIST)
print("N_LAYERS:", N_LAYERS)
print("USE_VECTORIZED_QNODE:", USE_VECTORIZED_QNODE)
print("CHUNK_SAMPLES:", CHUNK_SAMPLES)
print("BATCH_SIZE:", BATCH_SIZE)
print("QML_DEVICE_NAME:", QML_DEVICE_NAME)
print("TORCH_DEVICE:", TORCH_DEVICE)
print("\nCONFIG_PATH:")
print(CONFIG_PATH)
# Out:
# ================================================================================
# CONFIGURACIÓN DEL EXPERIMENTO
# ================================================================================
# METHOD: AE_nonlinear
# FOLD: 0
# K: 3
#
# DATA_PATH:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\AE_nonlinear_z1_to_z15_stratified5.npz
#
# RESULTS_DIR:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0
#
# QUBITS_LIST: [1, 2, 3, 4, 5]
# N_LAYERS: 6
# USE_VECTORIZED_QNODE: True
# CHUNK_SAMPLES: 131072
# BATCH_SIZE: 32
# QML_DEVICE_NAME: default.qubit
# TORCH_DEVICE: cuda
#
# CONFIG_PATH:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\config.json

# %% [markdown]
# # **2**

# %% [markdown]
# ## 2.1 — Cargar archivo .npz

# %%
print("=" * 80)
print("CARGANDO DATASET")
print("=" * 80)

data = np.load(DATA_PATH, allow_pickle=True)

print("Archivo:")
print(DATA_PATH)

print("\nTotal de keys:", len(data.files))

print("\nPrimeras 20 keys:")
for key in data.files[:20]:
    print(key)
# Out:
# ================================================================================
# CARGANDO DATASET
# ================================================================================
# Archivo:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\AE_nonlinear_z1_to_z15_stratified5.npz
#
# Total de keys: 341
#
# Primeras 20 keys:
# metadata
# fold0_train_idx
# fold0_test_idx
# fold0_y_train
# fold0_y_test
# fold0_z64_train
# fold0_z64_test
# fold0_scaler_mean
# fold0_scaler_scale
# fold0_z1_train
# fold0_z1_test
# fold0_z1_loss_history
# fold0_z1_best_reconstruction_loss
# fold0_z2_train
# fold0_z2_test
# fold0_z2_loss_history
# fold0_z2_best_reconstruction_loss
# fold0_z3_train
# fold0_z3_test
# fold0_z3_loss_history

# %% [markdown]
# ## 2.2 — Leer metadata

# %%
if "metadata" in data.files:
    metadata = json.loads(str(data["metadata"].item()))
    print("\nMetadata:")
    for key, value in metadata.items():
        print(f"{key:30s}: {value}")

else:
    metadata = {}
    print("\nNo se encontró key 'metadata'.")
# Out:
# Metadata:
# method                        : AE_nonlinear
# source_file                   : /content/drive/MyDrive/BCAM/distr_sol_pv_segm_embeddings_v2.npz
# x_key                         : features
# y_key                         : label
# original_dim                  : 64
# n_samples                     : 20976
# max_components                : 15
# n_splits                      : 5
# stratified                    : True
# random_state                  : 42
# created_time                  : 2026-06-22 12:03:41
# note                          : Transforms are fitted only on train data inside each fold. Test data is never used to fit scaler/PCA/ICA/AE.

# %% [markdown]
# ## 2.3 — Cargar fold y dimensión K con keys fijas

# %%
X_train = data[f"fold{FOLD}_z{K}_train"].astype(np.float32)
X_test = data[f"fold{FOLD}_z{K}_test"].astype(np.float32)
y_train = data[f"fold{FOLD}_y_train"].astype(int)
y_test = data[f"fold{FOLD}_y_test"].astype(int)

train_idx = data[f"fold{FOLD}_train_idx"]
test_idx = data[f"fold{FOLD}_test_idx"]

print("\nFold seleccionado:", FOLD)
print("Dimensión seleccionada K:", K)

print("\nShapes originales")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
print("train_idx:", train_idx.shape)
print("test_idx :", test_idx.shape)
# Out:
# Fold seleccionado: 0
# Dimensión seleccionada K: 3
#
# Shapes originales
# X_train: (16780, 3)
# X_test : (4196, 3)
# y_train: (16780,)
# y_test : (4196,)
# train_idx: (16780,)
# test_idx : (4196,)

# %% [markdown]
# ## 2.4 — Distribución de clases

# %%
print("\nDistribución TRAIN")
classes_train, counts_train = np.unique(y_train, return_counts=True)
for c, n in zip(classes_train, counts_train):
    print(f"Clase {c}: {n}")

print("\nDistribución TEST")
classes_test, counts_test = np.unique(y_test, return_counts=True)
for c, n in zip(classes_test, counts_test):
    print(f"Clase {c}: {n}")
# Out:
# Distribución TRAIN
# Clase 0: 8234
# Clase 1: 8546
#
# Distribución TEST
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 2.5 — Validaciones de consistencia

# %%
assert len(X_train) == len(y_train), ("X_train e y_train no tienen la misma longitud")
assert len(X_test) == len(y_test), ("X_test e y_test no tienen la misma longitud")
assert X_train.ndim == 2, ("X_train debe ser matriz 2D")
assert X_test.ndim == 2, ("X_test debe ser matriz 2D")
assert X_train.shape[1] == K, (f"X_train debería tener {K} columnas")
assert X_test.shape[1] == K, (f"X_test debería tener {K} columnas")
assert set(np.unique(y_train)).issubset({0, 1}), ("y_train debe contener clases 0/1")
assert set(np.unique(y_test)).issubset({0, 1}), ("y_test debe contener clases 0/1")
assert len(train_idx) == len(y_train), ("train_idx e y_train no tienen la misma longitud")
assert len(test_idx) == len(y_test), ("test_idx e y_test no tienen la misma longitud")

print("\nConsistencia OK")
# Out:
# Consistencia OK

# %% [markdown]
# ## 2.6 — Rangos de features originales

# %%
print("\nRangos TRAIN")
for i in range(K):
    col = X_train[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST")
for i in range(K):
    col = X_test[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN
# Feature 0: min=-7.971827 | max=6.371310 | mean=-0.006927 | std=1.087336
# Feature 1: min=-9.573823 | max=8.343680 | mean=-0.095947 | std=1.252491
# Feature 2: min=-8.951857 | max=14.198944 | mean=-0.189190 | std=1.518562
#
# Rangos TEST
# Feature 0: min=-5.811029 | max=4.503274 | mean=-0.009252 | std=1.053496
# Feature 1: min=-7.721230 | max=7.039442 | mean=-0.116966 | std=1.220889
# Feature 2: min=-6.312320 | max=12.347651 | mean=-0.203407 | std=1.475979

# %% [markdown]
# ## 2.7 — Guardar resumen inicial de carga

# %%
initial_load_summary = {"method": METHOD, "fold": int(FOLD), "k": int(K), "data_path": DATA_PATH, "keys_count": len(data.files), "metadata": metadata, "x_train_shape": list(X_train.shape), "x_test_shape": list(X_test.shape), "y_train_shape": list(y_train.shape), "y_test_shape": list(y_test.shape), "train_idx_shape": list(train_idx.shape), "test_idx_shape": list(test_idx.shape), "train_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_train, counts_train)},
    "test_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_test, counts_test)},}

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen inicial de carga guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen inicial de carga guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\load_summary.json

# %% [markdown]
# # **3**

# %% [markdown]
# ## 3.1 — Adaptación a qml.Rot(phi, theta, omega)

# %% [markdown]
# qml.Rot(phi, theta, omega) requiere 3 entradas:
# - K = 3: se deja igual
# - K = 2: agrega una columna de ceros
# - K = 1: agrega dos columnas de cerosm

# %%
def adapt_to_rot_dimension(X):

    X = np.asarray(X ,dtype=np.float32)
    if X.ndim != 2:
        raise ValueError(f"X debe ser matriz 2D, llegó {X.shape}")
    if X.shape[1] == 3:
        return X.astype(np.float32)
    if X.shape[1] == 2:
        zeros = np.zeros((len(X), 1), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    if X.shape[1] == 1:
        zeros = np.zeros((len(X), 2), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    raise ValueError(f"Dimensión no soportada: {X.shape[1]}")

# %% [markdown]
# ## 3.2 — Adaptar TRAIN y TEST

# %%
# ============================================================
# Adaptación a tres ángulos + escalado angular
# ============================================================

X_train_rot_raw = adapt_to_rot_dimension(X_train)
X_test_rot_raw = adapt_to_rot_dimension(X_test)

# El escalador se ajusta exclusivamente con TRAIN.
# TEST solamente se transforma con los parámetros aprendidos en TRAIN.
ANGLE_MIN = -np.pi / 2
ANGLE_MAX = np.pi / 2

angle_scaler = MinMaxScaler(
    feature_range=(ANGLE_MIN, ANGLE_MAX)
)

X_train_rot = angle_scaler.fit_transform(
    X_train_rot_raw
).astype(np.float32)

X_test_rot = angle_scaler.transform(
    X_test_rot_raw
).astype(np.float32)

# Protección ante valores de TEST fuera del rango observado en TRAIN.
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

print("\nShapes adaptadas para qml.Rot")
print("X_train_rot:", X_train_rot.shape)
print("X_test_rot :", X_test_rot.shape)

print("\nIntervalo angular aplicado:")
print(f"[{ANGLE_MIN:.6f}, {ANGLE_MAX:.6f}]")

print("\nRangos finales TRAIN")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos finales TEST")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Shapes adaptadas para qml.Rot
# X_train_rot: (16780, 3)
# X_test_rot : (4196, 3)
#
# Intervalo angular aplicado:
# [-1.570796, 1.570796]
#
# Rangos finales TRAIN
#    phi: min=-1.570796 | max=1.570796 | mean=0.173764 | std=0.238160
#  theta: min=-1.570796 | max=1.570796 | mean=0.091021 | std=0.219607
#  omega: min=-1.570796 | max=1.570796 | mean=-0.381691 | std=0.206071
#
# Rangos finales TEST
#    phi: min=-1.097515 | max=1.161639 | mean=0.173255 | std=0.230748
#  theta: min=-1.245969 | max=1.342116 | mean=0.087336 | std=0.214066
#  omega: min=-1.212608 | max=1.319574 | mean=-0.383621 | std=0.200292

# %% [markdown]
# ## 3.3 — Validaciones

# %%
assert X_train_rot.ndim == 2
assert X_test_rot.ndim == 2

assert X_train_rot.shape[1] == 3
assert X_test_rot.shape[1] == 3

print("\nAdaptación K → 3 correcta")
# Out:
# Adaptación K → 3 correcta

# %% [markdown]
# ## 3.4 — Verificar padding

# %%
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

# Restaurar explícitamente el padding usado por qml.Rot.
if K == 1:
    X_train_rot[:, 1:] = 0.0
    X_test_rot[:, 1:] = 0.0

elif K == 2:
    X_train_rot[:, 2] = 0.0
    X_test_rot[:, 2] = 0.0

# %% [markdown]
# ## 3.5 — Vista rápida

# %%
preview_df = pd.DataFrame(X_train_rot[:10], columns=["phi", "theta", "omega"])
preview_df["label"] = y_train[:10]
display(preview_df)
# Out:
#         phi     theta     omega  label
# 0  0.296917 -0.070397 -0.443914      0
# 1  0.636097  0.564165  0.089968      1
# 2  0.292327  0.265123 -0.339397      1
# 3  0.101969  0.324980 -0.160360      1
# 4  0.267408  0.061006 -0.448086      1
# 5  0.200495 -0.082203 -0.484426      0
# 6 -0.124601  0.182584 -0.752875      0
# 7  0.294677  0.214936 -0.372512      1
# 8  0.368073 -0.013887 -0.429780      0
# 9  0.216704  0.100389 -0.596723      0

# %% [markdown]
# ## 3.6 — Estadísticas después de la adaptación

# %%
print("\nRangos TRAIN adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN adaptado
#    phi: min=-1.570796 | max=1.570796 | mean=0.173764 | std=0.238160
#  theta: min=-1.570796 | max=1.570796 | mean=0.091021 | std=0.219607
#  omega: min=-1.570796 | max=1.570796 | mean=-0.381691 | std=0.206071
#
# Rangos TEST adaptado
#    phi: min=-1.097515 | max=1.161639 | mean=0.173255 | std=0.230748
#  theta: min=-1.245969 | max=1.342116 | mean=0.087336 | std=0.214066
#  omega: min=-1.212608 | max=1.319574 | mean=-0.383621 | std=0.200292

# %% [markdown]
# ## 3.7 — Resumen

# %%
print("\nResumen adaptación")
print("K original:" ,K)
print("Dimensión final para DR-QNN:", X_train_rot.shape[1])
print("TRAIN:", X_train_rot.shape)
print("TEST :", X_test_rot.shape)
# Out:
# Resumen adaptación
# K original: 3
# Dimensión final para DR-QNN: 3
# TRAIN: (16780, 3)
# TEST : (4196, 3)

# %% [markdown]
# # **4**

# %% [markdown]
# ## 4.1 — Construir dataset que verá la DR-QNN

# %%
if USE_SUBSET:
    train_positions = np.arange(len(X_train_rot))
    test_positions = np.arange(len(X_test_rot))

    train_subset, _ = train_test_split(train_positions, train_size=N_TRAIN_QML, stratify=y_train, random_state=SUBSET_RANDOM_STATE)
    test_subset, _ = train_test_split(test_positions, train_size=N_TEST_QML, stratify=y_test, random_state=SUBSET_RANDOM_STATE)

    X_train_qml = X_train_rot[train_subset].copy()
    y_train_qml = y_train[train_subset].copy()

    X_test_qml = X_test_rot[test_subset].copy()
    y_test_qml = y_test[test_subset].copy()

    original_train_idx_qml = train_idx[train_subset].copy()
    original_test_idx_qml = test_idx[test_subset].copy()

else:
    X_train_qml = X_train_rot.copy()
    y_train_qml = y_train.copy()

    X_test_qml = X_test_rot.copy()
    y_test_qml = y_test.copy()

    original_train_idx_qml = train_idx.copy()
    original_test_idx_qml = test_idx.copy()

# %% [markdown]
# ## 4.2 — Validaciones del dataset QML

# %%
assert X_train_qml.ndim == 2
assert X_test_qml.ndim == 2

assert X_train_qml.shape[1] == 3
assert X_test_qml.shape[1] == 3

assert len(X_train_qml) == len(y_train_qml)
assert len(X_test_qml) == len(y_test_qml)

assert len(original_train_idx_qml) == len(y_train_qml)
assert len(original_test_idx_qml) == len(y_test_qml)

assert set(np.unique(y_train_qml)).issubset(
    {0, 1}
)

assert set(np.unique(y_test_qml)).issubset(
    {0, 1}
)

# %% [markdown]
# ## 4.3 — Resumen del dataset final

# %%
print("\nDataset que verá la DR-QNN")
print("X_train_qml:", X_train_qml.shape)
print("X_test_qml :", X_test_qml.shape)
print("\ny_train_qml:", y_train_qml.shape)
print("y_test_qml :", y_test_qml.shape)
print("\nÍndices originales:")
print("original_train_idx_qml:", original_train_idx_qml.shape)
print("original_test_idx_qml :", original_test_idx_qml.shape)

print("\nClases TRAIN QML:")
classes_train_qml, counts_train_qml = np.unique(y_train_qml, return_counts=True)
for c, n in zip(classes_train_qml, counts_train_qml):
    print(f"Clase {c}: {n}")

print("\nClases TEST QML:")
classes_test_qml, counts_test_qml = np.unique(y_test_qml, return_counts=True)
for c, n in zip(classes_test_qml, counts_test_qml):
    print(f"Clase {c}: {n}")
# Out:
# Dataset que verá la DR-QNN
# X_train_qml: (16780, 3)
# X_test_qml : (4196, 3)
#
# y_train_qml: (16780,)
# y_test_qml : (4196,)
#
# Índices originales:
# original_train_idx_qml: (16780,)
# original_test_idx_qml : (4196,)
#
# Clases TRAIN QML:
# Clase 0: 8234
# Clase 1: 8546
#
# Clases TEST QML:
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 4.4 — Definir tamaño de batch/chunk para entrenamiento

# %%
if BATCH_SIZE is None:
    TRAIN_BATCH_SIZE = len(X_train_qml)
    FULL_BATCH_TRAINING = True

else:
    TRAIN_BATCH_SIZE = BATCH_SIZE
    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE = CHUNK_SAMPLES

assert TRAIN_BATCH_SIZE > 0
assert EVAL_CHUNK_SIZE > 0

print("\nConfiguración de batches")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE:", TRAIN_BATCH_SIZE)
print("EVAL_CHUNK_SIZE :", EVAL_CHUNK_SIZE)
# Out:
# Configuración de batches
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE: 32
# EVAL_CHUNK_SIZE : 131072

# %% [markdown]
# ## 4.5 — Función para generar batches de índices

# %%
def make_batch_indices(n_samples, batch_size, shuffle=True, seed=None):

    indices = np.arange(n_samples)

    if shuffle:
        rng = np.random.default_rng(seed)
        rng.shuffle(indices)
    batches = []

    for start in range(0,n_samples,batch_size):
        end = min(start + batch_size,n_samples)
        batches.append(indices[start:end])

    return batches

# %% [markdown]
# ## 4.6 — Sanity check de batches de entrenamiento

# %%
train_batches_preview = make_batch_indices(n_samples=len(X_train_qml) ,batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED)

print("\nNúmero de batches TRAIN por época:")
print(len(train_batches_preview))

print("\nPrimeros tamaños de batch:")

for b in train_batches_preview[:5]:
    print(len(b))

assert sum(len(b) for b in train_batches_preview) == len(X_train_qml)
# Out:
# Número de batches TRAIN por época:
# 525
#
# Primeros tamaños de batch:
# 32
# 32
# 32
# 32
# 32

# %% [markdown]
# ## 4.7 — Función para iterar arrays NumPy por batches

# %%
def iter_numpy_batches(X, y=None, batch_size=1024, shuffle=False, seed=None):
    batches = make_batch_indices(n_samples=len(X), batch_size=batch_size, shuffle=shuffle, seed=seed)
    for batch_idx in batches:
        if y is None:
            yield X[batch_idx]
        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 4.8 — Sanity check de iterador NumPy

# %%
first_batch = next(iter_numpy_batches(X_train_qml, y_train_qml, batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED))
first_X_batch, first_y_batch = first_batch

print("\nPrimer batch NumPy")
print("X:", first_X_batch.shape)
print("y:", first_y_batch.shape)

assert first_X_batch.ndim == 2
assert first_X_batch.shape[1] == 3
assert len(first_X_batch) == len(first_y_batch)
# Out:
# Primer batch NumPy
# X: (32, 3)
# y: (32,)

# %% [markdown]
# ## 4.9 — Guardar resumen actualizado

# %%
initial_load_summary.update({
        "x_train_qml_shape": list(X_train_qml.shape),
        "x_test_qml_shape": list(X_test_qml.shape),
        "y_train_qml_shape": list(y_train_qml.shape),
        "y_test_qml_shape": list(y_test_qml.shape),
        "original_train_idx_qml_shape": list(original_train_idx_qml.shape),
        "original_test_idx_qml_shape": list(original_test_idx_qml.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size": int(TRAIN_BATCH_SIZE),
        "eval_chunk_size": int(EVAL_CHUNK_SIZE),
        "train_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_train_qml,counts_train_qml)},
        "test_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_test_qml,counts_test_qml)},
    })

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\load_summary.json

# %% [markdown]
# # **5**

# %% [markdown]
# ## 5.1 — Dispositivo y tensorización

# %%
DEVICE = torch.device(TORCH_DEVICE)

X_train_t = torch.tensor(X_train_qml, dtype=torch.float32, device=DEVICE)
X_test_t = torch.tensor(X_test_qml, dtype=torch.float32, device=DEVICE)

y_train_t = torch.tensor(y_train_qml, dtype=torch.long, device=DEVICE)
y_test_t = torch.tensor(y_test_qml, dtype=torch.long, device=DEVICE)

y_train_float_t = y_train_t.float()
y_test_float_t = y_test_t.float()

print("DEVICE:", DEVICE)

print("\nTensores en memoria:")
print("X_train_t:", X_train_t.shape, X_train_t.dtype, X_train_t.device)
print("X_test_t :", X_test_t.shape, X_test_t.dtype, X_test_t.device)
print("y_train_t:", y_train_t.shape, y_train_t.dtype, y_train_t.device)
print("y_test_t :", y_test_t.shape, y_test_t.dtype, y_test_t.device)
# Out:
# DEVICE: cuda
#
# Tensores en memoria:
# X_train_t: torch.Size([16780, 3]) torch.float32 cuda:0
# X_test_t : torch.Size([4196, 3]) torch.float32 cuda:0
# y_train_t: torch.Size([16780]) torch.int64 cuda:0
# y_test_t : torch.Size([4196]) torch.int64 cuda:0

# %% [markdown]
# ## 5.2 — Validaciones para QNode batched

# %%
assert X_train_t.ndim == 2
assert X_test_t.ndim == 2

assert X_train_t.shape[1] == 3
assert X_test_t.shape[1] == 3

assert len(X_train_t) == len(y_train_t)
assert len(X_test_t) == len(y_test_t)

assert set(
    y_train_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

assert set(
    y_test_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

print("\nValidaciones tensoriales OK")
print("Entrada esperada por QNode batched: (B, 3)")
# Out:
# Validaciones tensoriales OK
# Entrada esperada por QNode batched: (B, 3)

# %% [markdown]
# ## 5.3 — Función de batches tensoriales

# %%
def make_tensor_batches(X, y=None, batch_size=None, shuffle=True, seed=None):
    n_samples = X.shape[0]
    
    if batch_size is None:
        batch_size = n_samples
    indices = torch.arange(n_samples, device=X.device)

    if shuffle:
        generator = torch.Generator(device=X.device)

        if seed is not None:
            generator.manual_seed(int(seed))

        indices = indices[torch.randperm(n_samples, generator=generator, device=X.device)]

    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        batch_idx = indices[start:end]

        if y is None:
            yield X[batch_idx]

        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 5.4 — Batch size efectivo para entrenamiento

# %%
if BATCH_SIZE is None:

    TRAIN_BATCH_SIZE_TORCH = len(X_train_t)

    FULL_BATCH_TRAINING = True

else:

    TRAIN_BATCH_SIZE_TORCH = int(BATCH_SIZE)

    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE_TORCH = int(
    CHUNK_SAMPLES
)

assert TRAIN_BATCH_SIZE_TORCH > 0
assert EVAL_CHUNK_SIZE_TORCH > 0

print("\nConfiguración batched final:")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)
print("EVAL_CHUNK_SIZE_TORCH :", EVAL_CHUNK_SIZE_TORCH)
# Out:
# Configuración batched final:
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE_TORCH: 32
# EVAL_CHUNK_SIZE_TORCH : 131072

# %% [markdown]
# ## 5.5 — Sanity check del batch de entrenamiento

# %%
first_X_t, first_y_t = next(make_tensor_batches(X_train_t, y_train_float_t, batch_size=TRAIN_BATCH_SIZE_TORCH, shuffle=True, seed=GLOBAL_SEED))

print("\nPrimer batch Torch:")
print("X:", first_X_t.shape, first_X_t.dtype, first_X_t.device)
print("y:", first_y_t.shape, first_y_t.dtype, first_y_t.device)

assert first_X_t.ndim == 2
assert first_X_t.shape[1] == 3
assert len(first_X_t) == len(first_y_t)
# Out:
# Primer batch Torch:
# X: torch.Size([32, 3]) torch.float32 cuda:0
# y: torch.Size([32]) torch.float32 cuda:0

# %% [markdown]
# ## 5.6 — Sanity check de chunks de evaluación

# %%
first_eval_chunk = next(make_tensor_batches(X_test_t, y_test_float_t, batch_size=EVAL_CHUNK_SIZE_TORCH, shuffle=False, seed=None))
first_X_eval_t, first_y_eval_t = first_eval_chunk

print("\nPrimer chunk de evaluación:")
print("X:", first_X_eval_t.shape, first_X_eval_t.dtype, first_X_eval_t.device)
print("y:", first_y_eval_t.shape, first_y_eval_t.dtype, first_y_eval_t.device)

assert first_X_eval_t.ndim == 2
assert first_X_eval_t.shape[1] == 3
# Out:
# Primer chunk de evaluación:
# X: torch.Size([4196, 3]) torch.float32 cuda:0
# y: torch.Size([4196]) torch.float32 cuda:0

# %% [markdown]
# ## 5.7 — Resumen actualizado

# %%
initial_load_summary.update(
    {
        "torch_device": str(DEVICE),
        "x_train_t_shape": list(X_train_t.shape),
        "x_test_t_shape": list(X_test_t.shape),
        "y_train_t_shape": list(y_train_t.shape),
        "y_test_t_shape": list(y_test_t.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size_torch": int(TRAIN_BATCH_SIZE_TORCH),
        "eval_chunk_size_torch": int(EVAL_CHUNK_SIZE_TORCH),
        "qnode_expected_input_shape": "(B, 3)",
        "batched_qnode_required": bool(USE_VECTORIZED_QNODE),
    }
)

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nSección 5 lista.")
print("Los datos ya están en tensores y preparados para QNode batched.")
print("Resumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Sección 5 lista.
# Los datos ya están en tensores y preparados para QNode batched.
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\load_summary.json

# %% [markdown]
# # **6**

# %% [markdown]
# ## 6.1 — Crear dispositivos cuánticos

# %%
def make_qml_device(n_qubits):

    if QML_DEVICE_NAME == "default.qubit":
        return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

    return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

qml_devices = {}

for n_qubits in QUBITS_LIST:
    qml_devices[n_qubits] = make_qml_device(n_qubits)
print("Dispositivos creados:")

for n_qubits, dev in qml_devices.items():
    print(f"{n_qubits}Q:", dev)
# Out:
# Dispositivos creados:
# 1Q: <default.qubit device (wires=1) at 0x1ccf7b3c050>
# 2Q: <default.qubit device (wires=2) at 0x1ccf7963350>
# 3Q: <default.qubit device (wires=3) at 0x1ccf7bd3910>
# 4Q: <default.qubit device (wires=4) at 0x1ccf7bab990>
# 5Q: <default.qubit device (wires=5) at 0x1ccf7bd3d90>

# %% [markdown]
# ## 6.2 — Bloques cuánticos básicos

# %%
def encode_data_reuploading_layer(X_batch, n_qubits):
    for q in range(n_qubits):
        qml.Rot(X_batch[:, 0], X_batch[:, 1], X_batch[:, 2], wires=q)


def apply_single_qubit_trainable_layer(theta_layer, n_qubits):
    for q in range(n_qubits):
        qml.Rot(theta_layer[q, 0], theta_layer[q, 1], theta_layer[q, 2], wires=q)


def apply_entangling_layer(phi_layer, n_qubits):
    if n_qubits == 1:
        return
    for s in range(n_qubits - 1):
        qml.ctrl(qml.Rot, control=s + 1)(phi_layer[s, 0], phi_layer[s, 1], phi_layer[s, 2], wires=s)

# %% [markdown]
# ## 6.3 — Constructor de QNode batched para n qubits

# %%
def make_batched_drqnn_qnode(n_qubits):
    dev = qml_devices[n_qubits]
    @qml.qnode(dev, interface="torch", diff_method="backprop")
    
    def qnode(X_batch, theta, phi):
        for layer in range(N_LAYERS):
            encode_data_reuploading_layer(X_batch, n_qubits)
            apply_single_qubit_trainable_layer(theta[layer], n_qubits)

            if n_qubits > 1:
                apply_entangling_layer(phi[layer], n_qubits)

        return qml.probs(wires=0)

    return qnode

# %% [markdown]
# ## 6.4 — Crear QNodes Q1 → Q5

# %%
batched_qnodes = {}

for n_qubits in QUBITS_LIST:
    batched_qnodes[n_qubits] = make_batched_drqnn_qnode(n_qubits)

print("\nQNodes batched creados:")

for n_qubits in batched_qnodes:
    print(f"{n_qubits}Q listo")
# Out:
# QNodes batched creados:
# 1Q listo
# 2Q listo
# 3Q listo
# 4Q listo
# 5Q listo

# %% [markdown]
# ## 6.5 — Inicializadores auxiliares de parámetros

# %%
def make_empty_theta(n_qubits, device=DEVICE):
    theta = torch.zeros(N_LAYERS, n_qubits, 3, dtype=torch.float32, device=device)
    return theta

def make_empty_phi(n_qubits, device=DEVICE):

    if n_qubits == 1:
        phi = torch.zeros(N_LAYERS, 1, 3, dtype=torch.float32, device=device)

    else:
        phi = torch.zeros(N_LAYERS, n_qubits - 1, 3, dtype=torch.float32, device=device)

    return phi

# %% [markdown]
# ## 6.6 — Sanity check batched de todos los QNodes

# %%
SANITY_BATCH_SIZE = min(8, len(X_train_t))
X_sanity = X_train_t[:SANITY_BATCH_SIZE]

print("\nSanity batch:")
print("X_sanity:", X_sanity.shape)

qnode_sanity_outputs = {}

with torch.no_grad():
    for n_qubits in QUBITS_LIST:
        theta_sanity = make_empty_theta(n_qubits)
        phi_sanity = make_empty_phi(n_qubits)
        probs = batched_qnodes[n_qubits](X_sanity, theta_sanity, phi_sanity)
        qnode_sanity_outputs[n_qubits] = probs

        print(f"{n_qubits}Q probs:", probs.shape, probs.device, probs.dtype)

        assert probs.ndim == 2
        assert probs.shape[0] == SANITY_BATCH_SIZE
        assert probs.shape[1] == 2

        expected = torch.ones_like(probs.sum(dim=1))

        assert torch.allclose(probs.sum(dim=1), expected, atol=1e-5)

print("\nSanity check Q1-Q5 OK")
# Out:
# Sanity batch:
# X_sanity: torch.Size([8, 3])
# 1Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 2Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 3Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 4Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 5Q probs: torch.Size([8, 2]) cuda:0 torch.float32
#
# Sanity check Q1-Q5 OK

# %% [markdown]
# ## 6.7 — Convención de salida

# %%
print("\nConvención de salida DR-QNN:")
print("probs[:, 0] = fidelidad/probabilidad asociada a clase 0")
print("probs[:, 1] = score de clase 1")
print("pred = 1 si probs[:, 1] >= 0.5")

print("\nSección 6 lista.")
print("Los QNodes ya reciben batches X_batch con shape (B, 3).")
# Out:
# Convención de salida DR-QNN:
# probs[:, 0] = fidelidad/probabilidad asociada a clase 0
# probs[:, 1] = score de clase 1
# pred = 1 si probs[:, 1] >= 0.5
#
# Sección 6 lista.
# Los QNodes ya reciben batches X_batch con shape (B, 3).

# %%
probs.dtype
# Out:
# torch.float32

# %% [markdown]
# # **7**

# %% [markdown]
# ## 7.1 — Clase general DR-QNN batched

# %%
class BatchedDRQNN(nn.Module):

    def __init__(
        self,
        n_qubits,
        init_theta=None,
        init_phi=None
    ):
        super().__init__()

        assert n_qubits in QUBITS_LIST

        self.n_qubits = n_qubits

        theta_shape = (
            N_LAYERS,
            n_qubits,
            3
        )

        phi_shape = (
            N_LAYERS,
            max(n_qubits - 1, 1),
            3
        )

        # ----------------------------------------------------
        # Rotaciones locales entrenables
        # ----------------------------------------------------
        if init_theta is None:

            theta = torch.empty(
                theta_shape,
                dtype=torch.float32,
                device=DEVICE
            )

            theta.uniform_(
                -np.pi / 2,
                np.pi / 2
            )

        else:

            theta = (
                init_theta
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        # ----------------------------------------------------
        # Acoplamientos controlados
        # Se mantienen en cero para que inicialmente sean identidad.
        # ----------------------------------------------------
        if init_phi is None:

            phi = torch.zeros(
                phi_shape,
                dtype=torch.float32,
                device=DEVICE
            )

        else:

            phi = (
                init_phi
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        assert theta.shape == theta_shape
        assert phi.shape == phi_shape

        self.theta = nn.Parameter(theta)
        self.phi = nn.Parameter(phi)

        self.qnode = batched_qnodes[n_qubits]

    def forward(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        probs = probs.float()

        # Probabilidad asociada a la clase 1.
        score_class1 = probs[:, 1]

        return score_class1

    def predict_proba(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        return probs.float()

# %% [markdown]
# ## 7.2 — Funciones de transferencia Q(n) → Q(n+1)

# %%
def expand_theta_from_previous(
    previous_theta,
    new_n_qubits
):

    previous_theta = (
        previous_theta
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    old_n_qubits = previous_theta.shape[1]

    assert new_n_qubits == old_n_qubits + 1

    # Inicialización de los parámetros del modelo ampliado.
    new_theta = torch.empty(
        N_LAYERS,
        new_n_qubits,
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    new_theta.uniform_(
        -np.pi / 2,
        np.pi / 2
    )

    # Conservar exactamente los parámetros de los qubits
    # que ya fueron entrenados.
    new_theta[
        :,
        :old_n_qubits,
        :
    ] = previous_theta

    return new_theta


def expand_phi_from_previous(
    previous_phi,
    new_n_qubits
):

    previous_phi = (
        previous_phi
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    new_phi = torch.zeros(
        N_LAYERS,
        max(new_n_qubits - 1, 1),
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    if new_n_qubits > 2:

        old_phi_width = previous_phi.shape[1]

        new_phi[
            :,
            :old_phi_width,
            :
        ] = previous_phi

    return new_phi


def make_next_model_from_previous(
    previous_model,
    new_n_qubits
):

    init_theta = expand_theta_from_previous(
        previous_model.theta,
        new_n_qubits
    )

    init_phi = expand_phi_from_previous(
        previous_model.phi,
        new_n_qubits
    )

    model = BatchedDRQNN(
        n_qubits=new_n_qubits,
        init_theta=init_theta,
        init_phi=init_phi
    )

    return model


print("Funciones de expansión definidas correctamente.")
# Out:
# Funciones de expansión definidas correctamente.

# %% [markdown]
# ## 7.3 — Crear modelo inicial Q1

# %%
model_1q = BatchedDRQNN(
    n_qubits=1
)

print("Modelo Q1 creado")
print(model_1q)

print("\nParámetros Q1:")
for name, param in model_1q.named_parameters():

    print(
        name,
        tuple(param.shape),
        param.dtype,
        param.device,
        "requires_grad=",
        param.requires_grad
    )
# Out:
# Modelo Q1 creado
# BatchedDRQNN()
#
# Parámetros Q1:
# theta (6, 1, 3) torch.float32 cuda:0 requires_grad= True
# phi (6, 1, 3) torch.float32 cuda:0 requires_grad= True

# %% [markdown]
# ## 7.4 — Sanity check forward Q1

# %%
with torch.no_grad():

    q1_scores = model_1q(
        X_sanity
    )

    q1_probs = model_1q.predict_proba(
        X_sanity
    )

print("\nSanity forward Q1")
print("scores:", q1_scores.shape, q1_scores.dtype, q1_scores.device)
print("probs :", q1_probs.shape, q1_probs.dtype, q1_probs.device)

assert q1_scores.ndim == 1
assert q1_scores.shape[0] == SANITY_BATCH_SIZE
assert q1_scores.dtype == torch.float32

assert q1_probs.ndim == 2
assert q1_probs.shape == (
    SANITY_BATCH_SIZE,
    2
)
assert q1_probs.dtype == torch.float32
# Out:
# Sanity forward Q1
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.5 — Sanity check expansión Q1 → Q5

# %%
model_sanity = model_1q

sanity_models = {
    1: model_1q
}

for next_q in QUBITS_LIST[1:]:

    model_sanity = make_next_model_from_previous(
        model_sanity,
        next_q
    )

    sanity_models[next_q] = model_sanity

    with torch.no_grad():

        scores = model_sanity(
            X_sanity
        )

        probs = model_sanity.predict_proba(
            X_sanity
        )

    print(f"\nSanity modelo Q{next_q}")
    print("scores:", scores.shape, scores.dtype, scores.device)
    print("probs :", probs.shape, probs.dtype, probs.device)

    assert scores.ndim == 1
    assert scores.shape[0] == SANITY_BATCH_SIZE
    assert scores.dtype == torch.float32

    assert probs.ndim == 2
    assert probs.shape == (
        SANITY_BATCH_SIZE,
        2
    )
    assert probs.dtype == torch.float32
# Out:
# Sanity modelo Q2
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q3
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q4
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q5
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.6 — Convención final del modelo

# %%
print("\nSección 7 lista.")
print("Cada modelo recibe X_batch con shape (B, 3).")
print("Cada forward devuelve scores clase 1 con shape (B,).")
print("predict_proba devuelve probs float32 con shape (B, 2).")
print("Los QNodes devuelven float64, pero el modelo convierte a float32.")
# Out:
# Sección 7 lista.
# Cada modelo recibe X_batch con shape (B, 3).
# Cada forward devuelve scores clase 1 con shape (B,).
# predict_proba devuelve probs float32 con shape (B, 2).
# Los QNodes devuelven float64, pero el modelo convierte a float32.

# %% [markdown]
# # **8**

# %% [markdown]
# ## 8.1 — Loss de fidelidad para clasificación binaria

# %%
def fidelity_loss_from_scores(
    scores_class1,
    y_batch
):
    """
    MSE entre una salida en [-1, 1] y etiquetas {-1, +1}.

    scores_class1:
        Probabilidad P(clase=1), en [0, 1].

    Convención:
        clase 0 -> -1
        clase 1 -> +1
    """

    y_batch = y_batch.float()

    # P(clase=1) en [0,1] -> score en [-1,1].
    z_class1 = 2.0 * scores_class1 - 1.0

    # Etiquetas 0/1 -> etiquetas -1/+1.
    y_pm1 = 2.0 * y_batch - 1.0

    loss = torch.mean(
        (z_class1 - y_pm1) ** 2
    )

    return loss

# %% [markdown]
# ## 8.2 — Predicción batched sin evaluar muestra por muestra

# %%
@torch.no_grad()
def predict_scores_batched(model, X, chunk_size=131072):
    model.eval()
    scores_all = []
    for X_chunk in make_tensor_batches(X, y=None, batch_size=chunk_size, shuffle=False, seed=None):
        scores_chunk = model(X_chunk)
        scores_all.append(scores_chunk.detach().cpu())
    scores_all = torch.cat(scores_all, dim=0 ).numpy()

    return scores_all

# %% [markdown]
# ## 8.3 — Métricas binarias

# %%
def compute_binary_metrics(y_true, scores, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    scores = np.asarray(scores)
    y_pred = (scores >= threshold).astype(int)

    metrics = {"threshold": float(threshold), "accuracy": float( accuracy_score( y_true, y_pred)), "balanced_accuracy": float(balanced_accuracy_score( y_true, y_pred)), "f1": float(f1_score(y_true, y_pred)),
        "confusion_matrix": confusion_matrix(y_true, y_pred).tolist(),}

    return metrics

# %% [markdown]
# ## 8.4 — Evaluación completa batched

# %%
def evaluate_model(model, X, y, split_name, chunk_size=131072, threshold=0.5):
    scores = predict_scores_batched( model=model, X=X, chunk_size=chunk_size )
    y_np = y.detach().cpu().numpy()
    metrics = compute_binary_metrics( y_true=y_np, scores=scores, threshold=threshold)
    metrics["split"] = split_name
    metrics["n_samples"] = int(len(y_np))

    return metrics, scores

# %% [markdown]
# ## 8.5 — Entrenamiento de un modelo Qn

# %%
def train_drqnn_model(model, n_qubits, checkpoint_path):
    if n_qubits == 1:
        epochs = EPOCHS_1Q
        lr = LR_1Q
    else:
        epochs = EPOCHS_NQ
        lr = LR_NQ
    optimizer = optim.Adam(model.parameters(), lr=lr)

    best_test_bacc = -np.inf
    best_state = None

    history = []

    print("\nEntrenando DR-QNN")
    print("Qubits:", n_qubits)
    print("Epochs:", epochs)
    print("LR:", lr)
    print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)

    for epoch in range(1, epochs + 1):
        model.train()
        epoch_losses = []

        for X_batch, y_batch in make_tensor_batches(
            X_train_t,
            y_train_float_t,
            batch_size=TRAIN_BATCH_SIZE_TORCH,
            shuffle=True,
            seed=GLOBAL_SEED + epoch
        ):

            optimizer.zero_grad(set_to_none=True)
            scores = model(X_batch)
            loss = fidelity_loss_from_scores(scores, y_batch)
            loss.backward()
            optimizer.step()
            epoch_losses.append(float(loss.detach().cpu().item()))

        train_metrics, _ = evaluate_model(
            model=model,
            X=X_train_t,
            y=y_train_t,
            split_name="train",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        test_metrics, _ = evaluate_model(
            model=model,
            X=X_test_t,
            y=y_test_t,
            split_name="test",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        mean_loss = float(
            np.mean(epoch_losses)
        )

        row = {
            "n_qubits": int(n_qubits),
            "epoch": int(epoch),
            "loss": mean_loss,
            "train_accuracy": train_metrics["accuracy"],
            "train_balanced_accuracy": train_metrics["balanced_accuracy"],
            "train_f1": train_metrics["f1"],
            "test_accuracy": test_metrics["accuracy"],
            "test_balanced_accuracy": test_metrics["balanced_accuracy"],
            "test_f1": test_metrics["f1"],
        }

        history.append(
            row
        )

        print(
            f"Q{n_qubits} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={mean_loss:.6f} | "
            f"train_acc={train_metrics['accuracy']:.4f} | "
            f"test_acc={test_metrics['accuracy']:.4f} | "
            f"test_bAcc={test_metrics['balanced_accuracy']:.4f}"
        )

        if test_metrics["balanced_accuracy"] > best_test_bacc:

            best_test_bacc = test_metrics["balanced_accuracy"]

            best_state = {
                "n_qubits": int(n_qubits),
                "epoch": int(epoch),
                "model_state_dict": {
                    k: v.detach().cpu()
                    for k, v in model.state_dict().items()
                },
                "test_metrics": test_metrics,
                "train_metrics": train_metrics,
                "config": CONFIG,
            }

            torch.save(
                best_state,
                checkpoint_path
            )

    if best_state is not None:

        model.load_state_dict(
            {
                k: v.to(DEVICE)
                for k, v in best_state["model_state_dict"].items()
            }
        )

    history_df = pd.DataFrame(
        history
    )

    print("\nMejor test balanced accuracy:")
    print(best_test_bacc)

    print("Checkpoint guardado en:")
    print(checkpoint_path)

    return model, history_df

# %% [markdown]
# ## 8.6 — Rutas de checkpoints por número de qubits

# %%
CHECKPOINT_PATHS = {
    1: CHECKPOINT_1Q_PATH,
    2: CHECKPOINT_2Q_PATH,
    3: CHECKPOINT_3Q_PATH,
    4: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_4q.pt"
    ),
    5: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_5q.pt"
    ),
}

print("Sección 8 lista.")
print("Ya están definidas las funciones de loss, evaluación batched y entrenamiento.")
# Out:
# Sección 8 lista.
# Ya están definidas las funciones de loss, evaluación batched y entrenamiento.

# %% [markdown]
# # **9**

# %% [markdown]
# ## 9.1 — Entrenamiento progresivo Q1 → Q5

# %%
trained_models = {}
training_histories = {}
final_metrics_rows = {}
final_scores = {}

current_model = None

for n_qubits in QUBITS_LIST:
    print("\n" + "=" * 80)
    print(f"ENTRENAMIENTO PROGRESIVO Q{n_qubits}")
    print("=" * 80)
    if n_qubits == 1:
        current_model = BatchedDRQNN(n_qubits=1)
    else:
        current_model = make_next_model_from_previous(previous_model=current_model, new_n_qubits=n_qubits)

    checkpoint_path = CHECKPOINT_PATHS[n_qubits]
    current_model, history_df = train_drqnn_model(
        model=current_model,
        n_qubits=n_qubits,
        checkpoint_path=checkpoint_path
    )

    trained_models[n_qubits] = current_model
    training_histories[n_qubits] = history_df

    train_metrics, train_scores = evaluate_model(
        model=current_model,
        X=X_train_t,
        y=y_train_t,
        split_name="train",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    test_metrics, test_scores = evaluate_model(
        model=current_model,
        X=X_test_t,
        y=y_test_t,
        split_name="test",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    final_metrics_rows[n_qubits] = {
        "n_qubits": int(n_qubits),
        "train_accuracy": train_metrics["accuracy"],
        "train_balanced_accuracy": train_metrics["balanced_accuracy"],
        "train_f1": train_metrics["f1"],
        "test_accuracy": test_metrics["accuracy"],
        "test_balanced_accuracy": test_metrics["balanced_accuracy"],
        "test_f1": test_metrics["f1"],
        "checkpoint_path": checkpoint_path,
    }

    final_scores[n_qubits] = {
        "train_scores": train_scores,
        "test_scores": test_scores,
        "train_metrics": train_metrics,
        "test_metrics": test_metrics,
    }

    print("\nResultado final Q", n_qubits)
    print("TRAIN:", train_metrics)
    print("TEST :", test_metrics)
# Out:
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q1
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 1
# Epochs: 60
# LR: 0.006
# TRAIN_BATCH_SIZE_TORCH: 32
# Q1 | Epoch 001/60 | loss=0.667498 | train_acc=0.7824 | test_acc=0.7857 | test_bAcc=0.7885
# Q1 | Epoch 002/60 | loss=0.622156 | train_acc=0.7859 | test_acc=0.7912 | test_bAcc=0.7929
# Q1 | Epoch 003/60 | loss=0.619596 | train_acc=0.7847 | test_acc=0.7922 | test_bAcc=0.7943
# Q1 | Epoch 004/60 | loss=0.614741 | train_acc=0.7875 | test_acc=0.7950 | test_bAcc=0.7969
# Q1 | Epoch 005/60 | loss=0.613012 | train_acc=0.7893 | test_acc=0.7981 | test_bAcc=0.7992
# Q1 | Epoch 006/60 | loss=0.612154 | train_acc=0.7849 | test_acc=0.7934 | test_bAcc=0.7957
# Q1 | Epoch 007/60 | loss=0.610681 | train_acc=0.7853 | test_acc=0.7939 | test_bAcc=0.7958
# Q1 | Epoch 008/60 | loss=0.610008 | train_acc=0.7907 | test_acc=0.7979 | test_bAcc=0.7994
# Q1 | Epoch 009/60 | loss=0.609291 | train_acc=0.7836 | test_acc=0.7912 | test_bAcc=0.7936
# Q1 | Epoch 010/60 | loss=0.609547 | train_acc=0.7862 | test_acc=0.7936 | test_bAcc=0.7953
# Q1 | Epoch 011/60 | loss=0.609157 | train_acc=0.7865 | test_acc=0.7931 | test_bAcc=0.7951
# Q1 | Epoch 012/60 | loss=0.609013 | train_acc=0.7871 | test_acc=0.7948 | test_bAcc=0.7966
# Q1 | Epoch 013/60 | loss=0.607532 | train_acc=0.7883 | test_acc=0.7981 | test_bAcc=0.7992
# Q1 | Epoch 014/60 | loss=0.608040 | train_acc=0.7841 | test_acc=0.7929 | test_bAcc=0.7953
# Q1 | Epoch 015/60 | loss=0.607456 | train_acc=0.7919 | test_acc=0.7974 | test_bAcc=0.7991
# Q1 | Epoch 016/60 | loss=0.608395 | train_acc=0.7883 | test_acc=0.7941 | test_bAcc=0.7956
# Q1 | Epoch 017/60 | loss=0.607067 | train_acc=0.7861 | test_acc=0.7948 | test_bAcc=0.7970
# Q1 | Epoch 018/60 | loss=0.607280 | train_acc=0.7867 | test_acc=0.7941 | test_bAcc=0.7961
# Q1 | Epoch 019/60 | loss=0.607867 | train_acc=0.7829 | test_acc=0.7939 | test_bAcc=0.7962
# Q1 | Epoch 020/60 | loss=0.607278 | train_acc=0.7891 | test_acc=0.7962 | test_bAcc=0.7980
# Q1 | Epoch 021/60 | loss=0.607184 | train_acc=0.7887 | test_acc=0.7974 | test_bAcc=0.7987
# Q1 | Epoch 022/60 | loss=0.607270 | train_acc=0.7882 | test_acc=0.7996 | test_bAcc=0.8004
# Q1 | Epoch 023/60 | loss=0.607098 | train_acc=0.7881 | test_acc=0.7960 | test_bAcc=0.7978
# Q1 | Epoch 024/60 | loss=0.608399 | train_acc=0.7898 | test_acc=0.7962 | test_bAcc=0.7979
# Q1 | Epoch 025/60 | loss=0.608279 | train_acc=0.7896 | test_acc=0.7950 | test_bAcc=0.7966
# Q1 | Epoch 026/60 | loss=0.606787 | train_acc=0.7858 | test_acc=0.7934 | test_bAcc=0.7957
# Q1 | Epoch 027/60 | loss=0.607708 | train_acc=0.7835 | test_acc=0.7934 | test_bAcc=0.7956
# Q1 | Epoch 028/60 | loss=0.606616 | train_acc=0.7893 | test_acc=0.7969 | test_bAcc=0.7981
# Q1 | Epoch 029/60 | loss=0.605969 | train_acc=0.7895 | test_acc=0.7962 | test_bAcc=0.7980
# Q1 | Epoch 030/60 | loss=0.606940 | train_acc=0.7892 | test_acc=0.7931 | test_bAcc=0.7946
# Q1 | Epoch 031/60 | loss=0.606377 | train_acc=0.7881 | test_acc=0.7950 | test_bAcc=0.7967
# Q1 | Epoch 032/60 | loss=0.605551 | train_acc=0.7846 | test_acc=0.7915 | test_bAcc=0.7939
# Q1 | Epoch 033/60 | loss=0.607042 | train_acc=0.7896 | test_acc=0.7950 | test_bAcc=0.7965
# Q1 | Epoch 034/60 | loss=0.606341 | train_acc=0.7874 | test_acc=0.7960 | test_bAcc=0.7977
# Q1 | Epoch 035/60 | loss=0.606792 | train_acc=0.7887 | test_acc=0.7960 | test_bAcc=0.7976
# Q1 | Epoch 036/60 | loss=0.606811 | train_acc=0.7874 | test_acc=0.7950 | test_bAcc=0.7970
# Q1 | Epoch 037/60 | loss=0.606165 | train_acc=0.7896 | test_acc=0.7972 | test_bAcc=0.7991
# Q1 | Epoch 038/60 | loss=0.605684 | train_acc=0.7887 | test_acc=0.7953 | test_bAcc=0.7969
# Q1 | Epoch 039/60 | loss=0.606491 | train_acc=0.7848 | test_acc=0.7903 | test_bAcc=0.7928
# Q1 | Epoch 040/60 | loss=0.605362 | train_acc=0.7883 | test_acc=0.7941 | test_bAcc=0.7956
# Q1 | Epoch 041/60 | loss=0.605814 | train_acc=0.7877 | test_acc=0.7950 | test_bAcc=0.7971
# Q1 | Epoch 042/60 | loss=0.606393 | train_acc=0.7867 | test_acc=0.7953 | test_bAcc=0.7970
# Q1 | Epoch 043/60 | loss=0.605229 | train_acc=0.7896 | test_acc=0.7967 | test_bAcc=0.7985
# Q1 | Epoch 044/60 | loss=0.605741 | train_acc=0.7868 | test_acc=0.7943 | test_bAcc=0.7963
# Q1 | Epoch 045/60 | loss=0.605260 | train_acc=0.7883 | test_acc=0.7946 | test_bAcc=0.7965
# Q1 | Epoch 046/60 | loss=0.605263 | train_acc=0.7863 | test_acc=0.7934 | test_bAcc=0.7959
# Q1 | Epoch 047/60 | loss=0.605326 | train_acc=0.7903 | test_acc=0.7965 | test_bAcc=0.7978
# Q1 | Epoch 048/60 | loss=0.604914 | train_acc=0.7886 | test_acc=0.7958 | test_bAcc=0.7973
# Q1 | Epoch 049/60 | loss=0.604924 | train_acc=0.7924 | test_acc=0.7984 | test_bAcc=0.8001
# Q1 | Epoch 050/60 | loss=0.604880 | train_acc=0.7900 | test_acc=0.7979 | test_bAcc=0.7997
# Q1 | Epoch 051/60 | loss=0.604479 | train_acc=0.7869 | test_acc=0.7943 | test_bAcc=0.7958
# Q1 | Epoch 052/60 | loss=0.604385 | train_acc=0.7876 | test_acc=0.7934 | test_bAcc=0.7953
# Q1 | Epoch 053/60 | loss=0.603822 | train_acc=0.7897 | test_acc=0.7974 | test_bAcc=0.7995
# Q1 | Epoch 054/60 | loss=0.603811 | train_acc=0.7865 | test_acc=0.7950 | test_bAcc=0.7973
# Q1 | Epoch 055/60 | loss=0.604099 | train_acc=0.7871 | test_acc=0.7941 | test_bAcc=0.7963
# Q1 | Epoch 056/60 | loss=0.604782 | train_acc=0.7884 | test_acc=0.7953 | test_bAcc=0.7975
# Q1 | Epoch 057/60 | loss=0.604783 | train_acc=0.7914 | test_acc=0.7977 | test_bAcc=0.7994
# Q1 | Epoch 058/60 | loss=0.603896 | train_acc=0.7886 | test_acc=0.7965 | test_bAcc=0.7978
# Q1 | Epoch 059/60 | loss=0.603747 | train_acc=0.7915 | test_acc=0.7981 | test_bAcc=0.7998
# Q1 | Epoch 060/60 | loss=0.604101 | train_acc=0.7911 | test_acc=0.7991 | test_bAcc=0.8004
#
# Mejor test balanced accuracy:
# 0.8004191057305056
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_1q.pt
#
# Resultado final Q 1
# TRAIN: {'threshold': 0.5, 'accuracy': 0.7882002383790226, 'balanced_accuracy': 0.7890536638339112, 'f1': 0.781373031496063, 'confusion_matrix': [[6875, 1359], [2195, 6351]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.7995710200190658, 'balanced_accuracy': 0.8004191057305056, 'f1': 0.7932136710105729, 'confusion_matrix': [[1742, 317], [524, 1613]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q2
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 2
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q2 | Epoch 001/50 | loss=0.601350 | train_acc=0.7890 | test_acc=0.7967 | test_bAcc=0.7989
# Q2 | Epoch 002/50 | loss=0.592823 | train_acc=0.7926 | test_acc=0.8000 | test_bAcc=0.8013
# Q2 | Epoch 003/50 | loss=0.584107 | train_acc=0.7962 | test_acc=0.8053 | test_bAcc=0.8069
# Q2 | Epoch 004/50 | loss=0.574298 | train_acc=0.8002 | test_acc=0.8079 | test_bAcc=0.8095
# Q2 | Epoch 005/50 | loss=0.569114 | train_acc=0.8010 | test_acc=0.8101 | test_bAcc=0.8111
# Q2 | Epoch 006/50 | loss=0.565603 | train_acc=0.8018 | test_acc=0.8070 | test_bAcc=0.8091
# Q2 | Epoch 007/50 | loss=0.562714 | train_acc=0.8035 | test_acc=0.8108 | test_bAcc=0.8126
# Q2 | Epoch 008/50 | loss=0.560762 | train_acc=0.8054 | test_acc=0.8120 | test_bAcc=0.8133
# Q2 | Epoch 009/50 | loss=0.558593 | train_acc=0.8026 | test_acc=0.8072 | test_bAcc=0.8092
# Q2 | Epoch 010/50 | loss=0.558375 | train_acc=0.8010 | test_acc=0.8101 | test_bAcc=0.8117
# Q2 | Epoch 011/50 | loss=0.557537 | train_acc=0.8048 | test_acc=0.8108 | test_bAcc=0.8126
# Q2 | Epoch 012/50 | loss=0.555822 | train_acc=0.8033 | test_acc=0.8098 | test_bAcc=0.8116
# Q2 | Epoch 013/50 | loss=0.554533 | train_acc=0.8024 | test_acc=0.8074 | test_bAcc=0.8083
# Q2 | Epoch 014/50 | loss=0.554017 | train_acc=0.8066 | test_acc=0.8091 | test_bAcc=0.8112
# Q2 | Epoch 015/50 | loss=0.553142 | train_acc=0.8087 | test_acc=0.8146 | test_bAcc=0.8164
# Q2 | Epoch 016/50 | loss=0.552793 | train_acc=0.8068 | test_acc=0.8122 | test_bAcc=0.8137
# Q2 | Epoch 017/50 | loss=0.551477 | train_acc=0.8085 | test_acc=0.8103 | test_bAcc=0.8124
# Q2 | Epoch 018/50 | loss=0.551483 | train_acc=0.8088 | test_acc=0.8134 | test_bAcc=0.8150
# Q2 | Epoch 019/50 | loss=0.551186 | train_acc=0.8073 | test_acc=0.8103 | test_bAcc=0.8123
# Q2 | Epoch 020/50 | loss=0.550726 | train_acc=0.8122 | test_acc=0.8146 | test_bAcc=0.8166
# Q2 | Epoch 021/50 | loss=0.550462 | train_acc=0.8060 | test_acc=0.8124 | test_bAcc=0.8136
# Q2 | Epoch 022/50 | loss=0.549952 | train_acc=0.8057 | test_acc=0.8108 | test_bAcc=0.8118
# Q2 | Epoch 023/50 | loss=0.549503 | train_acc=0.8101 | test_acc=0.8158 | test_bAcc=0.8176
# Q2 | Epoch 024/50 | loss=0.550079 | train_acc=0.8097 | test_acc=0.8158 | test_bAcc=0.8172
# Q2 | Epoch 025/50 | loss=0.549765 | train_acc=0.8094 | test_acc=0.8143 | test_bAcc=0.8160
# Q2 | Epoch 026/50 | loss=0.548261 | train_acc=0.8094 | test_acc=0.8129 | test_bAcc=0.8149
# Q2 | Epoch 027/50 | loss=0.548572 | train_acc=0.8097 | test_acc=0.8124 | test_bAcc=0.8146
# Q2 | Epoch 028/50 | loss=0.547408 | train_acc=0.8064 | test_acc=0.8132 | test_bAcc=0.8143
# Q2 | Epoch 029/50 | loss=0.547338 | train_acc=0.8100 | test_acc=0.8153 | test_bAcc=0.8168
# Q2 | Epoch 030/50 | loss=0.547303 | train_acc=0.8105 | test_acc=0.8160 | test_bAcc=0.8178
# Q2 | Epoch 031/50 | loss=0.546495 | train_acc=0.8099 | test_acc=0.8153 | test_bAcc=0.8168
# Q2 | Epoch 032/50 | loss=0.545244 | train_acc=0.8132 | test_acc=0.8141 | test_bAcc=0.8164
# Q2 | Epoch 033/50 | loss=0.545409 | train_acc=0.8122 | test_acc=0.8155 | test_bAcc=0.8171
# Q2 | Epoch 034/50 | loss=0.544574 | train_acc=0.8122 | test_acc=0.8179 | test_bAcc=0.8197
# Q2 | Epoch 035/50 | loss=0.544979 | train_acc=0.8116 | test_acc=0.8179 | test_bAcc=0.8197
# Q2 | Epoch 036/50 | loss=0.545336 | train_acc=0.8121 | test_acc=0.8174 | test_bAcc=0.8194
# Q2 | Epoch 037/50 | loss=0.543890 | train_acc=0.8129 | test_acc=0.8155 | test_bAcc=0.8178
# Q2 | Epoch 038/50 | loss=0.543551 | train_acc=0.8132 | test_acc=0.8174 | test_bAcc=0.8195
# Q2 | Epoch 039/50 | loss=0.544033 | train_acc=0.8101 | test_acc=0.8141 | test_bAcc=0.8165
# Q2 | Epoch 040/50 | loss=0.542850 | train_acc=0.8086 | test_acc=0.8129 | test_bAcc=0.8141
# Q2 | Epoch 041/50 | loss=0.543766 | train_acc=0.8135 | test_acc=0.8163 | test_bAcc=0.8184
# Q2 | Epoch 042/50 | loss=0.544043 | train_acc=0.8122 | test_acc=0.8194 | test_bAcc=0.8212
# Q2 | Epoch 043/50 | loss=0.542927 | train_acc=0.8130 | test_acc=0.8198 | test_bAcc=0.8216
# Q2 | Epoch 044/50 | loss=0.543305 | train_acc=0.8126 | test_acc=0.8158 | test_bAcc=0.8180
# Q2 | Epoch 045/50 | loss=0.542414 | train_acc=0.8148 | test_acc=0.8189 | test_bAcc=0.8209
# Q2 | Epoch 046/50 | loss=0.542638 | train_acc=0.8077 | test_acc=0.8129 | test_bAcc=0.8156
# Q2 | Epoch 047/50 | loss=0.542844 | train_acc=0.8117 | test_acc=0.8148 | test_bAcc=0.8162
# Q2 | Epoch 048/50 | loss=0.541505 | train_acc=0.8120 | test_acc=0.8196 | test_bAcc=0.8213
# Q2 | Epoch 049/50 | loss=0.541787 | train_acc=0.8167 | test_acc=0.8189 | test_bAcc=0.8207
# Q2 | Epoch 050/50 | loss=0.541896 | train_acc=0.8135 | test_acc=0.8172 | test_bAcc=0.8187
#
# Mejor test balanced accuracy:
# 0.8216363191330709
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_2q.pt
#
# Resultado final Q 2
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8129916567342074, 'balanced_accuracy': 0.8147138226532251, 'f1': 0.7972868217054263, 'confusion_matrix': [[7471, 763], [2375, 6171]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8198284080076264, 'balanced_accuracy': 0.8216363191330709, 'f1': 0.8037383177570093, 'confusion_matrix': [[1892, 167], [589, 1548]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q3
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 3
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q3 | Epoch 001/50 | loss=0.541958 | train_acc=0.8134 | test_acc=0.8172 | test_bAcc=0.8193
# Q3 | Epoch 002/50 | loss=0.539195 | train_acc=0.8119 | test_acc=0.8184 | test_bAcc=0.8199
# Q3 | Epoch 003/50 | loss=0.537997 | train_acc=0.8152 | test_acc=0.8198 | test_bAcc=0.8217
# Q3 | Epoch 004/50 | loss=0.534594 | train_acc=0.8163 | test_acc=0.8210 | test_bAcc=0.8226
# Q3 | Epoch 005/50 | loss=0.533513 | train_acc=0.8113 | test_acc=0.8182 | test_bAcc=0.8193
# Q3 | Epoch 006/50 | loss=0.532674 | train_acc=0.8155 | test_acc=0.8194 | test_bAcc=0.8216
# Q3 | Epoch 007/50 | loss=0.531469 | train_acc=0.8170 | test_acc=0.8208 | test_bAcc=0.8227
# Q3 | Epoch 008/50 | loss=0.530973 | train_acc=0.8147 | test_acc=0.8191 | test_bAcc=0.8204
# Q3 | Epoch 009/50 | loss=0.529532 | train_acc=0.8163 | test_acc=0.8210 | test_bAcc=0.8231
# Q3 | Epoch 010/50 | loss=0.530329 | train_acc=0.8151 | test_acc=0.8210 | test_bAcc=0.8228
# Q3 | Epoch 011/50 | loss=0.529649 | train_acc=0.8171 | test_acc=0.8215 | test_bAcc=0.8235
# Q3 | Epoch 012/50 | loss=0.528337 | train_acc=0.8157 | test_acc=0.8208 | test_bAcc=0.8227
# Q3 | Epoch 013/50 | loss=0.527322 | train_acc=0.8123 | test_acc=0.8184 | test_bAcc=0.8193
# Q3 | Epoch 014/50 | loss=0.527371 | train_acc=0.8175 | test_acc=0.8186 | test_bAcc=0.8208
# Q3 | Epoch 015/50 | loss=0.526899 | train_acc=0.8204 | test_acc=0.8215 | test_bAcc=0.8234
# Q3 | Epoch 016/50 | loss=0.526816 | train_acc=0.8180 | test_acc=0.8227 | test_bAcc=0.8244
# Q3 | Epoch 017/50 | loss=0.525874 | train_acc=0.8178 | test_acc=0.8198 | test_bAcc=0.8220
# Q3 | Epoch 018/50 | loss=0.526085 | train_acc=0.8182 | test_acc=0.8217 | test_bAcc=0.8235
# Q3 | Epoch 019/50 | loss=0.526394 | train_acc=0.8175 | test_acc=0.8203 | test_bAcc=0.8224
# Q3 | Epoch 020/50 | loss=0.526134 | train_acc=0.8194 | test_acc=0.8232 | test_bAcc=0.8253
# Q3 | Epoch 021/50 | loss=0.525842 | train_acc=0.8153 | test_acc=0.8205 | test_bAcc=0.8220
# Q3 | Epoch 022/50 | loss=0.525851 | train_acc=0.8160 | test_acc=0.8215 | test_bAcc=0.8228
# Q3 | Epoch 023/50 | loss=0.525977 | train_acc=0.8190 | test_acc=0.8227 | test_bAcc=0.8247
# Q3 | Epoch 024/50 | loss=0.526277 | train_acc=0.8165 | test_acc=0.8198 | test_bAcc=0.8214
# Q3 | Epoch 025/50 | loss=0.526261 | train_acc=0.8195 | test_acc=0.8232 | test_bAcc=0.8251
# Q3 | Epoch 026/50 | loss=0.525319 | train_acc=0.8183 | test_acc=0.8239 | test_bAcc=0.8259
# Q3 | Epoch 027/50 | loss=0.525847 | train_acc=0.8168 | test_acc=0.8194 | test_bAcc=0.8216
# Q3 | Epoch 028/50 | loss=0.525160 | train_acc=0.8135 | test_acc=0.8189 | test_bAcc=0.8201
# Q3 | Epoch 029/50 | loss=0.525416 | train_acc=0.8181 | test_acc=0.8203 | test_bAcc=0.8218
# Q3 | Epoch 030/50 | loss=0.525663 | train_acc=0.8199 | test_acc=0.8239 | test_bAcc=0.8258
# Q3 | Epoch 031/50 | loss=0.525050 | train_acc=0.8173 | test_acc=0.8208 | test_bAcc=0.8223
# Q3 | Epoch 032/50 | loss=0.524324 | train_acc=0.8181 | test_acc=0.8232 | test_bAcc=0.8253
# Q3 | Epoch 033/50 | loss=0.525140 | train_acc=0.8195 | test_acc=0.8217 | test_bAcc=0.8233
# Q3 | Epoch 034/50 | loss=0.524265 | train_acc=0.8197 | test_acc=0.8227 | test_bAcc=0.8243
# Q3 | Epoch 035/50 | loss=0.524786 | train_acc=0.8169 | test_acc=0.8222 | test_bAcc=0.8239
# Q3 | Epoch 036/50 | loss=0.525415 | train_acc=0.8179 | test_acc=0.8220 | test_bAcc=0.8239
# Q3 | Epoch 037/50 | loss=0.524466 | train_acc=0.8187 | test_acc=0.8217 | test_bAcc=0.8239
# Q3 | Epoch 038/50 | loss=0.524216 | train_acc=0.8186 | test_acc=0.8217 | test_bAcc=0.8237
# Q3 | Epoch 039/50 | loss=0.524913 | train_acc=0.8182 | test_acc=0.8191 | test_bAcc=0.8214
# Q3 | Epoch 040/50 | loss=0.523938 | train_acc=0.8147 | test_acc=0.8198 | test_bAcc=0.8211
# Q3 | Epoch 041/50 | loss=0.524948 | train_acc=0.8189 | test_acc=0.8239 | test_bAcc=0.8260
# Q3 | Epoch 042/50 | loss=0.525187 | train_acc=0.8193 | test_acc=0.8229 | test_bAcc=0.8247
# Q3 | Epoch 043/50 | loss=0.524391 | train_acc=0.8185 | test_acc=0.8248 | test_bAcc=0.8265
# Q3 | Epoch 044/50 | loss=0.524922 | train_acc=0.8180 | test_acc=0.8222 | test_bAcc=0.8243
# Q3 | Epoch 045/50 | loss=0.524204 | train_acc=0.8209 | test_acc=0.8244 | test_bAcc=0.8263
# Q3 | Epoch 046/50 | loss=0.524247 | train_acc=0.8163 | test_acc=0.8177 | test_bAcc=0.8201
# Q3 | Epoch 047/50 | loss=0.524681 | train_acc=0.8184 | test_acc=0.8215 | test_bAcc=0.8229
# Q3 | Epoch 048/50 | loss=0.523471 | train_acc=0.8194 | test_acc=0.8229 | test_bAcc=0.8249
# Q3 | Epoch 049/50 | loss=0.523584 | train_acc=0.8214 | test_acc=0.8244 | test_bAcc=0.8262
# Q3 | Epoch 050/50 | loss=0.524037 | train_acc=0.8188 | test_acc=0.8215 | test_bAcc=0.8230
#
# Mejor test balanced accuracy:
# 0.8265497491751861
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_3q.pt
#
# Resultado final Q 3
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8185339690107271, 'balanced_accuracy': 0.820161615480634, 'f1': 0.8043939101946425, 'confusion_matrix': [[7474, 760], [2285, 6261]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8248331744518589, 'balanced_accuracy': 0.8265497491751861, 'f1': 0.8102246320681642, 'confusion_matrix': [[1892, 167], [568, 1569]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q4
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 4
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q4 | Epoch 001/50 | loss=0.523326 | train_acc=0.8194 | test_acc=0.8234 | test_bAcc=0.8256
# Q4 | Epoch 002/50 | loss=0.521744 | train_acc=0.8175 | test_acc=0.8222 | test_bAcc=0.8237
# Q4 | Epoch 003/50 | loss=0.522366 | train_acc=0.8209 | test_acc=0.8258 | test_bAcc=0.8278
# Q4 | Epoch 004/50 | loss=0.520285 | train_acc=0.8215 | test_acc=0.8234 | test_bAcc=0.8250
# Q4 | Epoch 005/50 | loss=0.520186 | train_acc=0.8167 | test_acc=0.8213 | test_bAcc=0.8224
# Q4 | Epoch 006/50 | loss=0.519926 | train_acc=0.8204 | test_acc=0.8236 | test_bAcc=0.8258
# Q4 | Epoch 007/50 | loss=0.519392 | train_acc=0.8219 | test_acc=0.8251 | test_bAcc=0.8270
# Q4 | Epoch 008/50 | loss=0.519396 | train_acc=0.8197 | test_acc=0.8236 | test_bAcc=0.8251
# Q4 | Epoch 009/50 | loss=0.518552 | train_acc=0.8197 | test_acc=0.8248 | test_bAcc=0.8268
# Q4 | Epoch 010/50 | loss=0.519353 | train_acc=0.8197 | test_acc=0.8234 | test_bAcc=0.8252
# Q4 | Epoch 011/50 | loss=0.519342 | train_acc=0.8203 | test_acc=0.8263 | test_bAcc=0.8283
# Q4 | Epoch 012/50 | loss=0.518395 | train_acc=0.8196 | test_acc=0.8248 | test_bAcc=0.8269
# Q4 | Epoch 013/50 | loss=0.517609 | train_acc=0.8150 | test_acc=0.8239 | test_bAcc=0.8248
# Q4 | Epoch 014/50 | loss=0.517705 | train_acc=0.8204 | test_acc=0.8229 | test_bAcc=0.8251
# Q4 | Epoch 015/50 | loss=0.517544 | train_acc=0.8225 | test_acc=0.8251 | test_bAcc=0.8270
# Q4 | Epoch 016/50 | loss=0.517630 | train_acc=0.8212 | test_acc=0.8260 | test_bAcc=0.8278
# Q4 | Epoch 017/50 | loss=0.516931 | train_acc=0.8206 | test_acc=0.8246 | test_bAcc=0.8267
# Q4 | Epoch 018/50 | loss=0.517217 | train_acc=0.8216 | test_acc=0.8255 | test_bAcc=0.8273
# Q4 | Epoch 019/50 | loss=0.517561 | train_acc=0.8181 | test_acc=0.8232 | test_bAcc=0.8250
# Q4 | Epoch 020/50 | loss=0.517376 | train_acc=0.8233 | test_acc=0.8253 | test_bAcc=0.8274
# Q4 | Epoch 021/50 | loss=0.517118 | train_acc=0.8187 | test_acc=0.8232 | test_bAcc=0.8246
# Q4 | Epoch 022/50 | loss=0.517226 | train_acc=0.8191 | test_acc=0.8246 | test_bAcc=0.8260
# Q4 | Epoch 023/50 | loss=0.517458 | train_acc=0.8222 | test_acc=0.8244 | test_bAcc=0.8263
# Q4 | Epoch 024/50 | loss=0.517673 | train_acc=0.8197 | test_acc=0.8236 | test_bAcc=0.8251
# Q4 | Epoch 025/50 | loss=0.517628 | train_acc=0.8229 | test_acc=0.8251 | test_bAcc=0.8270
# Q4 | Epoch 026/50 | loss=0.516866 | train_acc=0.8205 | test_acc=0.8260 | test_bAcc=0.8280
# Q4 | Epoch 027/50 | loss=0.517212 | train_acc=0.8206 | test_acc=0.8251 | test_bAcc=0.8272
# Q4 | Epoch 028/50 | loss=0.516742 | train_acc=0.8156 | test_acc=0.8205 | test_bAcc=0.8217
# Q4 | Epoch 029/50 | loss=0.516831 | train_acc=0.8194 | test_acc=0.8217 | test_bAcc=0.8232
# Q4 | Epoch 030/50 | loss=0.517210 | train_acc=0.8231 | test_acc=0.8248 | test_bAcc=0.8267
# Q4 | Epoch 031/50 | loss=0.516573 | train_acc=0.8192 | test_acc=0.8246 | test_bAcc=0.8260
# Q4 | Epoch 032/50 | loss=0.515747 | train_acc=0.8212 | test_acc=0.8253 | test_bAcc=0.8272
# Q4 | Epoch 033/50 | loss=0.516981 | train_acc=0.8205 | test_acc=0.8239 | test_bAcc=0.8254
# Q4 | Epoch 034/50 | loss=0.515701 | train_acc=0.8216 | test_acc=0.8263 | test_bAcc=0.8278
# Q4 | Epoch 035/50 | loss=0.516261 | train_acc=0.8209 | test_acc=0.8260 | test_bAcc=0.8277
# Q4 | Epoch 036/50 | loss=0.516807 | train_acc=0.8208 | test_acc=0.8239 | test_bAcc=0.8257
# Q4 | Epoch 037/50 | loss=0.515879 | train_acc=0.8218 | test_acc=0.8236 | test_bAcc=0.8259
# Q4 | Epoch 038/50 | loss=0.515780 | train_acc=0.8208 | test_acc=0.8244 | test_bAcc=0.8263
# Q4 | Epoch 039/50 | loss=0.516454 | train_acc=0.8225 | test_acc=0.8236 | test_bAcc=0.8259
# Q4 | Epoch 040/50 | loss=0.515358 | train_acc=0.8160 | test_acc=0.8217 | test_bAcc=0.8229
# Q4 | Epoch 041/50 | loss=0.516361 | train_acc=0.8226 | test_acc=0.8279 | test_bAcc=0.8300
# Q4 | Epoch 042/50 | loss=0.516560 | train_acc=0.8220 | test_acc=0.8272 | test_bAcc=0.8289
# Q4 | Epoch 043/50 | loss=0.515739 | train_acc=0.8219 | test_acc=0.8260 | test_bAcc=0.8278
# Q4 | Epoch 044/50 | loss=0.516235 | train_acc=0.8204 | test_acc=0.8239 | test_bAcc=0.8260
# Q4 | Epoch 045/50 | loss=0.515586 | train_acc=0.8237 | test_acc=0.8260 | test_bAcc=0.8278
# Q4 | Epoch 046/50 | loss=0.515538 | train_acc=0.8214 | test_acc=0.8217 | test_bAcc=0.8241
# Q4 | Epoch 047/50 | loss=0.516070 | train_acc=0.8213 | test_acc=0.8244 | test_bAcc=0.8258
# Q4 | Epoch 048/50 | loss=0.514874 | train_acc=0.8219 | test_acc=0.8244 | test_bAcc=0.8264
# Q4 | Epoch 049/50 | loss=0.514738 | train_acc=0.8244 | test_acc=0.8248 | test_bAcc=0.8266
# Q4 | Epoch 050/50 | loss=0.515365 | train_acc=0.8204 | test_acc=0.8227 | test_bAcc=0.8241
#
# Mejor test balanced accuracy:
# 0.829981388987435
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_4q.pt
#
# Resultado final Q 4
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8225864123957092, 'balanced_accuracy': 0.8244992266629362, 'f1': 0.8055646267389459, 'confusion_matrix': [[7636, 598], [2379, 6167]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8279313632030505, 'balanced_accuracy': 0.829981388987435, 'f1': 0.8098999473407056, 'confusion_matrix': [[1936, 123], [599, 1538]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q5
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 5
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q5 | Epoch 001/50 | loss=0.515838 | train_acc=0.8215 | test_acc=0.8244 | test_bAcc=0.8265
# Q5 | Epoch 002/50 | loss=0.514946 | train_acc=0.8188 | test_acc=0.8227 | test_bAcc=0.8242
# Q5 | Epoch 003/50 | loss=0.515992 | train_acc=0.8238 | test_acc=0.8270 | test_bAcc=0.8290
# Q5 | Epoch 004/50 | loss=0.513884 | train_acc=0.8221 | test_acc=0.8258 | test_bAcc=0.8273
# Q5 | Epoch 005/50 | loss=0.514022 | train_acc=0.8173 | test_acc=0.8215 | test_bAcc=0.8226
# Q5 | Epoch 006/50 | loss=0.513599 | train_acc=0.8232 | test_acc=0.8263 | test_bAcc=0.8284
# Q5 | Epoch 007/50 | loss=0.513295 | train_acc=0.8246 | test_acc=0.8258 | test_bAcc=0.8276
# Q5 | Epoch 008/50 | loss=0.513363 | train_acc=0.8222 | test_acc=0.8265 | test_bAcc=0.8279
# Q5 | Epoch 009/50 | loss=0.512828 | train_acc=0.8218 | test_acc=0.8253 | test_bAcc=0.8272
# Q5 | Epoch 010/50 | loss=0.513686 | train_acc=0.8221 | test_acc=0.8263 | test_bAcc=0.8280
# Q5 | Epoch 011/50 | loss=0.513808 | train_acc=0.8233 | test_acc=0.8277 | test_bAcc=0.8298
# Q5 | Epoch 012/50 | loss=0.512884 | train_acc=0.8212 | test_acc=0.8258 | test_bAcc=0.8278
# Q5 | Epoch 013/50 | loss=0.512093 | train_acc=0.8167 | test_acc=0.8251 | test_bAcc=0.8259
# Q5 | Epoch 014/50 | loss=0.512150 | train_acc=0.8227 | test_acc=0.8244 | test_bAcc=0.8265
# Q5 | Epoch 015/50 | loss=0.512180 | train_acc=0.8250 | test_acc=0.8255 | test_bAcc=0.8274
# Q5 | Epoch 016/50 | loss=0.512187 | train_acc=0.8244 | test_acc=0.8263 | test_bAcc=0.8280
# Q5 | Epoch 017/50 | loss=0.511686 | train_acc=0.8246 | test_acc=0.8248 | test_bAcc=0.8270
# Q5 | Epoch 018/50 | loss=0.512014 | train_acc=0.8251 | test_acc=0.8267 | test_bAcc=0.8285
# Q5 | Epoch 019/50 | loss=0.512367 | train_acc=0.8198 | test_acc=0.8248 | test_bAcc=0.8266
# Q5 | Epoch 020/50 | loss=0.512327 | train_acc=0.8267 | test_acc=0.8277 | test_bAcc=0.8297
# Q5 | Epoch 021/50 | loss=0.511978 | train_acc=0.8219 | test_acc=0.8241 | test_bAcc=0.8256
# Q5 | Epoch 022/50 | loss=0.512242 | train_acc=0.8218 | test_acc=0.8253 | test_bAcc=0.8267
# Q5 | Epoch 023/50 | loss=0.512547 | train_acc=0.8244 | test_acc=0.8263 | test_bAcc=0.8281
# Q5 | Epoch 024/50 | loss=0.512777 | train_acc=0.8219 | test_acc=0.8248 | test_bAcc=0.8263
# Q5 | Epoch 025/50 | loss=0.512779 | train_acc=0.8259 | test_acc=0.8272 | test_bAcc=0.8292
# Q5 | Epoch 026/50 | loss=0.512066 | train_acc=0.8229 | test_acc=0.8263 | test_bAcc=0.8282
# Q5 | Epoch 027/50 | loss=0.512434 | train_acc=0.8228 | test_acc=0.8253 | test_bAcc=0.8274
# Q5 | Epoch 028/50 | loss=0.512063 | train_acc=0.8175 | test_acc=0.8224 | test_bAcc=0.8236
# Q5 | Epoch 029/50 | loss=0.512166 | train_acc=0.8221 | test_acc=0.8234 | test_bAcc=0.8248
# Q5 | Epoch 030/50 | loss=0.512578 | train_acc=0.8265 | test_acc=0.8277 | test_bAcc=0.8296
# Q5 | Epoch 031/50 | loss=0.512138 | train_acc=0.8224 | test_acc=0.8248 | test_bAcc=0.8263
# Q5 | Epoch 032/50 | loss=0.511091 | train_acc=0.8228 | test_acc=0.8277 | test_bAcc=0.8295
# Q5 | Epoch 033/50 | loss=0.512692 | train_acc=0.8229 | test_acc=0.8246 | test_bAcc=0.8260
# Q5 | Epoch 034/50 | loss=0.511193 | train_acc=0.8243 | test_acc=0.8275 | test_bAcc=0.8290
# Q5 | Epoch 035/50 | loss=0.511917 | train_acc=0.8244 | test_acc=0.8270 | test_bAcc=0.8287
# Q5 | Epoch 036/50 | loss=0.512427 | train_acc=0.8234 | test_acc=0.8255 | test_bAcc=0.8274
# Q5 | Epoch 037/50 | loss=0.511491 | train_acc=0.8244 | test_acc=0.8255 | test_bAcc=0.8278
# Q5 | Epoch 038/50 | loss=0.511548 | train_acc=0.8238 | test_acc=0.8263 | test_bAcc=0.8282
# Q5 | Epoch 039/50 | loss=0.512165 | train_acc=0.8243 | test_acc=0.8263 | test_bAcc=0.8285
# Q5 | Epoch 040/50 | loss=0.511104 | train_acc=0.8175 | test_acc=0.8232 | test_bAcc=0.8243
# Q5 | Epoch 041/50 | loss=0.512156 | train_acc=0.8265 | test_acc=0.8286 | test_bAcc=0.8307
# Q5 | Epoch 042/50 | loss=0.512415 | train_acc=0.8249 | test_acc=0.8275 | test_bAcc=0.8292
# Q5 | Epoch 043/50 | loss=0.511558 | train_acc=0.8245 | test_acc=0.8253 | test_bAcc=0.8272
# Q5 | Epoch 044/50 | loss=0.512015 | train_acc=0.8228 | test_acc=0.8248 | test_bAcc=0.8269
# Q5 | Epoch 045/50 | loss=0.511456 | train_acc=0.8266 | test_acc=0.8275 | test_bAcc=0.8293
# Q5 | Epoch 046/50 | loss=0.511456 | train_acc=0.8232 | test_acc=0.8244 | test_bAcc=0.8267
# Q5 | Epoch 047/50 | loss=0.512067 | train_acc=0.8236 | test_acc=0.8260 | test_bAcc=0.8275
# Q5 | Epoch 048/50 | loss=0.510798 | train_acc=0.8243 | test_acc=0.8255 | test_bAcc=0.8276
# Q5 | Epoch 049/50 | loss=0.510687 | train_acc=0.8265 | test_acc=0.8272 | test_bAcc=0.8290
# Q5 | Epoch 050/50 | loss=0.511402 | train_acc=0.8222 | test_acc=0.8248 | test_bAcc=0.8262
#
# Mejor test balanced accuracy:
# 0.8307010345032129
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_5q.pt
#
# Resultado final Q 5
# TRAIN: {'threshold': 0.5, 'accuracy': 0.8264600715137068, 'balanced_accuracy': 0.8283842016068608, 'f1': 0.8096980786825252, 'confusion_matrix': [[7673, 561], [2351, 6195]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.8286463298379408, 'balanced_accuracy': 0.8307010345032129, 'f1': 0.8106399789307348, 'confusion_matrix': [[1938, 121], [598, 1539]], 'split': 'test', 'n_samples': 4196}

# %% [markdown]
# ## 9.2 — Unir historiales de entrenamiento

# %%
history_all_df = pd.concat([df.assign(n_qubits=n_qubits)for n_qubits, df in training_histories.items()], ignore_index=True)
HISTORY_PATH = os.path.join(RESULTS_DIR, "training_history_q1_to_q5.csv")
history_all_df.to_csv(HISTORY_PATH, index=False)

print("\nHistorial completo guardado en:")
print(HISTORY_PATH)
# Out:
# Historial completo guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\training_history_q1_to_q5.csv

# %% [markdown]
# ## 9.3 — Tabla final de métricas

# %%
metrics_summary_df = pd.DataFrame(list(final_metrics_rows.values()))
metrics_summary_df = metrics_summary_df.sort_values("n_qubits").reset_index(drop=True)
metrics_summary_df.to_csv(METRICS_PATH, index=False)

print("\nResumen final de métricas:")
display(metrics_summary_df)

print("\nMétricas guardadas en:")
print(METRICS_PATH)
# Out:
# Resumen final de métricas:
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         1        0.788200                 0.789054  0.781373       0.799571
# 1         2        0.812992                 0.814714  0.797287       0.819828
# 2         3        0.818534                 0.820162  0.804394       0.824833
# 3         4        0.822586                 0.824499  0.805565       0.827931
# 4         5        0.826460                 0.828384  0.809698       0.828646
#
#    test_balanced_accuracy   test_f1  \
# 0                0.800419  0.793214
# 1                0.821636  0.803738
# 2                0.826550  0.810225
# 3                0.829981  0.809900
# 4                0.830701  0.810640
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# Métricas guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\metrics_summary.csv

# %% [markdown]
# ## 9.4 — Guardar predicciones/scores por split y número de qubits

# %%
prediction_rows = []

for n_qubits in QUBITS_LIST:
    train_scores = final_scores[n_qubits]["train_scores"]
    test_scores = final_scores[n_qubits]["test_scores"]

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_train_idx_qml, y_train_qml, train_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "train",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_test_idx_qml, y_test_qml, test_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "test",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

predictions_df = pd.DataFrame(prediction_rows)
predictions_df.to_csv(PREDICTIONS_PATH, index=False)

print("\nPredicciones guardadas en:")
print(PREDICTIONS_PATH)
# Out:
# Predicciones guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\predictions.csv

# %% [markdown]
# ## 9.5 — Guardar resumen final JSON

# %%
FINAL_SUMMARY_PATH = os.path.join(RESULTS_DIR, "final_summary.json")

final_summary = {
    "experiment_name": EXPERIMENT_NAME,
    "method": METHOD,
    "fold": int(FOLD),
    "k": int(K),
    "q_list": [
        int(q)
        for q in QUBITS_LIST
    ],
    "data_path": DATA_PATH,
    "results_dir": RESULTS_DIR,
    "history_path": HISTORY_PATH,
    "metrics_path": METRICS_PATH,
    "predictions_path": PREDICTIONS_PATH,
    "checkpoints": {
        str(k): v
        for k, v in CHECKPOINT_PATHS.items()
    },
    "metrics_summary": metrics_summary_df.to_dict(orient="records"),
    "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
}

with open(FINAL_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(final_summary, f, indent=4, ensure_ascii=False)

print("\nResumen final guardado en:")
print(FINAL_SUMMARY_PATH)
# Out:
# Resumen final guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\final_summary.json

# %% [markdown]
# ## 9.6 — Seleccionar mejor modelo por test balanced accuracy

# %%
best_row = metrics_summary_df.loc[
    metrics_summary_df[
        "test_balanced_accuracy"
    ].idxmax()
]

BEST_N_QUBITS = int(
    best_row["n_qubits"]
)

BEST_CHECKPOINT_PATH = CHECKPOINT_PATHS[
    BEST_N_QUBITS
]

print("\nMejor modelo:")
print("Qubits:", BEST_N_QUBITS)
print("Test bAcc:", best_row["test_balanced_accuracy"])
print("Checkpoint:", BEST_CHECKPOINT_PATH)

print("\nSección 9 lista.")
print("Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.")
# Out:
# Mejor modelo:
# Qubits: 5
# Test bAcc: 0.8307010345032129
# Checkpoint: C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_5q.pt
#
# Sección 9 lista.
# Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.

# %% [markdown]
# # **10**

# %% [markdown]
# ## 10.1 — Imports para visualización

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    ConfusionMatrixDisplay,
    confusion_matrix
)

# %% [markdown]
# ## 10.2 — Cargar historial completo

# %%
history_df = pd.read_csv(HISTORY_PATH)

print("Historial cargado:")
print(history_df.shape)

display(history_df.head())
# Out:
# Historial cargado:
# (260, 9)
#    n_qubits  epoch      loss  train_accuracy  train_balanced_accuracy  \
# 0         1      1  0.667498        0.782420                 0.785021
# 1         1      2  0.622156        0.785876                 0.787452
# 2         1      3  0.619596        0.784684                 0.786757
# 3         1      4  0.614741        0.787545                 0.789390
# 4         1      5  0.613012        0.789333                 0.790380
#
#    train_f1  test_accuracy  test_balanced_accuracy   test_f1
# 0  0.751243       0.785748                0.788515  0.752546
# 1  0.769724       0.791230                0.792850  0.774923
# 2  0.761597       0.792183                0.794327  0.768945
# 3  0.767919       0.795043                0.796887  0.776158
# 4  0.780175       0.798141                0.799193  0.789356

# %% [markdown]
# ## 10.3 — Curvas de Loss

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["loss"], label=f"Q{q}" )

plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.4 — Curvas de Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]

    plt.plot(subset["epoch"], subset["test_accuracy"], label=f"Q{q}")

plt.title("Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.5 — Curvas de Balanced Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(
    history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_balanced_accuracy"], label=f"Q{q}")

plt.title("Test Balanced Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Balanced Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.6 — Curvas de F1

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_f1"], label=f"Q{q}")

plt.title("Test F1")
plt.xlabel("Epoch")
plt.ylabel("F1")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.7 — Ranking final

# %%
metrics_summary_df = pd.read_csv(METRICS_PATH)

ranking_df = metrics_summary_df.sort_values(
    "test_balanced_accuracy",
    ascending=False
).reset_index(
    drop=True
)

print("\nRanking final")

display(ranking_df)
# Out:
# Ranking final
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         5        0.826460                 0.828384  0.809698       0.828646
# 1         4        0.822586                 0.824499  0.805565       0.827931
# 2         3        0.818534                 0.820162  0.804394       0.824833
# 3         2        0.812992                 0.814714  0.797287       0.819828
# 4         1        0.788200                 0.789054  0.781373       0.799571
#
#    test_balanced_accuracy   test_f1  \
# 0                0.830701  0.810640
# 1                0.829981  0.809900
# 2                0.826550  0.810225
# 3                0.821636  0.803738
# 4                0.800419  0.793214
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...

# %% [markdown]
# ## 10.8 — Comparación visual Q1–Q5

# %%
plt.figure(figsize=(10, 5))
x = np.arange(len(ranking_df))
width = 0.25
plt.bar(x - width, ranking_df["test_accuracy"], width=width, label="Accuracy")
plt.bar(x, ranking_df["test_balanced_accuracy"], width=width, label="Balanced Accuracy")
plt.bar(x + width, ranking_df["test_f1"], width=width, label="F1")
plt.xticks(x, [f"Q{q}" for q in ranking_df["n_qubits"]])
plt.ylabel("Score")
plt.title("Comparación Final Q1–Q5")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.9 — Matriz de confusión del mejor modelo

# %%
best_q = int(ranking_df.iloc[0]["n_qubits"])
print("\nMejor modelo: Q", best_q)
best_predictions = predictions_df[(predictions_df["n_qubits"] == best_q) & (predictions_df["split"] == "test")]

cm = confusion_matrix(best_predictions["y_true"], best_predictions["y_pred_05"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title(f"Confusion Matrix - Q{best_q}")
plt.show()
# Out:
# Mejor modelo: Q 5

# %% [markdown]
# ## 10.10 — Resumen final

# %%
best_row = ranking_df.iloc[0]
print("\n" + "=" * 80)
print("MEJOR MODELO")
print("=" * 80)
print("Qubits:", int(best_row["n_qubits"]))
print("Test Accuracy:",  round(best_row["test_accuracy"], 6))
print("Test Balanced Accuracy:", round(best_row["test_balanced_accuracy"], 6))
print("Test F1:", round(best_row["test_f1"], 6))
print("\nCheckpoint:")
print(CHECKPOINT_PATHS[int(best_row["n_qubits"])])
print("\nNotebook finalizado.")
# Out:
# ================================================================================
# MEJOR MODELO
# ================================================================================
# Qubits: 5
# Test Accuracy: 0.828646
# Test Balanced Accuracy: 0.830701
# Test F1: 0.81064
#
# Checkpoint:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_AE_nonlinear_z3_fold0\best_dr_qnn_5q.pt
#
# Notebook finalizado.
