# %% [markdown]
# # **1**

# %%
import os
import json
import random
from datetime import datetime

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ## 1.1 — Carpetas base

# %%
BASE_DATA_DIR = r"C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold"

BASE_RESULTS_DIR = r"C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched"

os.makedirs(BASE_RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.2 — Selección del experimento

# %% [markdown]
# Métodos disponibles:
# - "PCA"
# - "ICA"
# - "AE_linear"
# - "AE_nonlinear"

# %%
METHOD = "ICA"
FOLD = 0
K = 3

METHOD_FILES = {
    "PCA": "PCA_z1_to_z15_stratified5.npz",
    "ICA": "ICA_z1_to_z15_stratified5.npz",
    "AE_linear": "AE_linear_z1_to_z15_stratified5.npz",
    "AE_nonlinear": "AE_nonlinear_z1_to_z15_stratified5.npz",
}

assert METHOD in METHOD_FILES, (f"METHOD inválido: {METHOD}. " f"Usa {list(METHOD_FILES.keys())}")
assert FOLD in [0, 1, 2, 3, 4], ("FOLD debe ser 0, 1, 2, 3 o 4")
assert K in [1, 2, 3], ("Para esta DR-QNN, K debe ser 1, 2 o 3")

DATA_PATH = os.path.join(BASE_DATA_DIR, METHOD_FILES[METHOD])

assert os.path.exists(DATA_PATH), (f"No existe el archivo: {DATA_PATH}")

# %% [markdown]
# ## 1.3 — Nombre del experimento

# %%
EXPERIMENT_NAME = (f"DR_QNN_BATCHED_{METHOD}_z{K}_fold{FOLD}")
RESULTS_DIR = os.path.join(BASE_RESULTS_DIR, EXPERIMENT_NAME)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.4 — Configuración del dataset

# %%
USE_SUBSET = False
N_TRAIN_QML = 200
N_TEST_QML = 120
SUBSET_RANDOM_STATE = 123

# %% [markdown]
# ## 1.5 — Configuración DR-QNN

# %%
N_LAYERS = 6
QUBITS_LIST = [1, 2, 3, 4, 5]
assert QUBITS_LIST == [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1.6 — Configuración de rapidez tipo MS-HQCNN

# %%
USE_VECTORIZED_QNODE = True
BATCH_SIZE = None
CHUNK_SAMPLES = 131072
assert CHUNK_SAMPLES > 0

# %% [markdown]
# ## 1.7 — Entrenamiento

# %%
EPOCHS_1Q = 60
EPOCHS_NQ = 50
LR_1Q = 0.1
LR_NQ = 0.05

# %% [markdown]
# ## 1.8 — Backend cuántico

# %%
QML_DEVICE_NAME = "default.qubit.torch"
SHOTS = None
assert QML_DEVICE_NAME in ["default.qubit", "default.qubit.torch"]

# %% [markdown]
# ## 1.9 — Reproducibilidad

# %%
GLOBAL_SEED = 42

def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_global_seed(GLOBAL_SEED)

# %% [markdown]
# ## 1.10 — Dispositivo PyTorch

# %%
TORCH_DEVICE = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(TORCH_DEVICE)
# Out:
# cuda

# %% [markdown]
# ## 1.11 — Rutas de guardado

# %%
CONFIG_PATH = os.path.join(RESULTS_DIR, "config.json")
LOAD_SUMMARY_PATH = os.path.join(RESULTS_DIR, "load_summary.json")
METRICS_PATH = os.path.join(RESULTS_DIR, "metrics_summary.csv")
PREDICTIONS_PATH = os.path.join(RESULTS_DIR, "predictions.csv")
CHECKPOINT_1Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_1q.pt")
CHECKPOINT_2Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_2q.pt")
CHECKPOINT_3Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_3q.pt")
CHECKPOINT_4Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_4q.pt")
CHECKPOINT_5Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_5q.pt")

# %% [markdown]
# ## 1.12 — Guardar configuración

# %%
CONFIG = {"experiment_name": EXPERIMENT_NAME, "method": METHOD, "fold": FOLD, "k": K, "data_path": DATA_PATH, "results_dir": RESULTS_DIR, "use_subset": USE_SUBSET, "n_train_qml": N_TRAIN_QML, "n_test_qml": N_TEST_QML, "subset_random_state": SUBSET_RANDOM_STATE, "n_layers": N_LAYERS, "qubits_list": QUBITS_LIST, "use_vectorized_qnode": USE_VECTORIZED_QNODE, "batch_size": BATCH_SIZE, "chunk_samples": CHUNK_SAMPLES, "epochs_1q": EPOCHS_1Q, "epochs_nq": EPOCHS_NQ, "lr_1q": LR_1Q, "lr_nq": LR_NQ, "qml_device_name": QML_DEVICE_NAME, "shots": SHOTS, "global_seed": GLOBAL_SEED, "torch_device": TORCH_DEVICE, "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),}

with open(CONFIG_PATH, "w", encoding="utf-8") as f:
    json.dump(CONFIG, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## 1.13 — Resumen

# %%
print("=" * 80)
print("CONFIGURACIÓN DEL EXPERIMENTO")
print("=" * 80)
print("METHOD:", METHOD)
print("FOLD:", FOLD)
print("K:", K)
print("\nDATA_PATH:")
print(DATA_PATH)
print("\nRESULTS_DIR:")
print(RESULTS_DIR)
print("\nQUBITS_LIST:", QUBITS_LIST)
print("N_LAYERS:", N_LAYERS)
print("USE_VECTORIZED_QNODE:", USE_VECTORIZED_QNODE)
print("CHUNK_SAMPLES:", CHUNK_SAMPLES)
print("BATCH_SIZE:", BATCH_SIZE)
print("QML_DEVICE_NAME:", QML_DEVICE_NAME)
print("TORCH_DEVICE:", TORCH_DEVICE)
print("\nCONFIG_PATH:")
print(CONFIG_PATH)
# Out:
# ================================================================================
# CONFIGURACIÓN DEL EXPERIMENTO
# ================================================================================
# METHOD: ICA
# FOLD: 0
# K: 3
#
# DATA_PATH:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\ICA_z1_to_z15_stratified5.npz
#
# RESULTS_DIR:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0
#
# QUBITS_LIST: [1, 2, 3, 4, 5]
# N_LAYERS: 6
# USE_VECTORIZED_QNODE: True
# CHUNK_SAMPLES: 131072
# BATCH_SIZE: None
# QML_DEVICE_NAME: default.qubit.torch
# TORCH_DEVICE: cuda
#
# CONFIG_PATH:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\config.json

# %% [markdown]
# # **2**

# %% [markdown]
# ## 2.1 — Cargar archivo .npz

# %%
print("=" * 80)
print("CARGANDO DATASET")
print("=" * 80)

data = np.load(DATA_PATH, allow_pickle=True)

print("Archivo:")
print(DATA_PATH)

print("\nTotal de keys:", len(data.files))

print("\nPrimeras 20 keys:")
for key in data.files[:20]:
    print(key)
# Out:
# ================================================================================
# CARGANDO DATASET
# ================================================================================
# Archivo:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\ICA_z1_to_z15_stratified5.npz
#
# Total de keys: 211
#
# Primeras 20 keys:
# metadata
# fold0_train_idx
# fold0_test_idx
# fold0_y_train
# fold0_y_test
# fold0_z64_train
# fold0_z64_test
# fold0_scaler_mean
# fold0_scaler_scale
# fold0_ica_components
# fold0_ica_mixing
# fold0_ica_mean
# fold0_ica_n_iter
# fold0_z1_train
# fold0_z1_test
# fold0_z2_train
# fold0_z2_test
# fold0_z3_train
# fold0_z3_test
# fold0_z4_train

# %% [markdown]
# ## 2.2 — Leer metadata

# %%
if "metadata" in data.files:
    metadata = json.loads(str(data["metadata"].item()))
    print("\nMetadata:")
    for key, value in metadata.items():
        print(f"{key:30s}: {value}")

else:
    metadata = {}
    print("\nNo se encontró key 'metadata'.")
# Out:
# Metadata:
# method                        : ICA
# source_file                   : /content/drive/MyDrive/BCAM/distr_sol_pv_segm_embeddings_v2.npz
# x_key                         : features
# y_key                         : label
# original_dim                  : 64
# n_samples                     : 20976
# max_components                : 15
# n_splits                      : 5
# stratified                    : True
# random_state                  : 42
# created_time                  : 2026-06-22 11:12:54
# note                          : Transforms are fitted only on train data inside each fold. Test data is never used to fit scaler/PCA/ICA/AE.

# %% [markdown]
# ## 2.3 — Cargar fold y dimensión K con keys fijas

# %%
X_train = data[f"fold{FOLD}_z{K}_train"].astype(np.float32)
X_test = data[f"fold{FOLD}_z{K}_test"].astype(np.float32)
y_train = data[f"fold{FOLD}_y_train"].astype(int)
y_test = data[f"fold{FOLD}_y_test"].astype(int)

train_idx = data[f"fold{FOLD}_train_idx"]
test_idx = data[f"fold{FOLD}_test_idx"]

print("\nFold seleccionado:", FOLD)
print("Dimensión seleccionada K:", K)

print("\nShapes originales")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
print("train_idx:", train_idx.shape)
print("test_idx :", test_idx.shape)
# Out:
# Fold seleccionado: 0
# Dimensión seleccionada K: 3
#
# Shapes originales
# X_train: (16780, 3)
# X_test : (4196, 3)
# y_train: (16780,)
# y_test : (4196,)
# train_idx: (16780,)
# test_idx : (4196,)

# %% [markdown]
# ## 2.4 — Distribución de clases

# %%
print("\nDistribución TRAIN")
classes_train, counts_train = np.unique(y_train, return_counts=True)
for c, n in zip(classes_train, counts_train):
    print(f"Clase {c}: {n}")

print("\nDistribución TEST")
classes_test, counts_test = np.unique(y_test, return_counts=True)
for c, n in zip(classes_test, counts_test):
    print(f"Clase {c}: {n}")
# Out:
# Distribución TRAIN
# Clase 0: 8234
# Clase 1: 8546
#
# Distribución TEST
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 2.5 — Validaciones de consistencia

# %%
assert len(X_train) == len(y_train), ("X_train e y_train no tienen la misma longitud")
assert len(X_test) == len(y_test), ("X_test e y_test no tienen la misma longitud")
assert X_train.ndim == 2, ("X_train debe ser matriz 2D")
assert X_test.ndim == 2, ("X_test debe ser matriz 2D")
assert X_train.shape[1] == K, (f"X_train debería tener {K} columnas")
assert X_test.shape[1] == K, (f"X_test debería tener {K} columnas")
assert set(np.unique(y_train)).issubset({0, 1}), ("y_train debe contener clases 0/1")
assert set(np.unique(y_test)).issubset({0, 1}), ("y_test debe contener clases 0/1")
assert len(train_idx) == len(y_train), ("train_idx e y_train no tienen la misma longitud")
assert len(test_idx) == len(y_test), ("test_idx e y_test no tienen la misma longitud")

print("\nConsistencia OK")
# Out:
# Consistencia OK

# %% [markdown]
# ## 2.6 — Rangos de features originales

# %%
print("\nRangos TRAIN")
for i in range(K):
    col = X_train[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST")
for i in range(K):
    col = X_test[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN
# Feature 0: min=-5.534948 | max=8.918611 | mean=0.000000 | std=1.000000
# Feature 1: min=-7.992353 | max=8.438933 | mean=-0.000000 | std=1.000000
# Feature 2: min=-6.111025 | max=2.405781 | mean=0.000000 | std=1.000000
#
# Rangos TEST
# Feature 0: min=-5.175409 | max=15.403171 | mean=0.000650 | std=1.023754
# Feature 1: min=-7.278120 | max=6.369575 | mean=-0.025534 | std=0.989365
# Feature 2: min=-4.960086 | max=2.509907 | mean=-0.041483 | std=1.023430

# %% [markdown]
# ## 2.7 — Guardar resumen inicial de carga

# %%
initial_load_summary = {"method": METHOD, "fold": int(FOLD), "k": int(K), "data_path": DATA_PATH, "keys_count": len(data.files), "metadata": metadata, "x_train_shape": list(X_train.shape), "x_test_shape": list(X_test.shape), "y_train_shape": list(y_train.shape), "y_test_shape": list(y_test.shape), "train_idx_shape": list(train_idx.shape), "test_idx_shape": list(test_idx.shape), "train_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_train, counts_train)},
    "test_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_test, counts_test)},}

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen inicial de carga guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen inicial de carga guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **3**

# %% [markdown]
# ## 3.1 — Adaptación a qml.Rot(phi, theta, omega)

# %% [markdown]
# qml.Rot(phi, theta, omega) requiere 3 entradas:
# - K = 3: se deja igual
# - K = 2: agrega una columna de ceros
# - K = 1: agrega dos columnas de cerosm

# %%
def adapt_to_rot_dimension(X):

    X = np.asarray(X ,dtype=np.float32)
    if X.ndim != 2:
        raise ValueError(f"X debe ser matriz 2D, llegó {X.shape}")
    if X.shape[1] == 3:
        return X.astype(np.float32)
    if X.shape[1] == 2:
        zeros = np.zeros((len(X), 1), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    if X.shape[1] == 1:
        zeros = np.zeros((len(X), 2), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    raise ValueError(f"Dimensión no soportada: {X.shape[1]}")

# %% [markdown]
# ## 3.2 — Adaptar TRAIN y TEST

# %%
X_train_rot = adapt_to_rot_dimension(X_train)
X_test_rot = adapt_to_rot_dimension(X_test)

print("\nShapes adaptadas para qml.Rot")
print("X_train_rot:", X_train_rot.shape)
print("X_test_rot :", X_test_rot.shape)
# Out:
# Shapes adaptadas para qml.Rot
# X_train_rot: (16780, 3)
# X_test_rot : (4196, 3)

# %% [markdown]
# ## 3.3 — Validaciones

# %%
assert X_train_rot.ndim == 2
assert X_test_rot.ndim == 2

assert X_train_rot.shape[1] == 3
assert X_test_rot.shape[1] == 3

print("\nAdaptación K → 3 correcta")
# Out:
# Adaptación K → 3 correcta

# %% [markdown]
# ## 3.4 — Verificar padding

# %%
if K == 1:
    assert np.allclose(X_train_rot[:, 1:], 0.0)
    assert np.allclose(X_test_rot[:, 1:], 0.0)
    print("Padding validado para K=1")

if K == 2:
    assert np.allclose(X_train_rot[:, 2], 0.0)
    assert np.allclose(X_test_rot[:, 2], 0.0)
    print("Padding validado para K=2")

# %% [markdown]
# ## 3.5 — Vista rápida

# %%
preview_df = pd.DataFrame(X_train_rot[:10], columns=["phi", "theta", "omega"])
preview_df["label"] = y_train[:10]
display(preview_df)
# Out:
#         phi     theta     omega  label
# 0 -0.397706 -0.364123 -0.085191      0
# 1 -1.371887 -4.554296 -1.481168      1
# 2 -0.284660 -0.868760  0.874149      1
# 3  0.471320  4.044684  0.954215      1
# 4  0.067301 -0.570358 -0.601094      1
# 5  0.088536 -1.141051 -1.937466      0
# 6  0.556380 -0.986627  0.421960      0
# 7  0.795841 -0.702104  0.878058      1
# 8 -1.053104  0.465723  0.228884      0
# 9 -1.087287  0.250483  0.634717      0

# %% [markdown]
# ## 3.6 — Estadísticas después de la adaptación

# %%
print("\nRangos TRAIN adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN adaptado
#    phi: min=-5.534948 | max=8.918611 | mean=0.000000 | std=1.000000
#  theta: min=-7.992353 | max=8.438933 | mean=-0.000000 | std=1.000000
#  omega: min=-6.111025 | max=2.405781 | mean=0.000000 | std=1.000000
#
# Rangos TEST adaptado
#    phi: min=-5.175409 | max=15.403171 | mean=0.000650 | std=1.023754
#  theta: min=-7.278120 | max=6.369575 | mean=-0.025534 | std=0.989365
#  omega: min=-4.960086 | max=2.509907 | mean=-0.041483 | std=1.023430

# %% [markdown]
# ## 3.7 — Resumen

# %%
print("\nResumen adaptación")
print("K original:" ,K)
print("Dimensión final para DR-QNN:", X_train_rot.shape[1])
print("TRAIN:", X_train_rot.shape)
print("TEST :", X_test_rot.shape)
# Out:
# Resumen adaptación
# K original: 3
# Dimensión final para DR-QNN: 3
# TRAIN: (16780, 3)
# TEST : (4196, 3)

# %% [markdown]
# # **4**

# %% [markdown]
# ## 4.1 — Construir dataset que verá la DR-QNN

# %%
if USE_SUBSET:
    train_positions = np.arange(len(X_train_rot))
    test_positions = np.arange(len(X_test_rot))

    train_subset, _ = train_test_split(train_positions, train_size=N_TRAIN_QML, stratify=y_train, random_state=SUBSET_RANDOM_STATE)
    test_subset, _ = train_test_split(test_positions, train_size=N_TEST_QML, stratify=y_test, random_state=SUBSET_RANDOM_STATE)

    X_train_qml = X_train_rot[train_subset].copy()
    y_train_qml = y_train[train_subset].copy()

    X_test_qml = X_test_rot[test_subset].copy()
    y_test_qml = y_test[test_subset].copy()

    original_train_idx_qml = train_idx[train_subset].copy()
    original_test_idx_qml = test_idx[test_subset].copy()

else:
    X_train_qml = X_train_rot.copy()
    y_train_qml = y_train.copy()

    X_test_qml = X_test_rot.copy()
    y_test_qml = y_test.copy()

    original_train_idx_qml = train_idx.copy()
    original_test_idx_qml = test_idx.copy()

# %% [markdown]
# ## 4.2 — Validaciones del dataset QML

# %%
assert X_train_qml.ndim == 2
assert X_test_qml.ndim == 2

assert X_train_qml.shape[1] == 3
assert X_test_qml.shape[1] == 3

assert len(X_train_qml) == len(y_train_qml)
assert len(X_test_qml) == len(y_test_qml)

assert len(original_train_idx_qml) == len(y_train_qml)
assert len(original_test_idx_qml) == len(y_test_qml)

assert set(np.unique(y_train_qml)).issubset(
    {0, 1}
)

assert set(np.unique(y_test_qml)).issubset(
    {0, 1}
)

# %% [markdown]
# ## 4.3 — Resumen del dataset final

# %%
print("\nDataset que verá la DR-QNN")
print("X_train_qml:", X_train_qml.shape)
print("X_test_qml :", X_test_qml.shape)
print("\ny_train_qml:", y_train_qml.shape)
print("y_test_qml :", y_test_qml.shape)
print("\nÍndices originales:")
print("original_train_idx_qml:", original_train_idx_qml.shape)
print("original_test_idx_qml :", original_test_idx_qml.shape)

print("\nClases TRAIN QML:")
classes_train_qml, counts_train_qml = np.unique(y_train_qml, return_counts=True)
for c, n in zip(classes_train_qml, counts_train_qml):
    print(f"Clase {c}: {n}")

print("\nClases TEST QML:")
classes_test_qml, counts_test_qml = np.unique(y_test_qml, return_counts=True)
for c, n in zip(classes_test_qml, counts_test_qml):
    print(f"Clase {c}: {n}")
# Out:
# Dataset que verá la DR-QNN
# X_train_qml: (16780, 3)
# X_test_qml : (4196, 3)
#
# y_train_qml: (16780,)
# y_test_qml : (4196,)
#
# Índices originales:
# original_train_idx_qml: (16780,)
# original_test_idx_qml : (4196,)
#
# Clases TRAIN QML:
# Clase 0: 8234
# Clase 1: 8546
#
# Clases TEST QML:
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 4.4 — Definir tamaño de batch/chunk para entrenamiento

# %%
if BATCH_SIZE is None:
    TRAIN_BATCH_SIZE = len(X_train_qml)
    FULL_BATCH_TRAINING = True

else:
    TRAIN_BATCH_SIZE = BATCH_SIZE
    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE = CHUNK_SAMPLES

assert TRAIN_BATCH_SIZE > 0
assert EVAL_CHUNK_SIZE > 0

print("\nConfiguración de batches")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE:", TRAIN_BATCH_SIZE)
print("EVAL_CHUNK_SIZE :", EVAL_CHUNK_SIZE)
# Out:
# Configuración de batches
# FULL_BATCH_TRAINING: True
# TRAIN_BATCH_SIZE: 16780
# EVAL_CHUNK_SIZE : 131072

# %% [markdown]
# ## 4.5 — Función para generar batches de índices

# %%
def make_batch_indices(n_samples, batch_size, shuffle=True, seed=None):

    indices = np.arange(n_samples)

    if shuffle:
        rng = np.random.default_rng(seed)
        rng.shuffle(indices)
    batches = []

    for start in range(0,n_samples,batch_size):
        end = min(start + batch_size,n_samples)
        batches.append(indices[start:end])

    return batches

# %% [markdown]
# ## 4.6 — Sanity check de batches de entrenamiento

# %%
train_batches_preview = make_batch_indices(n_samples=len(X_train_qml) ,batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED)

print("\nNúmero de batches TRAIN por época:")
print(len(train_batches_preview))

print("\nPrimeros tamaños de batch:")

for b in train_batches_preview[:5]:
    print(len(b))

assert sum(len(b) for b in train_batches_preview) == len(X_train_qml)
# Out:
# Número de batches TRAIN por época:
# 1
#
# Primeros tamaños de batch:
# 16780

# %% [markdown]
# ## 4.7 — Función para iterar arrays NumPy por batches

# %%
def iter_numpy_batches(X, y=None, batch_size=1024, shuffle=False, seed=None):
    batches = make_batch_indices(n_samples=len(X), batch_size=batch_size, shuffle=shuffle, seed=seed)
    for batch_idx in batches:
        if y is None:
            yield X[batch_idx]
        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 4.8 — Sanity check de iterador NumPy

# %%
first_batch = next(iter_numpy_batches(X_train_qml, y_train_qml, batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED))
first_X_batch, first_y_batch = first_batch

print("\nPrimer batch NumPy")
print("X:", first_X_batch.shape)
print("y:", first_y_batch.shape)

assert first_X_batch.ndim == 2
assert first_X_batch.shape[1] == 3
assert len(first_X_batch) == len(first_y_batch)
# Out:
# Primer batch NumPy
# X: (16780, 3)
# y: (16780,)

# %% [markdown]
# ## 4.9 — Guardar resumen actualizado

# %%
initial_load_summary.update({
        "x_train_qml_shape": list(X_train_qml.shape),
        "x_test_qml_shape": list(X_test_qml.shape),
        "y_train_qml_shape": list(y_train_qml.shape),
        "y_test_qml_shape": list(y_test_qml.shape),
        "original_train_idx_qml_shape": list(original_train_idx_qml.shape),
        "original_test_idx_qml_shape": list(original_test_idx_qml.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size": int(TRAIN_BATCH_SIZE),
        "eval_chunk_size": int(EVAL_CHUNK_SIZE),
        "train_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_train_qml,counts_train_qml)},
        "test_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_test_qml,counts_test_qml)},
    })

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **5**

# %% [markdown]
# ## 5.1 — Dispositivo y tensorización

# %%
DEVICE = torch.device(TORCH_DEVICE)

X_train_t = torch.tensor(X_train_qml, dtype=torch.float32, device=DEVICE)
X_test_t = torch.tensor(X_test_qml, dtype=torch.float32, device=DEVICE)

y_train_t = torch.tensor(y_train_qml, dtype=torch.long, device=DEVICE)
y_test_t = torch.tensor(y_test_qml, dtype=torch.long, device=DEVICE)

y_train_float_t = y_train_t.float()
y_test_float_t = y_test_t.float()

print("DEVICE:", DEVICE)

print("\nTensores en memoria:")
print("X_train_t:", X_train_t.shape, X_train_t.dtype, X_train_t.device)
print("X_test_t :", X_test_t.shape, X_test_t.dtype, X_test_t.device)
print("y_train_t:", y_train_t.shape, y_train_t.dtype, y_train_t.device)
print("y_test_t :", y_test_t.shape, y_test_t.dtype, y_test_t.device)
# Out:
# DEVICE: cuda
#
# Tensores en memoria:
# X_train_t: torch.Size([16780, 3]) torch.float32 cuda:0
# X_test_t : torch.Size([4196, 3]) torch.float32 cuda:0
# y_train_t: torch.Size([16780]) torch.int64 cuda:0
# y_test_t : torch.Size([4196]) torch.int64 cuda:0

# %% [markdown]
# ## 5.2 — Validaciones para QNode batched

# %%
assert X_train_t.ndim == 2
assert X_test_t.ndim == 2

assert X_train_t.shape[1] == 3
assert X_test_t.shape[1] == 3

assert len(X_train_t) == len(y_train_t)
assert len(X_test_t) == len(y_test_t)

assert set(
    y_train_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

assert set(
    y_test_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

print("\nValidaciones tensoriales OK")
print("Entrada esperada por QNode batched: (B, 3)")
# Out:
# Validaciones tensoriales OK
# Entrada esperada por QNode batched: (B, 3)

# %% [markdown]
# ## 5.3 — Función de batches tensoriales

# %%
def make_tensor_batches(X, y=None, batch_size=None, shuffle=True, seed=None):
    n_samples = X.shape[0]
    
    if batch_size is None:
        batch_size = n_samples
    indices = torch.arange(n_samples, device=X.device)

    if shuffle:
        generator = torch.Generator(device=X.device)

        if seed is not None:
            generator.manual_seed(int(seed))

        indices = indices[torch.randperm(n_samples, generator=generator, device=X.device)]

    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        batch_idx = indices[start:end]

        if y is None:
            yield X[batch_idx]

        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 5.4 — Batch size efectivo para entrenamiento

# %%
if BATCH_SIZE is None:

    TRAIN_BATCH_SIZE_TORCH = len(X_train_t)

    FULL_BATCH_TRAINING = True

else:

    TRAIN_BATCH_SIZE_TORCH = int(BATCH_SIZE)

    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE_TORCH = int(
    CHUNK_SAMPLES
)

assert TRAIN_BATCH_SIZE_TORCH > 0
assert EVAL_CHUNK_SIZE_TORCH > 0

print("\nConfiguración batched final:")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)
print("EVAL_CHUNK_SIZE_TORCH :", EVAL_CHUNK_SIZE_TORCH)
# Out:
# Configuración batched final:
# FULL_BATCH_TRAINING: True
# TRAIN_BATCH_SIZE_TORCH: 16780
# EVAL_CHUNK_SIZE_TORCH : 131072

# %% [markdown]
# ## 5.5 — Sanity check del batch de entrenamiento

# %%
first_X_t, first_y_t = next(make_tensor_batches(X_train_t, y_train_float_t, batch_size=TRAIN_BATCH_SIZE_TORCH, shuffle=True, seed=GLOBAL_SEED))

print("\nPrimer batch Torch:")
print("X:", first_X_t.shape, first_X_t.dtype, first_X_t.device)
print("y:", first_y_t.shape, first_y_t.dtype, first_y_t.device)

assert first_X_t.ndim == 2
assert first_X_t.shape[1] == 3
assert len(first_X_t) == len(first_y_t)
# Out:
# Primer batch Torch:
# X: torch.Size([16780, 3]) torch.float32 cuda:0
# y: torch.Size([16780]) torch.float32 cuda:0

# %% [markdown]
# ## 5.6 — Sanity check de chunks de evaluación

# %%
first_eval_chunk = next(make_tensor_batches(X_test_t, y_test_float_t, batch_size=EVAL_CHUNK_SIZE_TORCH, shuffle=False, seed=None))
first_X_eval_t, first_y_eval_t = first_eval_chunk

print("\nPrimer chunk de evaluación:")
print("X:", first_X_eval_t.shape, first_X_eval_t.dtype, first_X_eval_t.device)
print("y:", first_y_eval_t.shape, first_y_eval_t.dtype, first_y_eval_t.device)

assert first_X_eval_t.ndim == 2
assert first_X_eval_t.shape[1] == 3
# Out:
# Primer chunk de evaluación:
# X: torch.Size([4196, 3]) torch.float32 cuda:0
# y: torch.Size([4196]) torch.float32 cuda:0

# %% [markdown]
# ## 5.7 — Resumen actualizado

# %%
initial_load_summary.update(
    {
        "torch_device": str(DEVICE),
        "x_train_t_shape": list(X_train_t.shape),
        "x_test_t_shape": list(X_test_t.shape),
        "y_train_t_shape": list(y_train_t.shape),
        "y_test_t_shape": list(y_test_t.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size_torch": int(TRAIN_BATCH_SIZE_TORCH),
        "eval_chunk_size_torch": int(EVAL_CHUNK_SIZE_TORCH),
        "qnode_expected_input_shape": "(B, 3)",
        "batched_qnode_required": bool(USE_VECTORIZED_QNODE),
    }
)

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nSección 5 lista.")
print("Los datos ya están en tensores y preparados para QNode batched.")
print("Resumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Sección 5 lista.
# Los datos ya están en tensores y preparados para QNode batched.
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **6**

# %% [markdown]
# ## 6.1 — Crear dispositivos cuánticos

# %%
def make_qml_device(n_qubits):

    if QML_DEVICE_NAME == "default.qubit.torch":
        return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS, torch_device=TORCH_DEVICE)

    return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

qml_devices = {}

for n_qubits in QUBITS_LIST:
    qml_devices[n_qubits] = make_qml_device(n_qubits)
print("Dispositivos creados:")

for n_qubits, dev in qml_devices.items():
    print(f"{n_qubits}Q:", dev)
# Out:
# Dispositivos creados:
# 1Q: Default qubit (Torch) PennyLane plugin
# Short name: default.qubit.torch
# Package: pennylane
# Plugin version: 0.37.0
# Author: Xanadu Inc.
# Wires: 1
# Shots: None
# 2Q: Default qubit (Torch) PennyLane plugin
# Short name: default.qubit.torch
# Package: pennylane
# Plugin version: 0.37.0
# Author: Xanadu Inc.
# Wires: 2
# Shots: None
# 3Q: Default qubit (Torch) PennyLane plugin
# Short name: default.qubit.torch
# Package: pennylane
# Plugin version: 0.37.0
# Author: Xanadu Inc.
# Wires: 3
# Shots: None
# 4Q: Default qubit (Torch) PennyLane plugin
# Short name: default.qubit.torch
# Package: pennylane
# Plugin version: 0.37.0
# Author: Xanadu Inc.
# Wires: 4
# Shots: None
# 5Q: Default qubit (Torch) PennyLane plugin
# Short name: default.qubit.torch
# Package: pennylane
# Plugin version: 0.37.0
# Author: Xanadu Inc.
# Wires: 5
# Shots: None

# %% [markdown]
# ## 6.2 — Bloques cuánticos básicos

# %%
def encode_data_reuploading_layer(X_batch, n_qubits):
    for q in range(n_qubits):
        qml.Rot(X_batch[:, 0], X_batch[:, 1], X_batch[:, 2], wires=q)


def apply_single_qubit_trainable_layer(theta_layer, n_qubits):
    for q in range(n_qubits):
        qml.Rot(theta_layer[q, 0], theta_layer[q, 1], theta_layer[q, 2], wires=q)


def apply_entangling_layer(phi_layer, n_qubits):
    if n_qubits == 1:
        return
    for s in range(n_qubits - 1):
        qml.ctrl(qml.Rot, control=s + 1)(phi_layer[s, 0], phi_layer[s, 1], phi_layer[s, 2], wires=s)

# %% [markdown]
# ## 6.3 — Constructor de QNode batched para n qubits

# %%
def make_batched_drqnn_qnode(n_qubits):
    dev = qml_devices[n_qubits]
    @qml.qnode(dev, interface="torch", diff_method="backprop")
    
    def qnode(X_batch, theta, phi):
        for layer in range(N_LAYERS):
            encode_data_reuploading_layer(X_batch, n_qubits)
            apply_single_qubit_trainable_layer(theta[layer], n_qubits)

            if n_qubits > 1:
                apply_entangling_layer(phi[layer], n_qubits)

        return qml.probs(wires=0)

    return qnode

# %% [markdown]
# ## 6.4 — Crear QNodes Q1 → Q5

# %%
batched_qnodes = {}

for n_qubits in QUBITS_LIST:
    batched_qnodes[n_qubits] = make_batched_drqnn_qnode(n_qubits)

print("\nQNodes batched creados:")

for n_qubits in batched_qnodes:
    print(f"{n_qubits}Q listo")
# Out:
# QNodes batched creados:
# 1Q listo
# 2Q listo
# 3Q listo
# 4Q listo
# 5Q listo

# %% [markdown]
# ## 6.5 — Inicializadores auxiliares de parámetros

# %%
def make_empty_theta(n_qubits, device=DEVICE):
    theta = torch.zeros(N_LAYERS, n_qubits, 3, dtype=torch.float32, device=device)
    return theta

def make_empty_phi(n_qubits, device=DEVICE):

    if n_qubits == 1:
        phi = torch.zeros(N_LAYERS, 1, 3, dtype=torch.float32, device=device)

    else:
        phi = torch.zeros(N_LAYERS, n_qubits - 1, 3, dtype=torch.float32, device=device)

    return phi

# %% [markdown]
# ## 6.6 — Sanity check batched de todos los QNodes

# %%
SANITY_BATCH_SIZE = min(8, len(X_train_t))
X_sanity = X_train_t[:SANITY_BATCH_SIZE]

print("\nSanity batch:")
print("X_sanity:", X_sanity.shape)

qnode_sanity_outputs = {}

with torch.no_grad():
    for n_qubits in QUBITS_LIST:
        theta_sanity = make_empty_theta(n_qubits)
        phi_sanity = make_empty_phi(n_qubits)
        probs = batched_qnodes[n_qubits](X_sanity, theta_sanity, phi_sanity)
        qnode_sanity_outputs[n_qubits] = probs

        print(f"{n_qubits}Q probs:", probs.shape, probs.device, probs.dtype)

        assert probs.ndim == 2
        assert probs.shape[0] == SANITY_BATCH_SIZE
        assert probs.shape[1] == 2

        expected = torch.ones_like(probs.sum(dim=1))

        assert torch.allclose(probs.sum(dim=1), expected, atol=1e-5)

print("\nSanity check Q1-Q5 OK")
# Out:
# Sanity batch:
# X_sanity: torch.Size([8, 3])
# 1Q probs: torch.Size([8, 2]) cuda:0 torch.float64
# 2Q probs: torch.Size([8, 2]) cuda:0 torch.float64
# 3Q probs: torch.Size([8, 2]) cuda:0 torch.float64
# 4Q probs: torch.Size([8, 2]) cuda:0 torch.float64
# 5Q probs: torch.Size([8, 2]) cuda:0 torch.float64
#
# Sanity check Q1-Q5 OK

# %% [markdown]
# ## 6.7 — Convención de salida

# %%
print("\nConvención de salida DR-QNN:")
print("probs[:, 0] = fidelidad/probabilidad asociada a clase 0")
print("probs[:, 1] = score de clase 1")
print("pred = 1 si probs[:, 1] >= 0.5")

print("\nSección 6 lista.")
print("Los QNodes ya reciben batches X_batch con shape (B, 3).")
# Out:
# Convención de salida DR-QNN:
# probs[:, 0] = fidelidad/probabilidad asociada a clase 0
# probs[:, 1] = score de clase 1
# pred = 1 si probs[:, 1] >= 0.5
#
# Sección 6 lista.
# Los QNodes ya reciben batches X_batch con shape (B, 3).

# %%
probs.dtype
# Out:
# torch.float64

# %% [markdown]
# # **7**

# %% [markdown]
# ## 7.1 — Clase general DR-QNN batched

# %%
class BatchedDRQNN(nn.Module):

    def __init__(self, n_qubits, init_theta=None, init_phi=None):
        super().__init__()
        assert n_qubits in QUBITS_LIST
        self.n_qubits = n_qubits
        theta_shape = (N_LAYERS, n_qubits, 3)
        phi_shape = (N_LAYERS, max(n_qubits - 1, 1), 3)

        if init_theta is None:
            theta = 0.01 * torch.randn(theta_shape, dtype=torch.float32, device=DEVICE)
        else:
            theta = init_theta.detach().clone().float().to(DEVICE)
        if init_phi is None:
            phi = torch.zeros( phi_shape, dtype=torch.float32, device=DEVICE)
        else:
            phi = init_phi.detach().clone().float().to(DEVICE)
        assert theta.shape == theta_shape
        assert phi.shape == phi_shape

        self.theta = nn.Parameter(theta)
        self.phi = nn.Parameter(phi)
        self.qnode = batched_qnodes[n_qubits]


    def forward(self,X_batch):
        probs = self.qnode(X_batch, self.theta, self.phi)
        probs = probs.float()
        score_class1 = probs[:,1]
        return score_class1

    def predict_proba(self, X_batch):
        probs = self.qnode(X_batch, self.theta, self.phi)
        probs = probs.float()

        return probs

# %% [markdown]
# ## 7.2 — Funciones de transferencia Q(n) → Q(n+1)

# %%
def expand_theta_from_previous(
    previous_theta,
    new_n_qubits
):

    previous_theta = previous_theta.detach().clone().float().to(
        DEVICE
    )

    old_n_qubits = previous_theta.shape[1]

    assert new_n_qubits == old_n_qubits + 1

    new_theta = 0.01 * torch.randn(
        N_LAYERS,
        new_n_qubits,
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    new_theta[
        :,
        :old_n_qubits,
        :
    ] = previous_theta

    return new_theta


def expand_phi_from_previous(
    previous_phi,
    new_n_qubits
):

    previous_phi = previous_phi.detach().clone().float().to(
        DEVICE
    )

    new_phi = torch.zeros(
        N_LAYERS,
        max(new_n_qubits - 1, 1),
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    if new_n_qubits > 2:

        old_phi_width = previous_phi.shape[1]

        new_phi[
            :,
            :old_phi_width,
            :
        ] = previous_phi

    return new_phi


def make_next_model_from_previous(
    previous_model,
    new_n_qubits
):

    init_theta = expand_theta_from_previous(
        previous_model.theta,
        new_n_qubits
    )

    init_phi = expand_phi_from_previous(
        previous_model.phi,
        new_n_qubits
    )

    model = BatchedDRQNN(
        n_qubits=new_n_qubits,
        init_theta=init_theta,
        init_phi=init_phi
    )

    return model

# %% [markdown]
# ## 7.3 — Crear modelo inicial Q1

# %%
model_1q = BatchedDRQNN(
    n_qubits=1
)

print("Modelo Q1 creado")
print(model_1q)

print("\nParámetros Q1:")
for name, param in model_1q.named_parameters():

    print(
        name,
        tuple(param.shape),
        param.dtype,
        param.device,
        "requires_grad=",
        param.requires_grad
    )
# Out:
# Modelo Q1 creado
# BatchedDRQNN()
#
# Parámetros Q1:
# theta (6, 1, 3) torch.float32 cuda:0 requires_grad= True
# phi (6, 1, 3) torch.float32 cuda:0 requires_grad= True

# %% [markdown]
# ## 7.4 — Sanity check forward Q1

# %%
with torch.no_grad():

    q1_scores = model_1q(
        X_sanity
    )

    q1_probs = model_1q.predict_proba(
        X_sanity
    )

print("\nSanity forward Q1")
print("scores:", q1_scores.shape, q1_scores.dtype, q1_scores.device)
print("probs :", q1_probs.shape, q1_probs.dtype, q1_probs.device)

assert q1_scores.ndim == 1
assert q1_scores.shape[0] == SANITY_BATCH_SIZE
assert q1_scores.dtype == torch.float32

assert q1_probs.ndim == 2
assert q1_probs.shape == (
    SANITY_BATCH_SIZE,
    2
)
assert q1_probs.dtype == torch.float32
# Out:
# Sanity forward Q1
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.5 — Sanity check expansión Q1 → Q5

# %%
model_sanity = model_1q

sanity_models = {
    1: model_1q
}

for next_q in QUBITS_LIST[1:]:

    model_sanity = make_next_model_from_previous(
        model_sanity,
        next_q
    )

    sanity_models[next_q] = model_sanity

    with torch.no_grad():

        scores = model_sanity(
            X_sanity
        )

        probs = model_sanity.predict_proba(
            X_sanity
        )

    print(f"\nSanity modelo Q{next_q}")
    print("scores:", scores.shape, scores.dtype, scores.device)
    print("probs :", probs.shape, probs.dtype, probs.device)

    assert scores.ndim == 1
    assert scores.shape[0] == SANITY_BATCH_SIZE
    assert scores.dtype == torch.float32

    assert probs.ndim == 2
    assert probs.shape == (
        SANITY_BATCH_SIZE,
        2
    )
    assert probs.dtype == torch.float32
# Out:
# Sanity modelo Q2
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q3
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q4
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q5
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.6 — Convención final del modelo

# %%
print("\nSección 7 lista.")
print("Cada modelo recibe X_batch con shape (B, 3).")
print("Cada forward devuelve scores clase 1 con shape (B,).")
print("predict_proba devuelve probs float32 con shape (B, 2).")
print("Los QNodes devuelven float64, pero el modelo convierte a float32.")
# Out:
# Sección 7 lista.
# Cada modelo recibe X_batch con shape (B, 3).
# Cada forward devuelve scores clase 1 con shape (B,).
# predict_proba devuelve probs float32 con shape (B, 2).
# Los QNodes devuelven float64, pero el modelo convierte a float32.

# %% [markdown]
# # **8**

# %% [markdown]
# ## 8.1 — Loss de fidelidad para clasificación binaria

# %%
def fidelity_loss_from_scores(scores_class1, y_batch):
    y_batch = y_batch.float()
    correct_prob = (y_batch * scores_class1 + (1.0 - y_batch) * (1.0 - scores_class1))
    loss = (1.0 - correct_prob).mean()
    return loss

# %% [markdown]
# ## 8.2 — Predicción batched sin evaluar muestra por muestra

# %%
@torch.no_grad()
def predict_scores_batched(model, X, chunk_size=131072):
    model.eval()
    scores_all = []
    for X_chunk in make_tensor_batches(X, y=None, batch_size=chunk_size, shuffle=False, seed=None):
        scores_chunk = model(X_chunk)
        scores_all.append(scores_chunk.detach().cpu())
    scores_all = torch.cat(scores_all, dim=0 ).numpy()

    return scores_all

# %% [markdown]
# ## 8.3 — Métricas binarias

# %%
def compute_binary_metrics(y_true, scores, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    scores = np.asarray(scores)
    y_pred = (scores >= threshold).astype(int)

    metrics = {"threshold": float(threshold), "accuracy": float( accuracy_score( y_true, y_pred)), "balanced_accuracy": float(balanced_accuracy_score( y_true, y_pred)), "f1": float(f1_score(y_true, y_pred)),
        "confusion_matrix": confusion_matrix(y_true, y_pred).tolist(),}

    return metrics

# %% [markdown]
# ## 8.4 — Evaluación completa batched

# %%
def evaluate_model(model, X, y, split_name, chunk_size=131072, threshold=0.5):
    scores = predict_scores_batched( model=model, X=X, chunk_size=chunk_size )
    y_np = y.detach().cpu().numpy()
    metrics = compute_binary_metrics( y_true=y_np, scores=scores, threshold=threshold)
    metrics["split"] = split_name
    metrics["n_samples"] = int(len(y_np))

    return metrics, scores

# %% [markdown]
# ## 8.5 — Entrenamiento de un modelo Qn

# %%
def train_drqnn_model(model, n_qubits, checkpoint_path):
    if n_qubits == 1:
        epochs = EPOCHS_1Q
        lr = LR_1Q
    else:
        epochs = EPOCHS_NQ
        lr = LR_NQ
    optimizer = optim.Adam(model.parameters(), lr=lr)

    best_test_bacc = -np.inf
    best_state = None

    history = []

    print("\nEntrenando DR-QNN")
    print("Qubits:", n_qubits)
    print("Epochs:", epochs)
    print("LR:", lr)
    print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)

    for epoch in range(1, epochs + 1):
        model.train()
        epoch_losses = []

        for X_batch, y_batch in make_tensor_batches(
            X_train_t,
            y_train_float_t,
            batch_size=TRAIN_BATCH_SIZE_TORCH,
            shuffle=True,
            seed=GLOBAL_SEED + epoch
        ):

            optimizer.zero_grad(set_to_none=True)
            scores = model(X_batch)
            loss = fidelity_loss_from_scores(scores, y_batch)
            loss.backward()
            optimizer.step()
            epoch_losses.append(float(loss.detach().cpu().item()))

        train_metrics, _ = evaluate_model(
            model=model,
            X=X_train_t,
            y=y_train_t,
            split_name="train",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        test_metrics, _ = evaluate_model(
            model=model,
            X=X_test_t,
            y=y_test_t,
            split_name="test",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        mean_loss = float(
            np.mean(epoch_losses)
        )

        row = {
            "n_qubits": int(n_qubits),
            "epoch": int(epoch),
            "loss": mean_loss,
            "train_accuracy": train_metrics["accuracy"],
            "train_balanced_accuracy": train_metrics["balanced_accuracy"],
            "train_f1": train_metrics["f1"],
            "test_accuracy": test_metrics["accuracy"],
            "test_balanced_accuracy": test_metrics["balanced_accuracy"],
            "test_f1": test_metrics["f1"],
        }

        history.append(
            row
        )

        print(
            f"Q{n_qubits} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={mean_loss:.6f} | "
            f"train_acc={train_metrics['accuracy']:.4f} | "
            f"test_acc={test_metrics['accuracy']:.4f} | "
            f"test_bAcc={test_metrics['balanced_accuracy']:.4f}"
        )

        if test_metrics["balanced_accuracy"] > best_test_bacc:

            best_test_bacc = test_metrics["balanced_accuracy"]

            best_state = {
                "n_qubits": int(n_qubits),
                "epoch": int(epoch),
                "model_state_dict": {
                    k: v.detach().cpu()
                    for k, v in model.state_dict().items()
                },
                "test_metrics": test_metrics,
                "train_metrics": train_metrics,
                "config": CONFIG,
            }

            torch.save(
                best_state,
                checkpoint_path
            )

    if best_state is not None:

        model.load_state_dict(
            {
                k: v.to(DEVICE)
                for k, v in best_state["model_state_dict"].items()
            }
        )

    history_df = pd.DataFrame(
        history
    )

    print("\nMejor test balanced accuracy:")
    print(best_test_bacc)

    print("Checkpoint guardado en:")
    print(checkpoint_path)

    return model, history_df

# %% [markdown]
# ## 8.6 — Rutas de checkpoints por número de qubits

# %%
CHECKPOINT_PATHS = {
    1: CHECKPOINT_1Q_PATH,
    2: CHECKPOINT_2Q_PATH,
    3: CHECKPOINT_3Q_PATH,
    4: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_4q.pt"
    ),
    5: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_5q.pt"
    ),
}

print("Sección 8 lista.")
print("Ya están definidas las funciones de loss, evaluación batched y entrenamiento.")
# Out:
# Sección 8 lista.
# Ya están definidas las funciones de loss, evaluación batched y entrenamiento.

# %% [markdown]
# # **9**

# %% [markdown]
# ## 9.1 — Entrenamiento progresivo Q1 → Q5

# %%
trained_models = {}
training_histories = {}
final_metrics_rows = {}
final_scores = {}

current_model = None

for n_qubits in QUBITS_LIST:
    print("\n" + "=" * 80)
    print(f"ENTRENAMIENTO PROGRESIVO Q{n_qubits}")
    print("=" * 80)
    if n_qubits == 1:
        current_model = BatchedDRQNN(n_qubits=1)
    else:
        current_model = make_next_model_from_previous(previous_model=current_model, new_n_qubits=n_qubits)

    checkpoint_path = CHECKPOINT_PATHS[n_qubits]
    current_model, history_df = train_drqnn_model(
        model=current_model,
        n_qubits=n_qubits,
        checkpoint_path=checkpoint_path
    )

    trained_models[n_qubits] = current_model
    training_histories[n_qubits] = history_df

    train_metrics, train_scores = evaluate_model(
        model=current_model,
        X=X_train_t,
        y=y_train_t,
        split_name="train",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    test_metrics, test_scores = evaluate_model(
        model=current_model,
        X=X_test_t,
        y=y_test_t,
        split_name="test",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    final_metrics_rows[n_qubits] = {
        "n_qubits": int(n_qubits),
        "train_accuracy": train_metrics["accuracy"],
        "train_balanced_accuracy": train_metrics["balanced_accuracy"],
        "train_f1": train_metrics["f1"],
        "test_accuracy": test_metrics["accuracy"],
        "test_balanced_accuracy": test_metrics["balanced_accuracy"],
        "test_f1": test_metrics["f1"],
        "checkpoint_path": checkpoint_path,
    }

    final_scores[n_qubits] = {
        "train_scores": train_scores,
        "test_scores": test_scores,
        "train_metrics": train_metrics,
        "test_metrics": test_metrics,
    }

    print("\nResultado final Q", n_qubits)
    print("TRAIN:", train_metrics)
    print("TEST :", test_metrics)
# Out:
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q1
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 1
# Epochs: 60
# LR: 0.1
# TRAIN_BATCH_SIZE_TORCH: 16780
# Q1 | Epoch 001/60 | loss=0.473666 | train_acc=0.5343 | test_acc=0.5415 | test_bAcc=0.5483
# Q1 | Epoch 002/60 | loss=0.467889 | train_acc=0.5344 | test_acc=0.5357 | test_bAcc=0.5426
# Q1 | Epoch 003/60 | loss=0.461069 | train_acc=0.5410 | test_acc=0.5443 | test_bAcc=0.5510
# Q1 | Epoch 004/60 | loss=0.451463 | train_acc=0.5568 | test_acc=0.5562 | test_bAcc=0.5625
# Q1 | Epoch 005/60 | loss=0.441580 | train_acc=0.5733 | test_acc=0.5663 | test_bAcc=0.5720
# Q1 | Epoch 006/60 | loss=0.434138 | train_acc=0.5868 | test_acc=0.5748 | test_bAcc=0.5800
# Q1 | Epoch 007/60 | loss=0.429132 | train_acc=0.5928 | test_acc=0.5820 | test_bAcc=0.5865
# Q1 | Epoch 008/60 | loss=0.424584 | train_acc=0.6013 | test_acc=0.5925 | test_bAcc=0.5967
# Q1 | Epoch 009/60 | loss=0.419164 | train_acc=0.6067 | test_acc=0.5991 | test_bAcc=0.6032
# Q1 | Epoch 010/60 | loss=0.413881 | train_acc=0.6132 | test_acc=0.6096 | test_bAcc=0.6136
# Q1 | Epoch 011/60 | loss=0.409896 | train_acc=0.6188 | test_acc=0.6199 | test_bAcc=0.6237
# Q1 | Epoch 012/60 | loss=0.407267 | train_acc=0.6232 | test_acc=0.6296 | test_bAcc=0.6334
# Q1 | Epoch 013/60 | loss=0.405291 | train_acc=0.6287 | test_acc=0.6387 | test_bAcc=0.6423
# Q1 | Epoch 014/60 | loss=0.403515 | train_acc=0.6319 | test_acc=0.6399 | test_bAcc=0.6434
# Q1 | Epoch 015/60 | loss=0.401820 | train_acc=0.6353 | test_acc=0.6416 | test_bAcc=0.6449
# Q1 | Epoch 016/60 | loss=0.400133 | train_acc=0.6368 | test_acc=0.6342 | test_bAcc=0.6374
# Q1 | Epoch 017/60 | loss=0.398305 | train_acc=0.6373 | test_acc=0.6368 | test_bAcc=0.6398
# Q1 | Epoch 018/60 | loss=0.396032 | train_acc=0.6415 | test_acc=0.6382 | test_bAcc=0.6412
# Q1 | Epoch 019/60 | loss=0.393075 | train_acc=0.6430 | test_acc=0.6442 | test_bAcc=0.6471
# Q1 | Epoch 020/60 | loss=0.389482 | train_acc=0.6492 | test_acc=0.6511 | test_bAcc=0.6540
# Q1 | Epoch 021/60 | loss=0.385608 | train_acc=0.6550 | test_acc=0.6568 | test_bAcc=0.6597
# Q1 | Epoch 022/60 | loss=0.381959 | train_acc=0.6585 | test_acc=0.6587 | test_bAcc=0.6616
# Q1 | Epoch 023/60 | loss=0.378957 | train_acc=0.6582 | test_acc=0.6602 | test_bAcc=0.6632
# Q1 | Epoch 024/60 | loss=0.376810 | train_acc=0.6604 | test_acc=0.6649 | test_bAcc=0.6681
# Q1 | Epoch 025/60 | loss=0.375519 | train_acc=0.6627 | test_acc=0.6649 | test_bAcc=0.6682
# Q1 | Epoch 026/60 | loss=0.374944 | train_acc=0.6624 | test_acc=0.6647 | test_bAcc=0.6681
# Q1 | Epoch 027/60 | loss=0.374853 | train_acc=0.6631 | test_acc=0.6597 | test_bAcc=0.6631
# Q1 | Epoch 028/60 | loss=0.374922 | train_acc=0.6647 | test_acc=0.6561 | test_bAcc=0.6596
# Q1 | Epoch 029/60 | loss=0.374819 | train_acc=0.6638 | test_acc=0.6561 | test_bAcc=0.6596
# Q1 | Epoch 030/60 | loss=0.374412 | train_acc=0.6645 | test_acc=0.6561 | test_bAcc=0.6595
# Q1 | Epoch 031/60 | loss=0.373885 | train_acc=0.6635 | test_acc=0.6566 | test_bAcc=0.6601
# Q1 | Epoch 032/60 | loss=0.373585 | train_acc=0.6617 | test_acc=0.6563 | test_bAcc=0.6599
# Q1 | Epoch 033/60 | loss=0.373656 | train_acc=0.6611 | test_acc=0.6585 | test_bAcc=0.6620
# Q1 | Epoch 034/60 | loss=0.373838 | train_acc=0.6611 | test_acc=0.6590 | test_bAcc=0.6626
# Q1 | Epoch 035/60 | loss=0.373719 | train_acc=0.6615 | test_acc=0.6585 | test_bAcc=0.6621
# Q1 | Epoch 036/60 | loss=0.373124 | train_acc=0.6603 | test_acc=0.6602 | test_bAcc=0.6638
# Q1 | Epoch 037/60 | loss=0.372204 | train_acc=0.6606 | test_acc=0.6590 | test_bAcc=0.6627
# Q1 | Epoch 038/60 | loss=0.371225 | train_acc=0.6616 | test_acc=0.6592 | test_bAcc=0.6629
# Q1 | Epoch 039/60 | loss=0.370340 | train_acc=0.6631 | test_acc=0.6613 | test_bAcc=0.6651
# Q1 | Epoch 040/60 | loss=0.369548 | train_acc=0.6622 | test_acc=0.6644 | test_bAcc=0.6681
# Q1 | Epoch 041/60 | loss=0.368832 | train_acc=0.6644 | test_acc=0.6666 | test_bAcc=0.6702
# Q1 | Epoch 042/60 | loss=0.368239 | train_acc=0.6658 | test_acc=0.6697 | test_bAcc=0.6733
# Q1 | Epoch 043/60 | loss=0.367808 | train_acc=0.6660 | test_acc=0.6709 | test_bAcc=0.6745
# Q1 | Epoch 044/60 | loss=0.367483 | train_acc=0.6664 | test_acc=0.6702 | test_bAcc=0.6738
# Q1 | Epoch 045/60 | loss=0.367169 | train_acc=0.6682 | test_acc=0.6671 | test_bAcc=0.6707
# Q1 | Epoch 046/60 | loss=0.366813 | train_acc=0.6700 | test_acc=0.6716 | test_bAcc=0.6751
# Q1 | Epoch 047/60 | loss=0.366414 | train_acc=0.6694 | test_acc=0.6694 | test_bAcc=0.6729
# Q1 | Epoch 048/60 | loss=0.366008 | train_acc=0.6680 | test_acc=0.6704 | test_bAcc=0.6739
# Q1 | Epoch 049/60 | loss=0.365603 | train_acc=0.6679 | test_acc=0.6704 | test_bAcc=0.6738
# Q1 | Epoch 050/60 | loss=0.365135 | train_acc=0.6678 | test_acc=0.6725 | test_bAcc=0.6759
# Q1 | Epoch 051/60 | loss=0.364512 | train_acc=0.6700 | test_acc=0.6714 | test_bAcc=0.6746
# Q1 | Epoch 052/60 | loss=0.363723 | train_acc=0.6711 | test_acc=0.6749 | test_bAcc=0.6780
# Q1 | Epoch 053/60 | loss=0.362849 | train_acc=0.6725 | test_acc=0.6785 | test_bAcc=0.6815
# Q1 | Epoch 054/60 | loss=0.361956 | train_acc=0.6736 | test_acc=0.6804 | test_bAcc=0.6833
# Q1 | Epoch 055/60 | loss=0.361030 | train_acc=0.6748 | test_acc=0.6826 | test_bAcc=0.6853
# Q1 | Epoch 056/60 | loss=0.359986 | train_acc=0.6765 | test_acc=0.6837 | test_bAcc=0.6863
# Q1 | Epoch 057/60 | loss=0.358743 | train_acc=0.6774 | test_acc=0.6861 | test_bAcc=0.6886
# Q1 | Epoch 058/60 | loss=0.357285 | train_acc=0.6791 | test_acc=0.6890 | test_bAcc=0.6914
# Q1 | Epoch 059/60 | loss=0.355699 | train_acc=0.6819 | test_acc=0.6878 | test_bAcc=0.6900
# Q1 | Epoch 060/60 | loss=0.354157 | train_acc=0.6840 | test_acc=0.6897 | test_bAcc=0.6919
#
# Mejor test balanced accuracy:
# 0.6918662670681439
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_1q.pt
#
# Resultado final Q 1
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6840286054827175, 'balanced_accuracy': 0.6862249310636046, 'f1': 0.6468158806288302, 'confusion_matrix': [[6623, 1611], [3691, 4855]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6897044804575786, 'balanced_accuracy': 0.6918662670681439, 'f1': 0.6539074960127592, 'confusion_matrix': [[1664, 395], [907, 1230]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q2
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 2
# Epochs: 50
# LR: 0.05
# TRAIN_BATCH_SIZE_TORCH: 16780
# Q2 | Epoch 001/50 | loss=0.352878 | train_acc=0.6849 | test_acc=0.6928 | test_bAcc=0.6950
# Q2 | Epoch 002/50 | loss=0.352133 | train_acc=0.6853 | test_acc=0.6902 | test_bAcc=0.6924
# Q2 | Epoch 003/50 | loss=0.350228 | train_acc=0.6854 | test_acc=0.6890 | test_bAcc=0.6912
# Q2 | Epoch 004/50 | loss=0.349496 | train_acc=0.6853 | test_acc=0.6897 | test_bAcc=0.6919
# Q2 | Epoch 005/50 | loss=0.348300 | train_acc=0.6857 | test_acc=0.6918 | test_bAcc=0.6941
# Q2 | Epoch 006/50 | loss=0.347624 | train_acc=0.6867 | test_acc=0.6892 | test_bAcc=0.6915
# Q2 | Epoch 007/50 | loss=0.347248 | train_acc=0.6865 | test_acc=0.6873 | test_bAcc=0.6896
# Q2 | Epoch 008/50 | loss=0.346630 | train_acc=0.6873 | test_acc=0.6854 | test_bAcc=0.6877
# Q2 | Epoch 009/50 | loss=0.346102 | train_acc=0.6865 | test_acc=0.6864 | test_bAcc=0.6886
# Q2 | Epoch 010/50 | loss=0.345848 | train_acc=0.6859 | test_acc=0.6866 | test_bAcc=0.6888
# Q2 | Epoch 011/50 | loss=0.345558 | train_acc=0.6868 | test_acc=0.6857 | test_bAcc=0.6879
# Q2 | Epoch 012/50 | loss=0.345192 | train_acc=0.6883 | test_acc=0.6845 | test_bAcc=0.6867
# Q2 | Epoch 013/50 | loss=0.344934 | train_acc=0.6883 | test_acc=0.6861 | test_bAcc=0.6884
# Q2 | Epoch 014/50 | loss=0.344793 | train_acc=0.6884 | test_acc=0.6888 | test_bAcc=0.6910
# Q2 | Epoch 015/50 | loss=0.344635 | train_acc=0.6883 | test_acc=0.6880 | test_bAcc=0.6903
# Q2 | Epoch 016/50 | loss=0.344432 | train_acc=0.6890 | test_acc=0.6888 | test_bAcc=0.6910
# Q2 | Epoch 017/50 | loss=0.344279 | train_acc=0.6901 | test_acc=0.6888 | test_bAcc=0.6911
# Q2 | Epoch 018/50 | loss=0.344218 | train_acc=0.6906 | test_acc=0.6880 | test_bAcc=0.6904
# Q2 | Epoch 019/50 | loss=0.344196 | train_acc=0.6910 | test_acc=0.6873 | test_bAcc=0.6897
# Q2 | Epoch 020/50 | loss=0.344183 | train_acc=0.6915 | test_acc=0.6864 | test_bAcc=0.6887
# Q2 | Epoch 021/50 | loss=0.344185 | train_acc=0.6918 | test_acc=0.6876 | test_bAcc=0.6899
# Q2 | Epoch 022/50 | loss=0.344168 | train_acc=0.6922 | test_acc=0.6878 | test_bAcc=0.6902
# Q2 | Epoch 023/50 | loss=0.344089 | train_acc=0.6912 | test_acc=0.6880 | test_bAcc=0.6904
# Q2 | Epoch 024/50 | loss=0.343978 | train_acc=0.6908 | test_acc=0.6888 | test_bAcc=0.6912
# Q2 | Epoch 025/50 | loss=0.343882 | train_acc=0.6912 | test_acc=0.6883 | test_bAcc=0.6907
# Q2 | Epoch 026/50 | loss=0.343794 | train_acc=0.6912 | test_acc=0.6883 | test_bAcc=0.6907
# Q2 | Epoch 027/50 | loss=0.343698 | train_acc=0.6913 | test_acc=0.6873 | test_bAcc=0.6898
# Q2 | Epoch 028/50 | loss=0.343607 | train_acc=0.6909 | test_acc=0.6888 | test_bAcc=0.6912
# Q2 | Epoch 029/50 | loss=0.343530 | train_acc=0.6910 | test_acc=0.6895 | test_bAcc=0.6919
# Q2 | Epoch 030/50 | loss=0.343454 | train_acc=0.6909 | test_acc=0.6899 | test_bAcc=0.6924
# Q2 | Epoch 031/50 | loss=0.343369 | train_acc=0.6910 | test_acc=0.6895 | test_bAcc=0.6919
# Q2 | Epoch 032/50 | loss=0.343276 | train_acc=0.6908 | test_acc=0.6888 | test_bAcc=0.6912
# Q2 | Epoch 033/50 | loss=0.343179 | train_acc=0.6908 | test_acc=0.6888 | test_bAcc=0.6912
# Q2 | Epoch 034/50 | loss=0.343078 | train_acc=0.6906 | test_acc=0.6897 | test_bAcc=0.6921
# Q2 | Epoch 035/50 | loss=0.342977 | train_acc=0.6906 | test_acc=0.6899 | test_bAcc=0.6923
# Q2 | Epoch 036/50 | loss=0.342883 | train_acc=0.6912 | test_acc=0.6897 | test_bAcc=0.6921
# Q2 | Epoch 037/50 | loss=0.342792 | train_acc=0.6915 | test_acc=0.6897 | test_bAcc=0.6921
# Q2 | Epoch 038/50 | loss=0.342677 | train_acc=0.6923 | test_acc=0.6909 | test_bAcc=0.6933
# Q2 | Epoch 039/50 | loss=0.342533 | train_acc=0.6922 | test_acc=0.6914 | test_bAcc=0.6937
# Q2 | Epoch 040/50 | loss=0.342380 | train_acc=0.6920 | test_acc=0.6899 | test_bAcc=0.6923
# Q2 | Epoch 041/50 | loss=0.342229 | train_acc=0.6916 | test_acc=0.6895 | test_bAcc=0.6918
# Q2 | Epoch 042/50 | loss=0.342085 | train_acc=0.6911 | test_acc=0.6895 | test_bAcc=0.6918
# Q2 | Epoch 043/50 | loss=0.341960 | train_acc=0.6908 | test_acc=0.6897 | test_bAcc=0.6920
# Q2 | Epoch 044/50 | loss=0.341841 | train_acc=0.6910 | test_acc=0.6899 | test_bAcc=0.6922
# Q2 | Epoch 045/50 | loss=0.341715 | train_acc=0.6908 | test_acc=0.6892 | test_bAcc=0.6915
# Q2 | Epoch 046/50 | loss=0.341588 | train_acc=0.6909 | test_acc=0.6890 | test_bAcc=0.6913
# Q2 | Epoch 047/50 | loss=0.341465 | train_acc=0.6912 | test_acc=0.6892 | test_bAcc=0.6915
# Q2 | Epoch 048/50 | loss=0.341346 | train_acc=0.6912 | test_acc=0.6897 | test_bAcc=0.6920
# Q2 | Epoch 049/50 | loss=0.341227 | train_acc=0.6910 | test_acc=0.6892 | test_bAcc=0.6915
# Q2 | Epoch 050/50 | loss=0.341103 | train_acc=0.6917 | test_acc=0.6897 | test_bAcc=0.6920
#
# Mejor test balanced accuracy:
# 0.694969958521237
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_2q.pt
#
# Resultado final Q 2
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6849225268176401, 'balanced_accuracy': 0.6870847992271006, 'f1': 0.6485408495645816, 'confusion_matrix': [[6615, 1619], [3668, 4878]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6928026692087702, 'balanced_accuracy': 0.694969958521237, 'f1': 0.6572720021270939, 'confusion_matrix': [[1671, 388], [901, 1236]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q3
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 3
# Epochs: 50
# LR: 0.05
# TRAIN_BATCH_SIZE_TORCH: 16780
# Q3 | Epoch 001/50 | loss=0.352133 | train_acc=0.6861 | test_acc=0.6902 | test_bAcc=0.6924
# Q3 | Epoch 002/50 | loss=0.352864 | train_acc=0.6843 | test_acc=0.6878 | test_bAcc=0.6900
# Q3 | Epoch 003/50 | loss=0.350424 | train_acc=0.6855 | test_acc=0.6916 | test_bAcc=0.6938
# Q3 | Epoch 004/50 | loss=0.348592 | train_acc=0.6860 | test_acc=0.6930 | test_bAcc=0.6952
# Q3 | Epoch 005/50 | loss=0.348499 | train_acc=0.6868 | test_acc=0.6947 | test_bAcc=0.6969
# Q3 | Epoch 006/50 | loss=0.348352 | train_acc=0.6874 | test_acc=0.6933 | test_bAcc=0.6955
# Q3 | Epoch 007/50 | loss=0.347144 | train_acc=0.6874 | test_acc=0.6916 | test_bAcc=0.6938
# Q3 | Epoch 008/50 | loss=0.346460 | train_acc=0.6867 | test_acc=0.6897 | test_bAcc=0.6919
# Q3 | Epoch 009/50 | loss=0.346487 | train_acc=0.6870 | test_acc=0.6897 | test_bAcc=0.6919
# Q3 | Epoch 010/50 | loss=0.346158 | train_acc=0.6875 | test_acc=0.6890 | test_bAcc=0.6912
# Q3 | Epoch 011/50 | loss=0.345480 | train_acc=0.6890 | test_acc=0.6864 | test_bAcc=0.6886
# Q3 | Epoch 012/50 | loss=0.344935 | train_acc=0.6895 | test_acc=0.6880 | test_bAcc=0.6902
# Q3 | Epoch 013/50 | loss=0.344624 | train_acc=0.6895 | test_acc=0.6873 | test_bAcc=0.6896
# Q3 | Epoch 014/50 | loss=0.344471 | train_acc=0.6885 | test_acc=0.6871 | test_bAcc=0.6893
# Q3 | Epoch 015/50 | loss=0.344349 | train_acc=0.6887 | test_acc=0.6873 | test_bAcc=0.6896
# Q3 | Epoch 016/50 | loss=0.344167 | train_acc=0.6883 | test_acc=0.6883 | test_bAcc=0.6906
# Q3 | Epoch 017/50 | loss=0.344054 | train_acc=0.6895 | test_acc=0.6892 | test_bAcc=0.6915
# Q3 | Epoch 018/50 | loss=0.344009 | train_acc=0.6895 | test_acc=0.6890 | test_bAcc=0.6913
# Q3 | Epoch 019/50 | loss=0.343884 | train_acc=0.6899 | test_acc=0.6890 | test_bAcc=0.6913
# Q3 | Epoch 020/50 | loss=0.343683 | train_acc=0.6905 | test_acc=0.6904 | test_bAcc=0.6927
# Q3 | Epoch 021/50 | loss=0.343474 | train_acc=0.6908 | test_acc=0.6902 | test_bAcc=0.6925
# Q3 | Epoch 022/50 | loss=0.343285 | train_acc=0.6914 | test_acc=0.6890 | test_bAcc=0.6914
# Q3 | Epoch 023/50 | loss=0.343143 | train_acc=0.6912 | test_acc=0.6890 | test_bAcc=0.6914
# Q3 | Epoch 024/50 | loss=0.343050 | train_acc=0.6908 | test_acc=0.6902 | test_bAcc=0.6926
# Q3 | Epoch 025/50 | loss=0.342985 | train_acc=0.6906 | test_acc=0.6902 | test_bAcc=0.6926
# Q3 | Epoch 026/50 | loss=0.342914 | train_acc=0.6909 | test_acc=0.6890 | test_bAcc=0.6914
# Q3 | Epoch 027/50 | loss=0.342796 | train_acc=0.6908 | test_acc=0.6890 | test_bAcc=0.6914
# Q3 | Epoch 028/50 | loss=0.342656 | train_acc=0.6915 | test_acc=0.6888 | test_bAcc=0.6911
# Q3 | Epoch 029/50 | loss=0.342550 | train_acc=0.6917 | test_acc=0.6897 | test_bAcc=0.6921
# Q3 | Epoch 030/50 | loss=0.342450 | train_acc=0.6915 | test_acc=0.6902 | test_bAcc=0.6926
# Q3 | Epoch 031/50 | loss=0.342321 | train_acc=0.6912 | test_acc=0.6899 | test_bAcc=0.6923
# Q3 | Epoch 032/50 | loss=0.342197 | train_acc=0.6913 | test_acc=0.6902 | test_bAcc=0.6926
# Q3 | Epoch 033/50 | loss=0.342104 | train_acc=0.6913 | test_acc=0.6923 | test_bAcc=0.6947
# Q3 | Epoch 034/50 | loss=0.342011 | train_acc=0.6916 | test_acc=0.6923 | test_bAcc=0.6947
# Q3 | Epoch 035/50 | loss=0.341889 | train_acc=0.6911 | test_acc=0.6930 | test_bAcc=0.6954
# Q3 | Epoch 036/50 | loss=0.341752 | train_acc=0.6915 | test_acc=0.6935 | test_bAcc=0.6958
# Q3 | Epoch 037/50 | loss=0.341625 | train_acc=0.6918 | test_acc=0.6933 | test_bAcc=0.6956
# Q3 | Epoch 038/50 | loss=0.341492 | train_acc=0.6917 | test_acc=0.6933 | test_bAcc=0.6956
# Q3 | Epoch 039/50 | loss=0.341339 | train_acc=0.6919 | test_acc=0.6942 | test_bAcc=0.6966
# Q3 | Epoch 040/50 | loss=0.341182 | train_acc=0.6919 | test_acc=0.6935 | test_bAcc=0.6958
# Q3 | Epoch 041/50 | loss=0.341023 | train_acc=0.6926 | test_acc=0.6940 | test_bAcc=0.6963
# Q3 | Epoch 042/50 | loss=0.340857 | train_acc=0.6927 | test_acc=0.6945 | test_bAcc=0.6968
# Q3 | Epoch 043/50 | loss=0.340694 | train_acc=0.6928 | test_acc=0.6942 | test_bAcc=0.6965
# Q3 | Epoch 044/50 | loss=0.340549 | train_acc=0.6927 | test_acc=0.6947 | test_bAcc=0.6970
# Q3 | Epoch 045/50 | loss=0.340425 | train_acc=0.6930 | test_acc=0.6940 | test_bAcc=0.6963
# Q3 | Epoch 046/50 | loss=0.340318 | train_acc=0.6935 | test_acc=0.6942 | test_bAcc=0.6965
# Q3 | Epoch 047/50 | loss=0.340237 | train_acc=0.6933 | test_acc=0.6945 | test_bAcc=0.6968
# Q3 | Epoch 048/50 | loss=0.340168 | train_acc=0.6934 | test_acc=0.6949 | test_bAcc=0.6972
# Q3 | Epoch 049/50 | loss=0.340090 | train_acc=0.6934 | test_acc=0.6945 | test_bAcc=0.6967
# Q3 | Epoch 050/50 | loss=0.340012 | train_acc=0.6938 | test_acc=0.6954 | test_bAcc=0.6977
#
# Mejor test balanced accuracy:
# 0.6977032024168635
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_3q.pt
#
# Resultado final Q 3
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6938021454112038, 'balanced_accuracy': 0.6960195864685994, 'f1': 0.6573753000800213, 'confusion_matrix': [[6713, 1521], [3617, 4929]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6954242135367016, 'balanced_accuracy': 0.6977032024168635, 'f1': 0.6579229122055674, 'confusion_matrix': [[1689, 370], [908, 1229]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q4
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 4
# Epochs: 50
# LR: 0.05
# TRAIN_BATCH_SIZE_TORCH: 16780
# Q4 | Epoch 001/50 | loss=0.339953 | train_acc=0.6951 | test_acc=0.6976 | test_bAcc=0.6998
# Q4 | Epoch 002/50 | loss=0.342993 | train_acc=0.6948 | test_acc=0.6961 | test_bAcc=0.6982
# Q4 | Epoch 003/50 | loss=0.341983 | train_acc=0.6938 | test_acc=0.6949 | test_bAcc=0.6971
# Q4 | Epoch 004/50 | loss=0.341254 | train_acc=0.6934 | test_acc=0.6918 | test_bAcc=0.6942
# Q4 | Epoch 005/50 | loss=0.340994 | train_acc=0.6917 | test_acc=0.6902 | test_bAcc=0.6926
# Q4 | Epoch 006/50 | loss=0.340752 | train_acc=0.6915 | test_acc=0.6914 | test_bAcc=0.6937
# Q4 | Epoch 007/50 | loss=0.340762 | train_acc=0.6926 | test_acc=0.6926 | test_bAcc=0.6949
# Q4 | Epoch 008/50 | loss=0.340395 | train_acc=0.6933 | test_acc=0.6930 | test_bAcc=0.6953
# Q4 | Epoch 009/50 | loss=0.340010 | train_acc=0.6941 | test_acc=0.6952 | test_bAcc=0.6975
# Q4 | Epoch 010/50 | loss=0.339972 | train_acc=0.6945 | test_acc=0.6952 | test_bAcc=0.6974
# Q4 | Epoch 011/50 | loss=0.339999 | train_acc=0.6943 | test_acc=0.6957 | test_bAcc=0.6979
# Q4 | Epoch 012/50 | loss=0.339950 | train_acc=0.6945 | test_acc=0.6957 | test_bAcc=0.6979
# Q4 | Epoch 013/50 | loss=0.339795 | train_acc=0.6945 | test_acc=0.6971 | test_bAcc=0.6993
# Q4 | Epoch 014/50 | loss=0.339480 | train_acc=0.6955 | test_acc=0.6964 | test_bAcc=0.6986
# Q4 | Epoch 015/50 | loss=0.339221 | train_acc=0.6952 | test_acc=0.6945 | test_bAcc=0.6967
# Q4 | Epoch 016/50 | loss=0.339163 | train_acc=0.6945 | test_acc=0.6949 | test_bAcc=0.6972
# Q4 | Epoch 017/50 | loss=0.339178 | train_acc=0.6942 | test_acc=0.6952 | test_bAcc=0.6975
# Q4 | Epoch 018/50 | loss=0.339165 | train_acc=0.6948 | test_acc=0.6957 | test_bAcc=0.6979
# Q4 | Epoch 019/50 | loss=0.339092 | train_acc=0.6943 | test_acc=0.6966 | test_bAcc=0.6989
# Q4 | Epoch 020/50 | loss=0.338957 | train_acc=0.6942 | test_acc=0.6964 | test_bAcc=0.6986
# Q4 | Epoch 021/50 | loss=0.338867 | train_acc=0.6946 | test_acc=0.6961 | test_bAcc=0.6984
# Q4 | Epoch 022/50 | loss=0.338847 | train_acc=0.6950 | test_acc=0.6976 | test_bAcc=0.6998
# Q4 | Epoch 023/50 | loss=0.338808 | train_acc=0.6949 | test_acc=0.6978 | test_bAcc=0.7000
# Q4 | Epoch 024/50 | loss=0.338752 | train_acc=0.6948 | test_acc=0.6976 | test_bAcc=0.6998
# Q4 | Epoch 025/50 | loss=0.338695 | train_acc=0.6949 | test_acc=0.6973 | test_bAcc=0.6995
# Q4 | Epoch 026/50 | loss=0.338618 | train_acc=0.6952 | test_acc=0.6971 | test_bAcc=0.6993
# Q4 | Epoch 027/50 | loss=0.338555 | train_acc=0.6955 | test_acc=0.6969 | test_bAcc=0.6991
# Q4 | Epoch 028/50 | loss=0.338508 | train_acc=0.6955 | test_acc=0.6966 | test_bAcc=0.6988
# Q4 | Epoch 029/50 | loss=0.338459 | train_acc=0.6954 | test_acc=0.6969 | test_bAcc=0.6991
# Q4 | Epoch 030/50 | loss=0.338434 | train_acc=0.6949 | test_acc=0.6973 | test_bAcc=0.6995
# Q4 | Epoch 031/50 | loss=0.338404 | train_acc=0.6949 | test_acc=0.6978 | test_bAcc=0.7000
# Q4 | Epoch 032/50 | loss=0.338337 | train_acc=0.6951 | test_acc=0.6978 | test_bAcc=0.7000
# Q4 | Epoch 033/50 | loss=0.338276 | train_acc=0.6949 | test_acc=0.6973 | test_bAcc=0.6995
# Q4 | Epoch 034/50 | loss=0.338238 | train_acc=0.6948 | test_acc=0.6978 | test_bAcc=0.7000
# Q4 | Epoch 035/50 | loss=0.338210 | train_acc=0.6950 | test_acc=0.6980 | test_bAcc=0.7002
# Q4 | Epoch 036/50 | loss=0.338178 | train_acc=0.6951 | test_acc=0.6983 | test_bAcc=0.7005
# Q4 | Epoch 037/50 | loss=0.338124 | train_acc=0.6948 | test_acc=0.6983 | test_bAcc=0.7005
# Q4 | Epoch 038/50 | loss=0.338072 | train_acc=0.6951 | test_acc=0.6978 | test_bAcc=0.7000
# Q4 | Epoch 039/50 | loss=0.338039 | train_acc=0.6952 | test_acc=0.6976 | test_bAcc=0.6998
# Q4 | Epoch 040/50 | loss=0.338014 | train_acc=0.6957 | test_acc=0.6980 | test_bAcc=0.7002
# Q4 | Epoch 041/50 | loss=0.337995 | train_acc=0.6956 | test_acc=0.6973 | test_bAcc=0.6995
# Q4 | Epoch 042/50 | loss=0.337966 | train_acc=0.6952 | test_acc=0.6964 | test_bAcc=0.6986
# Q4 | Epoch 043/50 | loss=0.337931 | train_acc=0.6950 | test_acc=0.6959 | test_bAcc=0.6981
# Q4 | Epoch 044/50 | loss=0.337906 | train_acc=0.6948 | test_acc=0.6959 | test_bAcc=0.6981
# Q4 | Epoch 045/50 | loss=0.337881 | train_acc=0.6951 | test_acc=0.6957 | test_bAcc=0.6979
# Q4 | Epoch 046/50 | loss=0.337851 | train_acc=0.6952 | test_acc=0.6964 | test_bAcc=0.6986
# Q4 | Epoch 047/50 | loss=0.337823 | train_acc=0.6954 | test_acc=0.6966 | test_bAcc=0.6988
# Q4 | Epoch 048/50 | loss=0.337798 | train_acc=0.6951 | test_acc=0.6971 | test_bAcc=0.6993
# Q4 | Epoch 049/50 | loss=0.337775 | train_acc=0.6949 | test_acc=0.6964 | test_bAcc=0.6986
# Q4 | Epoch 050/50 | loss=0.337752 | train_acc=0.6951 | test_acc=0.6961 | test_bAcc=0.6984
#
# Mejor test balanced accuracy:
# 0.7004665593808117
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_4q.pt
#
# Resultado final Q 4
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6950536352800953, 'balanced_accuracy': 0.6972814853119391, 'f1': 0.658570761326483, 'confusion_matrix': [[6728, 1506], [3611, 4935]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6982840800762631, 'balanced_accuracy': 0.7004665593808117, 'f1': 0.6631186801490154, 'confusion_matrix': [[1684, 375], [891, 1246]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q5
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 5
# Epochs: 50
# LR: 0.05
# TRAIN_BATCH_SIZE_TORCH: 16780
# Q5 | Epoch 001/50 | loss=0.338124 | train_acc=0.6924 | test_acc=0.6899 | test_bAcc=0.6923
# Q5 | Epoch 002/50 | loss=0.345528 | train_acc=0.6946 | test_acc=0.6945 | test_bAcc=0.6968
# Q5 | Epoch 003/50 | loss=0.339927 | train_acc=0.6956 | test_acc=0.7007 | test_bAcc=0.7029
# Q5 | Epoch 004/50 | loss=0.341406 | train_acc=0.6949 | test_acc=0.6992 | test_bAcc=0.7014
# Q5 | Epoch 005/50 | loss=0.340671 | train_acc=0.6952 | test_acc=0.6976 | test_bAcc=0.6997
# Q5 | Epoch 006/50 | loss=0.339870 | train_acc=0.6940 | test_acc=0.6959 | test_bAcc=0.6981
# Q5 | Epoch 007/50 | loss=0.339982 | train_acc=0.6941 | test_acc=0.6942 | test_bAcc=0.6965
# Q5 | Epoch 008/50 | loss=0.339599 | train_acc=0.6937 | test_acc=0.6928 | test_bAcc=0.6951
# Q5 | Epoch 009/50 | loss=0.338901 | train_acc=0.6940 | test_acc=0.6945 | test_bAcc=0.6967
# Q5 | Epoch 010/50 | loss=0.338817 | train_acc=0.6949 | test_acc=0.6959 | test_bAcc=0.6981
# Q5 | Epoch 011/50 | loss=0.339077 | train_acc=0.6957 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 012/50 | loss=0.339029 | train_acc=0.6954 | test_acc=0.6964 | test_bAcc=0.6986
# Q5 | Epoch 013/50 | loss=0.338792 | train_acc=0.6959 | test_acc=0.6961 | test_bAcc=0.6984
# Q5 | Epoch 014/50 | loss=0.338658 | train_acc=0.6957 | test_acc=0.6957 | test_bAcc=0.6979
# Q5 | Epoch 015/50 | loss=0.338581 | train_acc=0.6961 | test_acc=0.6959 | test_bAcc=0.6981
# Q5 | Epoch 016/50 | loss=0.338398 | train_acc=0.6954 | test_acc=0.6969 | test_bAcc=0.6991
# Q5 | Epoch 017/50 | loss=0.338212 | train_acc=0.6947 | test_acc=0.6964 | test_bAcc=0.6986
# Q5 | Epoch 018/50 | loss=0.338242 | train_acc=0.6946 | test_acc=0.6976 | test_bAcc=0.6998
# Q5 | Epoch 019/50 | loss=0.338374 | train_acc=0.6948 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 020/50 | loss=0.338291 | train_acc=0.6952 | test_acc=0.6969 | test_bAcc=0.6991
# Q5 | Epoch 021/50 | loss=0.338055 | train_acc=0.6952 | test_acc=0.6973 | test_bAcc=0.6995
# Q5 | Epoch 022/50 | loss=0.337970 | train_acc=0.6954 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 023/50 | loss=0.338040 | train_acc=0.6957 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 024/50 | loss=0.338045 | train_acc=0.6952 | test_acc=0.6980 | test_bAcc=0.7003
# Q5 | Epoch 025/50 | loss=0.337952 | train_acc=0.6952 | test_acc=0.6983 | test_bAcc=0.7005
# Q5 | Epoch 026/50 | loss=0.337895 | train_acc=0.6951 | test_acc=0.6973 | test_bAcc=0.6996
# Q5 | Epoch 027/50 | loss=0.337907 | train_acc=0.6952 | test_acc=0.6961 | test_bAcc=0.6984
# Q5 | Epoch 028/50 | loss=0.337893 | train_acc=0.6952 | test_acc=0.6954 | test_bAcc=0.6977
# Q5 | Epoch 029/50 | loss=0.337823 | train_acc=0.6951 | test_acc=0.6954 | test_bAcc=0.6977
# Q5 | Epoch 030/50 | loss=0.337761 | train_acc=0.6949 | test_acc=0.6952 | test_bAcc=0.6974
# Q5 | Epoch 031/50 | loss=0.337738 | train_acc=0.6948 | test_acc=0.6954 | test_bAcc=0.6976
# Q5 | Epoch 032/50 | loss=0.337731 | train_acc=0.6953 | test_acc=0.6973 | test_bAcc=0.6995
# Q5 | Epoch 033/50 | loss=0.337730 | train_acc=0.6955 | test_acc=0.6973 | test_bAcc=0.6995
# Q5 | Epoch 034/50 | loss=0.337729 | train_acc=0.6955 | test_acc=0.6969 | test_bAcc=0.6990
# Q5 | Epoch 035/50 | loss=0.337694 | train_acc=0.6957 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 036/50 | loss=0.337626 | train_acc=0.6949 | test_acc=0.6969 | test_bAcc=0.6991
# Q5 | Epoch 037/50 | loss=0.337586 | train_acc=0.6946 | test_acc=0.6964 | test_bAcc=0.6986
# Q5 | Epoch 038/50 | loss=0.337599 | train_acc=0.6947 | test_acc=0.6961 | test_bAcc=0.6984
# Q5 | Epoch 039/50 | loss=0.337606 | train_acc=0.6948 | test_acc=0.6961 | test_bAcc=0.6984
# Q5 | Epoch 040/50 | loss=0.337575 | train_acc=0.6946 | test_acc=0.6969 | test_bAcc=0.6991
# Q5 | Epoch 041/50 | loss=0.337540 | train_acc=0.6951 | test_acc=0.6971 | test_bAcc=0.6993
# Q5 | Epoch 042/50 | loss=0.337519 | train_acc=0.6951 | test_acc=0.6969 | test_bAcc=0.6990
# Q5 | Epoch 043/50 | loss=0.337496 | train_acc=0.6948 | test_acc=0.6969 | test_bAcc=0.6990
# Q5 | Epoch 044/50 | loss=0.337473 | train_acc=0.6949 | test_acc=0.6966 | test_bAcc=0.6988
# Q5 | Epoch 045/50 | loss=0.337460 | train_acc=0.6947 | test_acc=0.6961 | test_bAcc=0.6983
# Q5 | Epoch 046/50 | loss=0.337449 | train_acc=0.6945 | test_acc=0.6959 | test_bAcc=0.6981
# Q5 | Epoch 047/50 | loss=0.337431 | train_acc=0.6946 | test_acc=0.6966 | test_bAcc=0.6988
# Q5 | Epoch 048/50 | loss=0.337408 | train_acc=0.6946 | test_acc=0.6966 | test_bAcc=0.6988
# Q5 | Epoch 049/50 | loss=0.337385 | train_acc=0.6948 | test_acc=0.6969 | test_bAcc=0.6990
# Q5 | Epoch 050/50 | loss=0.337366 | train_acc=0.6948 | test_acc=0.6966 | test_bAcc=0.6988
#
# Mejor test balanced accuracy:
# 0.7028860591947924
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Resultado final Q 5
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6955899880810489, 'balanced_accuracy': 0.6978612536274422, 'f1': 0.6582820444206583, 'confusion_matrix': [[6752, 1482], [3626, 4920]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.7006673021925643, 'balanced_accuracy': 0.7028860591947924, 'f1': 0.6650666666666667, 'confusion_matrix': [[1693, 366], [890, 1247]], 'split': 'test', 'n_samples': 4196}

# %% [markdown]
# ## 9.2 — Unir historiales de entrenamiento

# %%
history_all_df = pd.concat([df.assign(n_qubits=n_qubits)for n_qubits, df in training_histories.items()], ignore_index=True)
HISTORY_PATH = os.path.join(RESULTS_DIR, "training_history_q1_to_q5.csv")
history_all_df.to_csv(HISTORY_PATH, index=False)

print("\nHistorial completo guardado en:")
print(HISTORY_PATH)
# Out:
# Historial completo guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\training_history_q1_to_q5.csv

# %% [markdown]
# ## 9.3 — Tabla final de métricas

# %%
metrics_summary_df = pd.DataFrame(list(final_metrics_rows.values()))
metrics_summary_df = metrics_summary_df.sort_values("n_qubits").reset_index(drop=True)
metrics_summary_df.to_csv(METRICS_PATH, index=False)

print("\nResumen final de métricas:")
display(metrics_summary_df)

print("\nMétricas guardadas en:")
print(METRICS_PATH)
# Out:
# Resumen final de métricas:
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         1        0.684029                 0.686225  0.646816       0.689704
# 1         2        0.684923                 0.687085  0.648541       0.692803
# 2         3        0.693802                 0.696020  0.657375       0.695424
# 3         4        0.695054                 0.697281  0.658571       0.698284
# 4         5        0.695590                 0.697861  0.658282       0.700667
#
#    test_balanced_accuracy   test_f1  \
# 0                0.691866  0.653907
# 1                0.694970  0.657272
# 2                0.697703  0.657923
# 3                0.700467  0.663119
# 4                0.702886  0.665067
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# Métricas guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\metrics_summary.csv

# %% [markdown]
# ## 9.4 — Guardar predicciones/scores por split y número de qubits

# %%
prediction_rows = []

for n_qubits in QUBITS_LIST:
    train_scores = final_scores[n_qubits]["train_scores"]
    test_scores = final_scores[n_qubits]["test_scores"]

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_train_idx_qml, y_train_qml, train_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "train",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_test_idx_qml, y_test_qml, test_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "test",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

predictions_df = pd.DataFrame(prediction_rows)
predictions_df.to_csv(PREDICTIONS_PATH, index=False)

print("\nPredicciones guardadas en:")
print(PREDICTIONS_PATH)
# Out:
# Predicciones guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\predictions.csv

# %% [markdown]
# ## 9.5 — Guardar resumen final JSON

# %%
FINAL_SUMMARY_PATH = os.path.join(RESULTS_DIR, "final_summary.json")

final_summary = {
    "experiment_name": EXPERIMENT_NAME,
    "method": METHOD,
    "fold": int(FOLD),
    "k": int(K),
    "q_list": [
        int(q)
        for q in QUBITS_LIST
    ],
    "data_path": DATA_PATH,
    "results_dir": RESULTS_DIR,
    "history_path": HISTORY_PATH,
    "metrics_path": METRICS_PATH,
    "predictions_path": PREDICTIONS_PATH,
    "checkpoints": {
        str(k): v
        for k, v in CHECKPOINT_PATHS.items()
    },
    "metrics_summary": metrics_summary_df.to_dict(orient="records"),
    "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
}

with open(FINAL_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(final_summary, f, indent=4, ensure_ascii=False)

print("\nResumen final guardado en:")
print(FINAL_SUMMARY_PATH)
# Out:
# Resumen final guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\final_summary.json

# %% [markdown]
# ## 9.6 — Seleccionar mejor modelo por test balanced accuracy

# %%
best_row = metrics_summary_df.loc[
    metrics_summary_df[
        "test_balanced_accuracy"
    ].idxmax()
]

BEST_N_QUBITS = int(
    best_row["n_qubits"]
)

BEST_CHECKPOINT_PATH = CHECKPOINT_PATHS[
    BEST_N_QUBITS
]

print("\nMejor modelo:")
print("Qubits:", BEST_N_QUBITS)
print("Test bAcc:", best_row["test_balanced_accuracy"])
print("Checkpoint:", BEST_CHECKPOINT_PATH)

print("\nSección 9 lista.")
print("Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.")
# Out:
# Mejor modelo:
# Qubits: 5
# Test bAcc: 0.7028860591947924
# Checkpoint: C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Sección 9 lista.
# Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.

# %% [markdown]
# # **10**

# %% [markdown]
# ## 10.1 — Imports para visualización

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    ConfusionMatrixDisplay,
    confusion_matrix
)

# %% [markdown]
# ## 10.2 — Cargar historial completo

# %%
history_df = pd.read_csv(HISTORY_PATH)

print("Historial cargado:")
print(history_df.shape)

display(history_df.head())
# Out:
# Historial cargado:
# (260, 9)
#    n_qubits  epoch      loss  train_accuracy  train_balanced_accuracy  \
# 0         1      1  0.473666        0.534267                 0.541026
# 1         1      2  0.467889        0.534386                 0.541147
# 2         1      3  0.461069        0.541001                 0.547595
# 3         1      4  0.451463        0.556794                 0.562986
# 4         1      5  0.441580        0.573302                 0.578940
#
#    train_f1  test_accuracy  test_balanced_accuracy   test_f1
# 0  0.279657       0.541468                0.548259  0.288987
# 1  0.279709       0.535748                0.542572  0.277984
# 2  0.299818       0.544328                0.550986  0.301170
# 3  0.345738       0.556244                0.562499  0.341584
# 4  0.396900       0.566254                0.571998  0.381793

# %% [markdown]
# ## 10.3 — Curvas de Loss

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["loss"], label=f"Q{q}" )

plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.4 — Curvas de Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]

    plt.plot(subset["epoch"], subset["test_accuracy"], label=f"Q{q}")

plt.title("Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.5 — Curvas de Balanced Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(
    history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_balanced_accuracy"], label=f"Q{q}")

plt.title("Test Balanced Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Balanced Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.6 — Curvas de F1

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_f1"], label=f"Q{q}")

plt.title("Test F1")
plt.xlabel("Epoch")
plt.ylabel("F1")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.7 — Ranking final

# %%
metrics_summary_df = pd.read_csv(METRICS_PATH)

ranking_df = metrics_summary_df.sort_values(
    "test_balanced_accuracy",
    ascending=False
).reset_index(
    drop=True
)

print("\nRanking final")

display(ranking_df)
# Out:
# Ranking final
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         5        0.695590                 0.697861  0.658282       0.700667
# 1         4        0.695054                 0.697281  0.658571       0.698284
# 2         3        0.693802                 0.696020  0.657375       0.695424
# 3         2        0.684923                 0.687085  0.648541       0.692803
# 4         1        0.684029                 0.686225  0.646816       0.689704
#
#    test_balanced_accuracy   test_f1  \
# 0                0.702886  0.665067
# 1                0.700467  0.663119
# 2                0.697703  0.657923
# 3                0.694970  0.657272
# 4                0.691866  0.653907
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...

# %% [markdown]
# ## 10.8 — Comparación visual Q1–Q5

# %%
plt.figure(figsize=(10, 5))
x = np.arange(len(ranking_df))
width = 0.25
plt.bar(x - width, ranking_df["test_accuracy"], width=width, label="Accuracy")
plt.bar(x, ranking_df["test_balanced_accuracy"], width=width, label="Balanced Accuracy")
plt.bar(x + width, ranking_df["test_f1"], width=width, label="F1")
plt.xticks(x, [f"Q{q}" for q in ranking_df["n_qubits"]])
plt.ylabel("Score")
plt.title("Comparación Final Q1–Q5")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.9 — Matriz de confusión del mejor modelo

# %%
best_q = int(ranking_df.iloc[0]["n_qubits"])
print("\nMejor modelo: Q", best_q)
best_predictions = predictions_df[(predictions_df["n_qubits"] == best_q) & (predictions_df["split"] == "test")]

cm = confusion_matrix(best_predictions["y_true"], best_predictions["y_pred_05"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title(f"Confusion Matrix - Q{best_q}")
plt.show()
# Out:
# Mejor modelo: Q 5

# %% [markdown]
# ## 10.10 — Resumen final

# %%
best_row = ranking_df.iloc[0]
print("\n" + "=" * 80)
print("MEJOR MODELO")
print("=" * 80)
print("Qubits:", int(best_row["n_qubits"]))
print("Test Accuracy:",  round(best_row["test_accuracy"], 6))
print("Test Balanced Accuracy:", round(best_row["test_balanced_accuracy"], 6))
print("Test F1:", round(best_row["test_f1"], 6))
print("\nCheckpoint:")
print(CHECKPOINT_PATHS[int(best_row["n_qubits"])])
print("\nNotebook finalizado.")
# Out:
# ================================================================================
# MEJOR MODELO
# ================================================================================
# Qubits: 5
# Test Accuracy: 0.700667
# Test Balanced Accuracy: 0.702886
# Test F1: 0.665067
#
# Checkpoint:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Notebook finalizado.
