# %% [markdown]
# # **1**

# %%
import os
import json
import random
from datetime import datetime

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

import pennylane as qml

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ## 1.1 — Carpetas base

# %%
BASE_DATA_DIR = r"C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold"

BASE_RESULTS_DIR = r"C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched"

os.makedirs(BASE_RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.2 — Selección del experimento

# %% [markdown]
# Métodos disponibles:
# - "PCA"
# - "ICA"
# - "AE_linear"
# - "AE_nonlinear"

# %%
METHOD = "ICA"
FOLD = 0
K = 3

METHOD_FILES = {
    "PCA": "PCA_z1_to_z15_stratified5.npz",
    "ICA": "ICA_z1_to_z15_stratified5.npz",
    "AE_linear": "AE_linear_z1_to_z15_stratified5.npz",
    "AE_nonlinear": "AE_nonlinear_z1_to_z15_stratified5.npz",
}

assert METHOD in METHOD_FILES, (f"METHOD inválido: {METHOD}. " f"Usa {list(METHOD_FILES.keys())}")
assert FOLD in [0, 1, 2, 3, 4], ("FOLD debe ser 0, 1, 2, 3 o 4")
assert K in [1, 2, 3], ("Para esta DR-QNN, K debe ser 1, 2 o 3")

DATA_PATH = os.path.join(BASE_DATA_DIR, METHOD_FILES[METHOD])

assert os.path.exists(DATA_PATH), (f"No existe el archivo: {DATA_PATH}")

# %% [markdown]
# ## 1.3 — Nombre del experimento

# %%
EXPERIMENT_NAME = (f"DR_QNN_BATCHED_{METHOD}_z{K}_fold{FOLD}")
RESULTS_DIR = os.path.join(BASE_RESULTS_DIR, EXPERIMENT_NAME)
os.makedirs(RESULTS_DIR, exist_ok=True)

# %% [markdown]
# ## 1.4 — Configuración del dataset

# %%
USE_SUBSET = False
N_TRAIN_QML = 200
N_TEST_QML = 120
SUBSET_RANDOM_STATE = 123

# %% [markdown]
# ## 1.5 — Configuración DR-QNN

# %%
N_LAYERS = 6
QUBITS_LIST = [1, 2, 3, 4, 5]
assert QUBITS_LIST == [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1.6 — Configuración de rapidez tipo MS-HQCNN

# %%
USE_VECTORIZED_QNODE = True

# Mini-batches de entrenamiento.
BATCH_SIZE = 32

# Tamaño de bloque utilizado únicamente para evaluación/inferencia.
CHUNK_SAMPLES = 131072

assert BATCH_SIZE > 0
assert CHUNK_SAMPLES > 0

# %% [markdown]
# ## 1.7 — Entrenamiento

# %%
EPOCHS_1Q = 60
EPOCHS_NQ = 50

# Learning rate de la DR-QNN de un qubit.
LR_1Q = 0.006

# Al expandir el modelo, se utiliza una tasa menor para no destruir
# los parámetros heredados del modelo anterior.
LR_NQ = 0.003

# %% [markdown]
# ## 1.8 — Backend cuántico

# %%
QML_DEVICE_NAME = "default.qubit"
SHOTS = None
assert QML_DEVICE_NAME in ["default.qubit"]

# %% [markdown]
# ## 1.9 — Reproducibilidad

# %%
GLOBAL_SEED = 42

def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_global_seed(GLOBAL_SEED)

# %% [markdown]
# ## 1.10 — Dispositivo PyTorch

# %%
TORCH_DEVICE = ("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(TORCH_DEVICE)
# Out:
# cuda

# %% [markdown]
# ## 1.11 — Rutas de guardado

# %%
CONFIG_PATH = os.path.join(RESULTS_DIR, "config.json")
LOAD_SUMMARY_PATH = os.path.join(RESULTS_DIR, "load_summary.json")
METRICS_PATH = os.path.join(RESULTS_DIR, "metrics_summary.csv")
PREDICTIONS_PATH = os.path.join(RESULTS_DIR, "predictions.csv")
CHECKPOINT_1Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_1q.pt")
CHECKPOINT_2Q_PATH = os.path.join(RESULTS_DIR, "best_dr_qnn_2q.pt")
CHECKPOINT_3Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_3q.pt")
CHECKPOINT_4Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_4q.pt")
CHECKPOINT_5Q_PATH = os.path.join(RESULTS_DIR,"best_dr_qnn_5q.pt")

# %% [markdown]
# ## 1.12 — Guardar configuración

# %%
CONFIG = {"experiment_name": EXPERIMENT_NAME, "method": METHOD, "fold": FOLD, "k": K, "data_path": DATA_PATH, "results_dir": RESULTS_DIR, "use_subset": USE_SUBSET, "n_train_qml": N_TRAIN_QML, "n_test_qml": N_TEST_QML, "subset_random_state": SUBSET_RANDOM_STATE, "n_layers": N_LAYERS, "qubits_list": QUBITS_LIST, "use_vectorized_qnode": USE_VECTORIZED_QNODE, "batch_size": BATCH_SIZE, "chunk_samples": CHUNK_SAMPLES, "epochs_1q": EPOCHS_1Q, "epochs_nq": EPOCHS_NQ, "lr_1q": LR_1Q, "lr_nq": LR_NQ, "qml_device_name": QML_DEVICE_NAME, "shots": SHOTS, "global_seed": GLOBAL_SEED, "torch_device": TORCH_DEVICE, "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),}

with open(CONFIG_PATH, "w", encoding="utf-8") as f:
    json.dump(CONFIG, f, indent=4, ensure_ascii=False)

# %% [markdown]
# ## 1.13 — Resumen

# %%
print("=" * 80)
print("CONFIGURACIÓN DEL EXPERIMENTO")
print("=" * 80)
print("METHOD:", METHOD)
print("FOLD:", FOLD)
print("K:", K)
print("\nDATA_PATH:")
print(DATA_PATH)
print("\nRESULTS_DIR:")
print(RESULTS_DIR)
print("\nQUBITS_LIST:", QUBITS_LIST)
print("N_LAYERS:", N_LAYERS)
print("USE_VECTORIZED_QNODE:", USE_VECTORIZED_QNODE)
print("CHUNK_SAMPLES:", CHUNK_SAMPLES)
print("BATCH_SIZE:", BATCH_SIZE)
print("QML_DEVICE_NAME:", QML_DEVICE_NAME)
print("TORCH_DEVICE:", TORCH_DEVICE)
print("\nCONFIG_PATH:")
print(CONFIG_PATH)
# Out:
# ================================================================================
# CONFIGURACIÓN DEL EXPERIMENTO
# ================================================================================
# METHOD: ICA
# FOLD: 0
# K: 3
#
# DATA_PATH:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\ICA_z1_to_z15_stratified5.npz
#
# RESULTS_DIR:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0
#
# QUBITS_LIST: [1, 2, 3, 4, 5]
# N_LAYERS: 6
# USE_VECTORIZED_QNODE: True
# CHUNK_SAMPLES: 131072
# BATCH_SIZE: 32
# QML_DEVICE_NAME: default.qubit
# TORCH_DEVICE: cuda
#
# CONFIG_PATH:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\config.json

# %% [markdown]
# # **2**

# %% [markdown]
# ## 2.1 — Cargar archivo .npz

# %%
print("=" * 80)
print("CARGANDO DATASET")
print("=" * 80)

data = np.load(DATA_PATH, allow_pickle=True)

print("Archivo:")
print(DATA_PATH)

print("\nTotal de keys:", len(data.files))

print("\nPrimeras 20 keys:")
for key in data.files[:20]:
    print(key)
# Out:
# ================================================================================
# CARGANDO DATASET
# ================================================================================
# Archivo:
# C:\Users\lapic\datasets\z64_dimensionality_reduction_5fold\ICA_z1_to_z15_stratified5.npz
#
# Total de keys: 211
#
# Primeras 20 keys:
# metadata
# fold0_train_idx
# fold0_test_idx
# fold0_y_train
# fold0_y_test
# fold0_z64_train
# fold0_z64_test
# fold0_scaler_mean
# fold0_scaler_scale
# fold0_ica_components
# fold0_ica_mixing
# fold0_ica_mean
# fold0_ica_n_iter
# fold0_z1_train
# fold0_z1_test
# fold0_z2_train
# fold0_z2_test
# fold0_z3_train
# fold0_z3_test
# fold0_z4_train

# %% [markdown]
# ## 2.2 — Leer metadata

# %%
if "metadata" in data.files:
    metadata = json.loads(str(data["metadata"].item()))
    print("\nMetadata:")
    for key, value in metadata.items():
        print(f"{key:30s}: {value}")

else:
    metadata = {}
    print("\nNo se encontró key 'metadata'.")
# Out:
# Metadata:
# method                        : ICA
# source_file                   : /content/drive/MyDrive/BCAM/distr_sol_pv_segm_embeddings_v2.npz
# x_key                         : features
# y_key                         : label
# original_dim                  : 64
# n_samples                     : 20976
# max_components                : 15
# n_splits                      : 5
# stratified                    : True
# random_state                  : 42
# created_time                  : 2026-06-22 11:12:54
# note                          : Transforms are fitted only on train data inside each fold. Test data is never used to fit scaler/PCA/ICA/AE.

# %% [markdown]
# ## 2.3 — Cargar fold y dimensión K con keys fijas

# %%
X_train = data[f"fold{FOLD}_z{K}_train"].astype(np.float32)
X_test = data[f"fold{FOLD}_z{K}_test"].astype(np.float32)
y_train = data[f"fold{FOLD}_y_train"].astype(int)
y_test = data[f"fold{FOLD}_y_test"].astype(int)

train_idx = data[f"fold{FOLD}_train_idx"]
test_idx = data[f"fold{FOLD}_test_idx"]

print("\nFold seleccionado:", FOLD)
print("Dimensión seleccionada K:", K)

print("\nShapes originales")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
print("train_idx:", train_idx.shape)
print("test_idx :", test_idx.shape)
# Out:
# Fold seleccionado: 0
# Dimensión seleccionada K: 3
#
# Shapes originales
# X_train: (16780, 3)
# X_test : (4196, 3)
# y_train: (16780,)
# y_test : (4196,)
# train_idx: (16780,)
# test_idx : (4196,)

# %% [markdown]
# ## 2.4 — Distribución de clases

# %%
print("\nDistribución TRAIN")
classes_train, counts_train = np.unique(y_train, return_counts=True)
for c, n in zip(classes_train, counts_train):
    print(f"Clase {c}: {n}")

print("\nDistribución TEST")
classes_test, counts_test = np.unique(y_test, return_counts=True)
for c, n in zip(classes_test, counts_test):
    print(f"Clase {c}: {n}")
# Out:
# Distribución TRAIN
# Clase 0: 8234
# Clase 1: 8546
#
# Distribución TEST
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 2.5 — Validaciones de consistencia

# %%
assert len(X_train) == len(y_train), ("X_train e y_train no tienen la misma longitud")
assert len(X_test) == len(y_test), ("X_test e y_test no tienen la misma longitud")
assert X_train.ndim == 2, ("X_train debe ser matriz 2D")
assert X_test.ndim == 2, ("X_test debe ser matriz 2D")
assert X_train.shape[1] == K, (f"X_train debería tener {K} columnas")
assert X_test.shape[1] == K, (f"X_test debería tener {K} columnas")
assert set(np.unique(y_train)).issubset({0, 1}), ("y_train debe contener clases 0/1")
assert set(np.unique(y_test)).issubset({0, 1}), ("y_test debe contener clases 0/1")
assert len(train_idx) == len(y_train), ("train_idx e y_train no tienen la misma longitud")
assert len(test_idx) == len(y_test), ("test_idx e y_test no tienen la misma longitud")

print("\nConsistencia OK")
# Out:
# Consistencia OK

# %% [markdown]
# ## 2.6 — Rangos de features originales

# %%
print("\nRangos TRAIN")
for i in range(K):
    col = X_train[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST")
for i in range(K):
    col = X_test[:, i]
    print(
        f"Feature {i}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN
# Feature 0: min=-5.534948 | max=8.918611 | mean=0.000000 | std=1.000000
# Feature 1: min=-7.992353 | max=8.438933 | mean=-0.000000 | std=1.000000
# Feature 2: min=-6.111025 | max=2.405781 | mean=0.000000 | std=1.000000
#
# Rangos TEST
# Feature 0: min=-5.175409 | max=15.403171 | mean=0.000650 | std=1.023754
# Feature 1: min=-7.278120 | max=6.369575 | mean=-0.025534 | std=0.989365
# Feature 2: min=-4.960086 | max=2.509907 | mean=-0.041483 | std=1.023430

# %% [markdown]
# ## 2.7 — Guardar resumen inicial de carga

# %%
initial_load_summary = {"method": METHOD, "fold": int(FOLD), "k": int(K), "data_path": DATA_PATH, "keys_count": len(data.files), "metadata": metadata, "x_train_shape": list(X_train.shape), "x_test_shape": list(X_test.shape), "y_train_shape": list(y_train.shape), "y_test_shape": list(y_test.shape), "train_idx_shape": list(train_idx.shape), "test_idx_shape": list(test_idx.shape), "train_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_train, counts_train)},
    "test_class_distribution": {
        str(c): int(n)
        for c, n in zip(classes_test, counts_test)},}

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen inicial de carga guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen inicial de carga guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **3**

# %% [markdown]
# ## 3.1 — Adaptación a qml.Rot(phi, theta, omega)

# %% [markdown]
# qml.Rot(phi, theta, omega) requiere 3 entradas:
# - K = 3: se deja igual
# - K = 2: agrega una columna de ceros
# - K = 1: agrega dos columnas de cerosm

# %%
def adapt_to_rot_dimension(X):

    X = np.asarray(X ,dtype=np.float32)
    if X.ndim != 2:
        raise ValueError(f"X debe ser matriz 2D, llegó {X.shape}")
    if X.shape[1] == 3:
        return X.astype(np.float32)
    if X.shape[1] == 2:
        zeros = np.zeros((len(X), 1), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    if X.shape[1] == 1:
        zeros = np.zeros((len(X), 2), dtype=np.float32)
        return np.concatenate([X, zeros], axis=1).astype(np.float32)
    raise ValueError(f"Dimensión no soportada: {X.shape[1]}")

# %% [markdown]
# ## 3.2 — Adaptar TRAIN y TEST

# %%
# ============================================================
# Adaptación a tres ángulos + escalado angular
# ============================================================

X_train_rot_raw = adapt_to_rot_dimension(X_train)
X_test_rot_raw = adapt_to_rot_dimension(X_test)

# El escalador se ajusta exclusivamente con TRAIN.
# TEST solamente se transforma con los parámetros aprendidos en TRAIN.
ANGLE_MIN = -np.pi / 2
ANGLE_MAX = np.pi / 2

angle_scaler = MinMaxScaler(
    feature_range=(ANGLE_MIN, ANGLE_MAX)
)

X_train_rot = angle_scaler.fit_transform(
    X_train_rot_raw
).astype(np.float32)

X_test_rot = angle_scaler.transform(
    X_test_rot_raw
).astype(np.float32)

# Protección ante valores de TEST fuera del rango observado en TRAIN.
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

print("\nShapes adaptadas para qml.Rot")
print("X_train_rot:", X_train_rot.shape)
print("X_test_rot :", X_test_rot.shape)

print("\nIntervalo angular aplicado:")
print(f"[{ANGLE_MIN:.6f}, {ANGLE_MAX:.6f}]")

print("\nRangos finales TRAIN")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos finales TEST")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Shapes adaptadas para qml.Rot
# X_train_rot: (16780, 3)
# X_test_rot : (4196, 3)
#
# Intervalo angular aplicado:
# [-1.570796, 1.570796]
#
# Rangos finales TRAIN
#    phi: min=-1.570796 | max=1.570796 | mean=-0.367733 | std=0.217358
#  theta: min=-1.570796 | max=1.570796 | mean=-0.042692 | std=0.191196
#  omega: min=-1.570796 | max=1.570796 | mean=0.683377 | std=0.368870
#
# Rangos finales TEST
#    phi: min=-1.492648 | max=1.570796 | mean=-0.368061 | std=0.217180
#  theta: min=-1.434238 | max=1.175144 | mean=-0.047574 | std=0.189162
#  omega: min=-1.146249 | max=1.570796 | mean=0.668061 | std=0.377477

# %% [markdown]
# ## 3.3 — Validaciones

# %%
assert X_train_rot.ndim == 2
assert X_test_rot.ndim == 2

assert X_train_rot.shape[1] == 3
assert X_test_rot.shape[1] == 3

print("\nAdaptación K → 3 correcta")
# Out:
# Adaptación K → 3 correcta

# %% [markdown]
# ## 3.4 — Verificar padding

# %%
X_train_rot = np.clip(
    X_train_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

X_test_rot = np.clip(
    X_test_rot,
    ANGLE_MIN,
    ANGLE_MAX
).astype(np.float32)

# Restaurar explícitamente el padding usado por qml.Rot.
if K == 1:
    X_train_rot[:, 1:] = 0.0
    X_test_rot[:, 1:] = 0.0

elif K == 2:
    X_train_rot[:, 2] = 0.0
    X_test_rot[:, 2] = 0.0

# %% [markdown]
# ## 3.5 — Vista rápida

# %%
preview_df = pd.DataFrame(X_train_rot[:10], columns=["phi", "theta", "omega"])
preview_df["label"] = y_train[:10]
display(preview_df)
# Out:
#         phi     theta     omega  label
# 0 -0.454177 -0.112311  0.651952      0
# 1 -0.665923 -0.913454  0.137019      1
# 2 -0.429606 -0.208795  1.005824      1
# 3 -0.265287  0.730635  1.035358      1
# 4 -0.353104 -0.151742  0.461651      1
# 5 -0.348489 -0.260856 -0.031296      0
# 6 -0.246799 -0.231331  0.839025      0
# 7 -0.194750 -0.176931  1.007266      1
# 8 -0.596633  0.046352  0.767805      0
# 9 -0.604063  0.005199  0.917504      0

# %% [markdown]
# ## 3.6 — Estadísticas después de la adaptación

# %%
print("\nRangos TRAIN adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_train_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )

print("\nRangos TEST adaptado")
for i, name in enumerate(["phi", "theta", "omega"]):
    col = X_test_rot[:, i]
    print(
        f"{name:>6s}: "
        f"min={col.min():.6f} | "
        f"max={col.max():.6f} | "
        f"mean={col.mean():.6f} | "
        f"std={col.std():.6f}"
    )
# Out:
# Rangos TRAIN adaptado
#    phi: min=-1.570796 | max=1.570796 | mean=-0.367733 | std=0.217358
#  theta: min=-1.570796 | max=1.570796 | mean=-0.042692 | std=0.191196
#  omega: min=-1.570796 | max=1.570796 | mean=0.683377 | std=0.368870
#
# Rangos TEST adaptado
#    phi: min=-1.492648 | max=1.570796 | mean=-0.368061 | std=0.217180
#  theta: min=-1.434238 | max=1.175144 | mean=-0.047574 | std=0.189162
#  omega: min=-1.146249 | max=1.570796 | mean=0.668061 | std=0.377477

# %% [markdown]
# ## 3.7 — Resumen

# %%
print("\nResumen adaptación")
print("K original:" ,K)
print("Dimensión final para DR-QNN:", X_train_rot.shape[1])
print("TRAIN:", X_train_rot.shape)
print("TEST :", X_test_rot.shape)
# Out:
# Resumen adaptación
# K original: 3
# Dimensión final para DR-QNN: 3
# TRAIN: (16780, 3)
# TEST : (4196, 3)

# %% [markdown]
# # **4**

# %% [markdown]
# ## 4.1 — Construir dataset que verá la DR-QNN

# %%
if USE_SUBSET:
    train_positions = np.arange(len(X_train_rot))
    test_positions = np.arange(len(X_test_rot))

    train_subset, _ = train_test_split(train_positions, train_size=N_TRAIN_QML, stratify=y_train, random_state=SUBSET_RANDOM_STATE)
    test_subset, _ = train_test_split(test_positions, train_size=N_TEST_QML, stratify=y_test, random_state=SUBSET_RANDOM_STATE)

    X_train_qml = X_train_rot[train_subset].copy()
    y_train_qml = y_train[train_subset].copy()

    X_test_qml = X_test_rot[test_subset].copy()
    y_test_qml = y_test[test_subset].copy()

    original_train_idx_qml = train_idx[train_subset].copy()
    original_test_idx_qml = test_idx[test_subset].copy()

else:
    X_train_qml = X_train_rot.copy()
    y_train_qml = y_train.copy()

    X_test_qml = X_test_rot.copy()
    y_test_qml = y_test.copy()

    original_train_idx_qml = train_idx.copy()
    original_test_idx_qml = test_idx.copy()

# %% [markdown]
# ## 4.2 — Validaciones del dataset QML

# %%
assert X_train_qml.ndim == 2
assert X_test_qml.ndim == 2

assert X_train_qml.shape[1] == 3
assert X_test_qml.shape[1] == 3

assert len(X_train_qml) == len(y_train_qml)
assert len(X_test_qml) == len(y_test_qml)

assert len(original_train_idx_qml) == len(y_train_qml)
assert len(original_test_idx_qml) == len(y_test_qml)

assert set(np.unique(y_train_qml)).issubset(
    {0, 1}
)

assert set(np.unique(y_test_qml)).issubset(
    {0, 1}
)

# %% [markdown]
# ## 4.3 — Resumen del dataset final

# %%
print("\nDataset que verá la DR-QNN")
print("X_train_qml:", X_train_qml.shape)
print("X_test_qml :", X_test_qml.shape)
print("\ny_train_qml:", y_train_qml.shape)
print("y_test_qml :", y_test_qml.shape)
print("\nÍndices originales:")
print("original_train_idx_qml:", original_train_idx_qml.shape)
print("original_test_idx_qml :", original_test_idx_qml.shape)

print("\nClases TRAIN QML:")
classes_train_qml, counts_train_qml = np.unique(y_train_qml, return_counts=True)
for c, n in zip(classes_train_qml, counts_train_qml):
    print(f"Clase {c}: {n}")

print("\nClases TEST QML:")
classes_test_qml, counts_test_qml = np.unique(y_test_qml, return_counts=True)
for c, n in zip(classes_test_qml, counts_test_qml):
    print(f"Clase {c}: {n}")
# Out:
# Dataset que verá la DR-QNN
# X_train_qml: (16780, 3)
# X_test_qml : (4196, 3)
#
# y_train_qml: (16780,)
# y_test_qml : (4196,)
#
# Índices originales:
# original_train_idx_qml: (16780,)
# original_test_idx_qml : (4196,)
#
# Clases TRAIN QML:
# Clase 0: 8234
# Clase 1: 8546
#
# Clases TEST QML:
# Clase 0: 2059
# Clase 1: 2137

# %% [markdown]
# ## 4.4 — Definir tamaño de batch/chunk para entrenamiento

# %%
if BATCH_SIZE is None:
    TRAIN_BATCH_SIZE = len(X_train_qml)
    FULL_BATCH_TRAINING = True

else:
    TRAIN_BATCH_SIZE = BATCH_SIZE
    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE = CHUNK_SAMPLES

assert TRAIN_BATCH_SIZE > 0
assert EVAL_CHUNK_SIZE > 0

print("\nConfiguración de batches")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE:", TRAIN_BATCH_SIZE)
print("EVAL_CHUNK_SIZE :", EVAL_CHUNK_SIZE)
# Out:
# Configuración de batches
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE: 32
# EVAL_CHUNK_SIZE : 131072

# %% [markdown]
# ## 4.5 — Función para generar batches de índices

# %%
def make_batch_indices(n_samples, batch_size, shuffle=True, seed=None):

    indices = np.arange(n_samples)

    if shuffle:
        rng = np.random.default_rng(seed)
        rng.shuffle(indices)
    batches = []

    for start in range(0,n_samples,batch_size):
        end = min(start + batch_size,n_samples)
        batches.append(indices[start:end])

    return batches

# %% [markdown]
# ## 4.6 — Sanity check de batches de entrenamiento

# %%
train_batches_preview = make_batch_indices(n_samples=len(X_train_qml) ,batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED)

print("\nNúmero de batches TRAIN por época:")
print(len(train_batches_preview))

print("\nPrimeros tamaños de batch:")

for b in train_batches_preview[:5]:
    print(len(b))

assert sum(len(b) for b in train_batches_preview) == len(X_train_qml)
# Out:
# Número de batches TRAIN por época:
# 525
#
# Primeros tamaños de batch:
# 32
# 32
# 32
# 32
# 32

# %% [markdown]
# ## 4.7 — Función para iterar arrays NumPy por batches

# %%
def iter_numpy_batches(X, y=None, batch_size=1024, shuffle=False, seed=None):
    batches = make_batch_indices(n_samples=len(X), batch_size=batch_size, shuffle=shuffle, seed=seed)
    for batch_idx in batches:
        if y is None:
            yield X[batch_idx]
        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 4.8 — Sanity check de iterador NumPy

# %%
first_batch = next(iter_numpy_batches(X_train_qml, y_train_qml, batch_size=TRAIN_BATCH_SIZE, shuffle=True, seed=GLOBAL_SEED))
first_X_batch, first_y_batch = first_batch

print("\nPrimer batch NumPy")
print("X:", first_X_batch.shape)
print("y:", first_y_batch.shape)

assert first_X_batch.ndim == 2
assert first_X_batch.shape[1] == 3
assert len(first_X_batch) == len(first_y_batch)
# Out:
# Primer batch NumPy
# X: (32, 3)
# y: (32,)

# %% [markdown]
# ## 4.9 — Guardar resumen actualizado

# %%
initial_load_summary.update({
        "x_train_qml_shape": list(X_train_qml.shape),
        "x_test_qml_shape": list(X_test_qml.shape),
        "y_train_qml_shape": list(y_train_qml.shape),
        "y_test_qml_shape": list(y_test_qml.shape),
        "original_train_idx_qml_shape": list(original_train_idx_qml.shape),
        "original_test_idx_qml_shape": list(original_test_idx_qml.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size": int(TRAIN_BATCH_SIZE),
        "eval_chunk_size": int(EVAL_CHUNK_SIZE),
        "train_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_train_qml,counts_train_qml)},
        "test_qml_class_distribution": {
            str(c): int(n)
            for c, n in zip(classes_test_qml,counts_test_qml)},
    })

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nResumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **5**

# %% [markdown]
# ## 5.1 — Dispositivo y tensorización

# %%
DEVICE = torch.device(TORCH_DEVICE)

X_train_t = torch.tensor(X_train_qml, dtype=torch.float32, device=DEVICE)
X_test_t = torch.tensor(X_test_qml, dtype=torch.float32, device=DEVICE)

y_train_t = torch.tensor(y_train_qml, dtype=torch.long, device=DEVICE)
y_test_t = torch.tensor(y_test_qml, dtype=torch.long, device=DEVICE)

y_train_float_t = y_train_t.float()
y_test_float_t = y_test_t.float()

print("DEVICE:", DEVICE)

print("\nTensores en memoria:")
print("X_train_t:", X_train_t.shape, X_train_t.dtype, X_train_t.device)
print("X_test_t :", X_test_t.shape, X_test_t.dtype, X_test_t.device)
print("y_train_t:", y_train_t.shape, y_train_t.dtype, y_train_t.device)
print("y_test_t :", y_test_t.shape, y_test_t.dtype, y_test_t.device)
# Out:
# DEVICE: cuda
#
# Tensores en memoria:
# X_train_t: torch.Size([16780, 3]) torch.float32 cuda:0
# X_test_t : torch.Size([4196, 3]) torch.float32 cuda:0
# y_train_t: torch.Size([16780]) torch.int64 cuda:0
# y_test_t : torch.Size([4196]) torch.int64 cuda:0

# %% [markdown]
# ## 5.2 — Validaciones para QNode batched

# %%
assert X_train_t.ndim == 2
assert X_test_t.ndim == 2

assert X_train_t.shape[1] == 3
assert X_test_t.shape[1] == 3

assert len(X_train_t) == len(y_train_t)
assert len(X_test_t) == len(y_test_t)

assert set(
    y_train_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

assert set(
    y_test_t.detach().cpu().numpy().tolist()
).issubset({0, 1})

print("\nValidaciones tensoriales OK")
print("Entrada esperada por QNode batched: (B, 3)")
# Out:
# Validaciones tensoriales OK
# Entrada esperada por QNode batched: (B, 3)

# %% [markdown]
# ## 5.3 — Función de batches tensoriales

# %%
def make_tensor_batches(X, y=None, batch_size=None, shuffle=True, seed=None):
    n_samples = X.shape[0]
    
    if batch_size is None:
        batch_size = n_samples
    indices = torch.arange(n_samples, device=X.device)

    if shuffle:
        generator = torch.Generator(device=X.device)

        if seed is not None:
            generator.manual_seed(int(seed))

        indices = indices[torch.randperm(n_samples, generator=generator, device=X.device)]

    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        batch_idx = indices[start:end]

        if y is None:
            yield X[batch_idx]

        else:
            yield X[batch_idx], y[batch_idx]

# %% [markdown]
# ## 5.4 — Batch size efectivo para entrenamiento

# %%
if BATCH_SIZE is None:

    TRAIN_BATCH_SIZE_TORCH = len(X_train_t)

    FULL_BATCH_TRAINING = True

else:

    TRAIN_BATCH_SIZE_TORCH = int(BATCH_SIZE)

    FULL_BATCH_TRAINING = False

EVAL_CHUNK_SIZE_TORCH = int(
    CHUNK_SAMPLES
)

assert TRAIN_BATCH_SIZE_TORCH > 0
assert EVAL_CHUNK_SIZE_TORCH > 0

print("\nConfiguración batched final:")
print("FULL_BATCH_TRAINING:", FULL_BATCH_TRAINING)
print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)
print("EVAL_CHUNK_SIZE_TORCH :", EVAL_CHUNK_SIZE_TORCH)
# Out:
# Configuración batched final:
# FULL_BATCH_TRAINING: False
# TRAIN_BATCH_SIZE_TORCH: 32
# EVAL_CHUNK_SIZE_TORCH : 131072

# %% [markdown]
# ## 5.5 — Sanity check del batch de entrenamiento

# %%
first_X_t, first_y_t = next(make_tensor_batches(X_train_t, y_train_float_t, batch_size=TRAIN_BATCH_SIZE_TORCH, shuffle=True, seed=GLOBAL_SEED))

print("\nPrimer batch Torch:")
print("X:", first_X_t.shape, first_X_t.dtype, first_X_t.device)
print("y:", first_y_t.shape, first_y_t.dtype, first_y_t.device)

assert first_X_t.ndim == 2
assert first_X_t.shape[1] == 3
assert len(first_X_t) == len(first_y_t)
# Out:
# Primer batch Torch:
# X: torch.Size([32, 3]) torch.float32 cuda:0
# y: torch.Size([32]) torch.float32 cuda:0

# %% [markdown]
# ## 5.6 — Sanity check de chunks de evaluación

# %%
first_eval_chunk = next(make_tensor_batches(X_test_t, y_test_float_t, batch_size=EVAL_CHUNK_SIZE_TORCH, shuffle=False, seed=None))
first_X_eval_t, first_y_eval_t = first_eval_chunk

print("\nPrimer chunk de evaluación:")
print("X:", first_X_eval_t.shape, first_X_eval_t.dtype, first_X_eval_t.device)
print("y:", first_y_eval_t.shape, first_y_eval_t.dtype, first_y_eval_t.device)

assert first_X_eval_t.ndim == 2
assert first_X_eval_t.shape[1] == 3
# Out:
# Primer chunk de evaluación:
# X: torch.Size([4196, 3]) torch.float32 cuda:0
# y: torch.Size([4196]) torch.float32 cuda:0

# %% [markdown]
# ## 5.7 — Resumen actualizado

# %%
initial_load_summary.update(
    {
        "torch_device": str(DEVICE),
        "x_train_t_shape": list(X_train_t.shape),
        "x_test_t_shape": list(X_test_t.shape),
        "y_train_t_shape": list(y_train_t.shape),
        "y_test_t_shape": list(y_test_t.shape),
        "full_batch_training": bool(FULL_BATCH_TRAINING),
        "train_batch_size_torch": int(TRAIN_BATCH_SIZE_TORCH),
        "eval_chunk_size_torch": int(EVAL_CHUNK_SIZE_TORCH),
        "qnode_expected_input_shape": "(B, 3)",
        "batched_qnode_required": bool(USE_VECTORIZED_QNODE),
    }
)

with open(LOAD_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(initial_load_summary, f, indent=4, ensure_ascii=False)

print("\nSección 5 lista.")
print("Los datos ya están en tensores y preparados para QNode batched.")
print("Resumen actualizado guardado en:")
print(LOAD_SUMMARY_PATH)
# Out:
# Sección 5 lista.
# Los datos ya están en tensores y preparados para QNode batched.
# Resumen actualizado guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\load_summary.json

# %% [markdown]
# # **6**

# %% [markdown]
# ## 6.1 — Crear dispositivos cuánticos

# %%
def make_qml_device(n_qubits):

    if QML_DEVICE_NAME == "default.qubit":
        return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

    return qml.device(QML_DEVICE_NAME, wires=n_qubits, shots=SHOTS)

qml_devices = {}

for n_qubits in QUBITS_LIST:
    qml_devices[n_qubits] = make_qml_device(n_qubits)
print("Dispositivos creados:")

for n_qubits, dev in qml_devices.items():
    print(f"{n_qubits}Q:", dev)
# Out:
# Dispositivos creados:
# 1Q: <default.qubit device (wires=1) at 0x1eb3d90cf50>
# 2Q: <default.qubit device (wires=2) at 0x1eb3e51d4d0>
# 3Q: <default.qubit device (wires=3) at 0x1eb3e657cd0>
# 4Q: <default.qubit device (wires=4) at 0x1eb3e67cbd0>
# 5Q: <default.qubit device (wires=5) at 0x1eb3e67f590>

# %% [markdown]
# ## 6.2 — Bloques cuánticos básicos

# %%
def encode_data_reuploading_layer(X_batch, n_qubits):
    for q in range(n_qubits):
        qml.Rot(X_batch[:, 0], X_batch[:, 1], X_batch[:, 2], wires=q)


def apply_single_qubit_trainable_layer(theta_layer, n_qubits):
    for q in range(n_qubits):
        qml.Rot(theta_layer[q, 0], theta_layer[q, 1], theta_layer[q, 2], wires=q)


def apply_entangling_layer(phi_layer, n_qubits):
    if n_qubits == 1:
        return
    for s in range(n_qubits - 1):
        qml.ctrl(qml.Rot, control=s + 1)(phi_layer[s, 0], phi_layer[s, 1], phi_layer[s, 2], wires=s)

# %% [markdown]
# ## 6.3 — Constructor de QNode batched para n qubits

# %%
def make_batched_drqnn_qnode(n_qubits):
    dev = qml_devices[n_qubits]
    @qml.qnode(dev, interface="torch", diff_method="backprop")
    
    def qnode(X_batch, theta, phi):
        for layer in range(N_LAYERS):
            encode_data_reuploading_layer(X_batch, n_qubits)
            apply_single_qubit_trainable_layer(theta[layer], n_qubits)

            if n_qubits > 1:
                apply_entangling_layer(phi[layer], n_qubits)

        return qml.probs(wires=0)

    return qnode

# %% [markdown]
# ## 6.4 — Crear QNodes Q1 → Q5

# %%
batched_qnodes = {}

for n_qubits in QUBITS_LIST:
    batched_qnodes[n_qubits] = make_batched_drqnn_qnode(n_qubits)

print("\nQNodes batched creados:")

for n_qubits in batched_qnodes:
    print(f"{n_qubits}Q listo")
# Out:
# QNodes batched creados:
# 1Q listo
# 2Q listo
# 3Q listo
# 4Q listo
# 5Q listo

# %% [markdown]
# ## 6.5 — Inicializadores auxiliares de parámetros

# %%
def make_empty_theta(n_qubits, device=DEVICE):
    theta = torch.zeros(N_LAYERS, n_qubits, 3, dtype=torch.float32, device=device)
    return theta

def make_empty_phi(n_qubits, device=DEVICE):

    if n_qubits == 1:
        phi = torch.zeros(N_LAYERS, 1, 3, dtype=torch.float32, device=device)

    else:
        phi = torch.zeros(N_LAYERS, n_qubits - 1, 3, dtype=torch.float32, device=device)

    return phi

# %% [markdown]
# ## 6.6 — Sanity check batched de todos los QNodes

# %%
SANITY_BATCH_SIZE = min(8, len(X_train_t))
X_sanity = X_train_t[:SANITY_BATCH_SIZE]

print("\nSanity batch:")
print("X_sanity:", X_sanity.shape)

qnode_sanity_outputs = {}

with torch.no_grad():
    for n_qubits in QUBITS_LIST:
        theta_sanity = make_empty_theta(n_qubits)
        phi_sanity = make_empty_phi(n_qubits)
        probs = batched_qnodes[n_qubits](X_sanity, theta_sanity, phi_sanity)
        qnode_sanity_outputs[n_qubits] = probs

        print(f"{n_qubits}Q probs:", probs.shape, probs.device, probs.dtype)

        assert probs.ndim == 2
        assert probs.shape[0] == SANITY_BATCH_SIZE
        assert probs.shape[1] == 2

        expected = torch.ones_like(probs.sum(dim=1))

        assert torch.allclose(probs.sum(dim=1), expected, atol=1e-5)

print("\nSanity check Q1-Q5 OK")
# Out:
# Sanity batch:
# X_sanity: torch.Size([8, 3])
# 1Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 2Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 3Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 4Q probs: torch.Size([8, 2]) cuda:0 torch.float32
# 5Q probs: torch.Size([8, 2]) cuda:0 torch.float32
#
# Sanity check Q1-Q5 OK

# %% [markdown]
# ## 6.7 — Convención de salida

# %%
print("\nConvención de salida DR-QNN:")
print("probs[:, 0] = fidelidad/probabilidad asociada a clase 0")
print("probs[:, 1] = score de clase 1")
print("pred = 1 si probs[:, 1] >= 0.5")

print("\nSección 6 lista.")
print("Los QNodes ya reciben batches X_batch con shape (B, 3).")
# Out:
# Convención de salida DR-QNN:
# probs[:, 0] = fidelidad/probabilidad asociada a clase 0
# probs[:, 1] = score de clase 1
# pred = 1 si probs[:, 1] >= 0.5
#
# Sección 6 lista.
# Los QNodes ya reciben batches X_batch con shape (B, 3).

# %%
probs.dtype
# Out:
# torch.float32

# %% [markdown]
# # **7**

# %% [markdown]
# ## 7.1 — Clase general DR-QNN batched

# %%
class BatchedDRQNN(nn.Module):

    def __init__(
        self,
        n_qubits,
        init_theta=None,
        init_phi=None
    ):
        super().__init__()

        assert n_qubits in QUBITS_LIST

        self.n_qubits = n_qubits

        theta_shape = (
            N_LAYERS,
            n_qubits,
            3
        )

        phi_shape = (
            N_LAYERS,
            max(n_qubits - 1, 1),
            3
        )

        # ----------------------------------------------------
        # Rotaciones locales entrenables
        # ----------------------------------------------------
        if init_theta is None:

            theta = torch.empty(
                theta_shape,
                dtype=torch.float32,
                device=DEVICE
            )

            theta.uniform_(
                -np.pi / 2,
                np.pi / 2
            )

        else:

            theta = (
                init_theta
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        # ----------------------------------------------------
        # Acoplamientos controlados
        # Se mantienen en cero para que inicialmente sean identidad.
        # ----------------------------------------------------
        if init_phi is None:

            phi = torch.zeros(
                phi_shape,
                dtype=torch.float32,
                device=DEVICE
            )

        else:

            phi = (
                init_phi
                .detach()
                .clone()
                .float()
                .to(DEVICE)
            )

        assert theta.shape == theta_shape
        assert phi.shape == phi_shape

        self.theta = nn.Parameter(theta)
        self.phi = nn.Parameter(phi)

        self.qnode = batched_qnodes[n_qubits]

    def forward(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        probs = probs.float()

        # Probabilidad asociada a la clase 1.
        score_class1 = probs[:, 1]

        return score_class1

    def predict_proba(self, X_batch):

        probs = self.qnode(
            X_batch,
            self.theta,
            self.phi
        )

        return probs.float()

# %% [markdown]
# ## 7.2 — Funciones de transferencia Q(n) → Q(n+1)

# %%
def expand_theta_from_previous(
    previous_theta,
    new_n_qubits
):

    previous_theta = (
        previous_theta
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    old_n_qubits = previous_theta.shape[1]

    assert new_n_qubits == old_n_qubits + 1

    # Inicialización de los parámetros del modelo ampliado.
    new_theta = torch.empty(
        N_LAYERS,
        new_n_qubits,
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    new_theta.uniform_(
        -np.pi / 2,
        np.pi / 2
    )

    # Conservar exactamente los parámetros de los qubits
    # que ya fueron entrenados.
    new_theta[
        :,
        :old_n_qubits,
        :
    ] = previous_theta

    return new_theta


def expand_phi_from_previous(
    previous_phi,
    new_n_qubits
):

    previous_phi = (
        previous_phi
        .detach()
        .clone()
        .float()
        .to(DEVICE)
    )

    new_phi = torch.zeros(
        N_LAYERS,
        max(new_n_qubits - 1, 1),
        3,
        dtype=torch.float32,
        device=DEVICE
    )

    if new_n_qubits > 2:

        old_phi_width = previous_phi.shape[1]

        new_phi[
            :,
            :old_phi_width,
            :
        ] = previous_phi

    return new_phi


def make_next_model_from_previous(
    previous_model,
    new_n_qubits
):

    init_theta = expand_theta_from_previous(
        previous_model.theta,
        new_n_qubits
    )

    init_phi = expand_phi_from_previous(
        previous_model.phi,
        new_n_qubits
    )

    model = BatchedDRQNN(
        n_qubits=new_n_qubits,
        init_theta=init_theta,
        init_phi=init_phi
    )

    return model


print("Funciones de expansión definidas correctamente.")
# Out:
# Funciones de expansión definidas correctamente.

# %% [markdown]
# ## 7.3 — Crear modelo inicial Q1

# %%
model_1q = BatchedDRQNN(
    n_qubits=1
)

print("Modelo Q1 creado")
print(model_1q)

print("\nParámetros Q1:")
for name, param in model_1q.named_parameters():

    print(
        name,
        tuple(param.shape),
        param.dtype,
        param.device,
        "requires_grad=",
        param.requires_grad
    )
# Out:
# Modelo Q1 creado
# BatchedDRQNN()
#
# Parámetros Q1:
# theta (6, 1, 3) torch.float32 cuda:0 requires_grad= True
# phi (6, 1, 3) torch.float32 cuda:0 requires_grad= True

# %% [markdown]
# ## 7.4 — Sanity check forward Q1

# %%
with torch.no_grad():

    q1_scores = model_1q(
        X_sanity
    )

    q1_probs = model_1q.predict_proba(
        X_sanity
    )

print("\nSanity forward Q1")
print("scores:", q1_scores.shape, q1_scores.dtype, q1_scores.device)
print("probs :", q1_probs.shape, q1_probs.dtype, q1_probs.device)

assert q1_scores.ndim == 1
assert q1_scores.shape[0] == SANITY_BATCH_SIZE
assert q1_scores.dtype == torch.float32

assert q1_probs.ndim == 2
assert q1_probs.shape == (
    SANITY_BATCH_SIZE,
    2
)
assert q1_probs.dtype == torch.float32
# Out:
# Sanity forward Q1
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.5 — Sanity check expansión Q1 → Q5

# %%
model_sanity = model_1q

sanity_models = {
    1: model_1q
}

for next_q in QUBITS_LIST[1:]:

    model_sanity = make_next_model_from_previous(
        model_sanity,
        next_q
    )

    sanity_models[next_q] = model_sanity

    with torch.no_grad():

        scores = model_sanity(
            X_sanity
        )

        probs = model_sanity.predict_proba(
            X_sanity
        )

    print(f"\nSanity modelo Q{next_q}")
    print("scores:", scores.shape, scores.dtype, scores.device)
    print("probs :", probs.shape, probs.dtype, probs.device)

    assert scores.ndim == 1
    assert scores.shape[0] == SANITY_BATCH_SIZE
    assert scores.dtype == torch.float32

    assert probs.ndim == 2
    assert probs.shape == (
        SANITY_BATCH_SIZE,
        2
    )
    assert probs.dtype == torch.float32
# Out:
# Sanity modelo Q2
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q3
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q4
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0
#
# Sanity modelo Q5
# scores: torch.Size([8]) torch.float32 cuda:0
# probs : torch.Size([8, 2]) torch.float32 cuda:0

# %% [markdown]
# ## 7.6 — Convención final del modelo

# %%
print("\nSección 7 lista.")
print("Cada modelo recibe X_batch con shape (B, 3).")
print("Cada forward devuelve scores clase 1 con shape (B,).")
print("predict_proba devuelve probs float32 con shape (B, 2).")
print("Los QNodes devuelven float64, pero el modelo convierte a float32.")
# Out:
# Sección 7 lista.
# Cada modelo recibe X_batch con shape (B, 3).
# Cada forward devuelve scores clase 1 con shape (B,).
# predict_proba devuelve probs float32 con shape (B, 2).
# Los QNodes devuelven float64, pero el modelo convierte a float32.

# %% [markdown]
# # **8**

# %% [markdown]
# ## 8.1 — Loss de fidelidad para clasificación binaria

# %%
def fidelity_loss_from_scores(
    scores_class1,
    y_batch
):
    """
    MSE entre una salida en [-1, 1] y etiquetas {-1, +1}.

    scores_class1:
        Probabilidad P(clase=1), en [0, 1].

    Convención:
        clase 0 -> -1
        clase 1 -> +1
    """

    y_batch = y_batch.float()

    # P(clase=1) en [0,1] -> score en [-1,1].
    z_class1 = 2.0 * scores_class1 - 1.0

    # Etiquetas 0/1 -> etiquetas -1/+1.
    y_pm1 = 2.0 * y_batch - 1.0

    loss = torch.mean(
        (z_class1 - y_pm1) ** 2
    )

    return loss

# %% [markdown]
# ## 8.2 — Predicción batched sin evaluar muestra por muestra

# %%
@torch.no_grad()
def predict_scores_batched(model, X, chunk_size=131072):
    model.eval()
    scores_all = []
    for X_chunk in make_tensor_batches(X, y=None, batch_size=chunk_size, shuffle=False, seed=None):
        scores_chunk = model(X_chunk)
        scores_all.append(scores_chunk.detach().cpu())
    scores_all = torch.cat(scores_all, dim=0 ).numpy()

    return scores_all

# %% [markdown]
# ## 8.3 — Métricas binarias

# %%
def compute_binary_metrics(y_true, scores, threshold=0.5):
    y_true = np.asarray(y_true).astype(int)
    scores = np.asarray(scores)
    y_pred = (scores >= threshold).astype(int)

    metrics = {"threshold": float(threshold), "accuracy": float( accuracy_score( y_true, y_pred)), "balanced_accuracy": float(balanced_accuracy_score( y_true, y_pred)), "f1": float(f1_score(y_true, y_pred)),
        "confusion_matrix": confusion_matrix(y_true, y_pred).tolist(),}

    return metrics

# %% [markdown]
# ## 8.4 — Evaluación completa batched

# %%
def evaluate_model(model, X, y, split_name, chunk_size=131072, threshold=0.5):
    scores = predict_scores_batched( model=model, X=X, chunk_size=chunk_size )
    y_np = y.detach().cpu().numpy()
    metrics = compute_binary_metrics( y_true=y_np, scores=scores, threshold=threshold)
    metrics["split"] = split_name
    metrics["n_samples"] = int(len(y_np))

    return metrics, scores

# %% [markdown]
# ## 8.5 — Entrenamiento de un modelo Qn

# %%
def train_drqnn_model(model, n_qubits, checkpoint_path):
    if n_qubits == 1:
        epochs = EPOCHS_1Q
        lr = LR_1Q
    else:
        epochs = EPOCHS_NQ
        lr = LR_NQ
    optimizer = optim.Adam(model.parameters(), lr=lr)

    best_test_bacc = -np.inf
    best_state = None

    history = []

    print("\nEntrenando DR-QNN")
    print("Qubits:", n_qubits)
    print("Epochs:", epochs)
    print("LR:", lr)
    print("TRAIN_BATCH_SIZE_TORCH:", TRAIN_BATCH_SIZE_TORCH)

    for epoch in range(1, epochs + 1):
        model.train()
        epoch_losses = []

        for X_batch, y_batch in make_tensor_batches(
            X_train_t,
            y_train_float_t,
            batch_size=TRAIN_BATCH_SIZE_TORCH,
            shuffle=True,
            seed=GLOBAL_SEED + epoch
        ):

            optimizer.zero_grad(set_to_none=True)
            scores = model(X_batch)
            loss = fidelity_loss_from_scores(scores, y_batch)
            loss.backward()
            optimizer.step()
            epoch_losses.append(float(loss.detach().cpu().item()))

        train_metrics, _ = evaluate_model(
            model=model,
            X=X_train_t,
            y=y_train_t,
            split_name="train",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        test_metrics, _ = evaluate_model(
            model=model,
            X=X_test_t,
            y=y_test_t,
            split_name="test",
            chunk_size=EVAL_CHUNK_SIZE_TORCH,
            threshold=0.5
        )

        mean_loss = float(
            np.mean(epoch_losses)
        )

        row = {
            "n_qubits": int(n_qubits),
            "epoch": int(epoch),
            "loss": mean_loss,
            "train_accuracy": train_metrics["accuracy"],
            "train_balanced_accuracy": train_metrics["balanced_accuracy"],
            "train_f1": train_metrics["f1"],
            "test_accuracy": test_metrics["accuracy"],
            "test_balanced_accuracy": test_metrics["balanced_accuracy"],
            "test_f1": test_metrics["f1"],
        }

        history.append(
            row
        )

        print(
            f"Q{n_qubits} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={mean_loss:.6f} | "
            f"train_acc={train_metrics['accuracy']:.4f} | "
            f"test_acc={test_metrics['accuracy']:.4f} | "
            f"test_bAcc={test_metrics['balanced_accuracy']:.4f}"
        )

        if test_metrics["balanced_accuracy"] > best_test_bacc:

            best_test_bacc = test_metrics["balanced_accuracy"]

            best_state = {
                "n_qubits": int(n_qubits),
                "epoch": int(epoch),
                "model_state_dict": {
                    k: v.detach().cpu()
                    for k, v in model.state_dict().items()
                },
                "test_metrics": test_metrics,
                "train_metrics": train_metrics,
                "config": CONFIG,
            }

            torch.save(
                best_state,
                checkpoint_path
            )

    if best_state is not None:

        model.load_state_dict(
            {
                k: v.to(DEVICE)
                for k, v in best_state["model_state_dict"].items()
            }
        )

    history_df = pd.DataFrame(
        history
    )

    print("\nMejor test balanced accuracy:")
    print(best_test_bacc)

    print("Checkpoint guardado en:")
    print(checkpoint_path)

    return model, history_df

# %% [markdown]
# ## 8.6 — Rutas de checkpoints por número de qubits

# %%
CHECKPOINT_PATHS = {
    1: CHECKPOINT_1Q_PATH,
    2: CHECKPOINT_2Q_PATH,
    3: CHECKPOINT_3Q_PATH,
    4: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_4q.pt"
    ),
    5: os.path.join(
        RESULTS_DIR,
        "best_dr_qnn_5q.pt"
    ),
}

print("Sección 8 lista.")
print("Ya están definidas las funciones de loss, evaluación batched y entrenamiento.")
# Out:
# Sección 8 lista.
# Ya están definidas las funciones de loss, evaluación batched y entrenamiento.

# %% [markdown]
# # **9**

# %% [markdown]
# ## 9.1 — Entrenamiento progresivo Q1 → Q5

# %%
trained_models = {}
training_histories = {}
final_metrics_rows = {}
final_scores = {}

current_model = None

for n_qubits in QUBITS_LIST:
    print("\n" + "=" * 80)
    print(f"ENTRENAMIENTO PROGRESIVO Q{n_qubits}")
    print("=" * 80)
    if n_qubits == 1:
        current_model = BatchedDRQNN(n_qubits=1)
    else:
        current_model = make_next_model_from_previous(previous_model=current_model, new_n_qubits=n_qubits)

    checkpoint_path = CHECKPOINT_PATHS[n_qubits]
    current_model, history_df = train_drqnn_model(
        model=current_model,
        n_qubits=n_qubits,
        checkpoint_path=checkpoint_path
    )

    trained_models[n_qubits] = current_model
    training_histories[n_qubits] = history_df

    train_metrics, train_scores = evaluate_model(
        model=current_model,
        X=X_train_t,
        y=y_train_t,
        split_name="train",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    test_metrics, test_scores = evaluate_model(
        model=current_model,
        X=X_test_t,
        y=y_test_t,
        split_name="test",
        chunk_size=EVAL_CHUNK_SIZE_TORCH,
        threshold=0.5
    )

    final_metrics_rows[n_qubits] = {
        "n_qubits": int(n_qubits),
        "train_accuracy": train_metrics["accuracy"],
        "train_balanced_accuracy": train_metrics["balanced_accuracy"],
        "train_f1": train_metrics["f1"],
        "test_accuracy": test_metrics["accuracy"],
        "test_balanced_accuracy": test_metrics["balanced_accuracy"],
        "test_f1": test_metrics["f1"],
        "checkpoint_path": checkpoint_path,
    }

    final_scores[n_qubits] = {
        "train_scores": train_scores,
        "test_scores": test_scores,
        "train_metrics": train_metrics,
        "test_metrics": test_metrics,
    }

    print("\nResultado final Q", n_qubits)
    print("TRAIN:", train_metrics)
    print("TEST :", test_metrics)
# Out:
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q1
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 1
# Epochs: 60
# LR: 0.006
# TRAIN_BATCH_SIZE_TORCH: 32
# Q1 | Epoch 001/60 | loss=0.902415 | train_acc=0.6613 | test_acc=0.6475 | test_bAcc=0.6504
# Q1 | Epoch 002/60 | loss=0.860172 | train_acc=0.6570 | test_acc=0.6375 | test_bAcc=0.6385
# Q1 | Epoch 003/60 | loss=0.858568 | train_acc=0.6555 | test_acc=0.6513 | test_bAcc=0.6552
# Q1 | Epoch 004/60 | loss=0.855380 | train_acc=0.6658 | test_acc=0.6554 | test_bAcc=0.6580
# Q1 | Epoch 005/60 | loss=0.854329 | train_acc=0.6323 | test_acc=0.6282 | test_bAcc=0.6267
# Q1 | Epoch 006/60 | loss=0.854181 | train_acc=0.6671 | test_acc=0.6594 | test_bAcc=0.6621
# Q1 | Epoch 007/60 | loss=0.853095 | train_acc=0.6655 | test_acc=0.6602 | test_bAcc=0.6632
# Q1 | Epoch 008/60 | loss=0.851908 | train_acc=0.6693 | test_acc=0.6640 | test_bAcc=0.6660
# Q1 | Epoch 009/60 | loss=0.850571 | train_acc=0.6603 | test_acc=0.6561 | test_bAcc=0.6604
# Q1 | Epoch 010/60 | loss=0.850259 | train_acc=0.6670 | test_acc=0.6594 | test_bAcc=0.6615
# Q1 | Epoch 011/60 | loss=0.847661 | train_acc=0.6694 | test_acc=0.6718 | test_bAcc=0.6757
# Q1 | Epoch 012/60 | loss=0.847263 | train_acc=0.6663 | test_acc=0.6637 | test_bAcc=0.6673
# Q1 | Epoch 013/60 | loss=0.847333 | train_acc=0.6684 | test_acc=0.6606 | test_bAcc=0.6624
# Q1 | Epoch 014/60 | loss=0.847049 | train_acc=0.6640 | test_acc=0.6663 | test_bAcc=0.6715
# Q1 | Epoch 015/60 | loss=0.846721 | train_acc=0.6698 | test_acc=0.6616 | test_bAcc=0.6638
# Q1 | Epoch 016/60 | loss=0.846020 | train_acc=0.6641 | test_acc=0.6501 | test_bAcc=0.6505
# Q1 | Epoch 017/60 | loss=0.843589 | train_acc=0.6718 | test_acc=0.6709 | test_bAcc=0.6756
# Q1 | Epoch 018/60 | loss=0.843037 | train_acc=0.6645 | test_acc=0.6625 | test_bAcc=0.6666
# Q1 | Epoch 019/60 | loss=0.844895 | train_acc=0.6591 | test_acc=0.6602 | test_bAcc=0.6657
# Q1 | Epoch 020/60 | loss=0.842387 | train_acc=0.6726 | test_acc=0.6678 | test_bAcc=0.6703
# Q1 | Epoch 021/60 | loss=0.843170 | train_acc=0.6694 | test_acc=0.6649 | test_bAcc=0.6681
# Q1 | Epoch 022/60 | loss=0.843009 | train_acc=0.6751 | test_acc=0.6730 | test_bAcc=0.6759
# Q1 | Epoch 023/60 | loss=0.842961 | train_acc=0.6688 | test_acc=0.6687 | test_bAcc=0.6736
# Q1 | Epoch 024/60 | loss=0.843973 | train_acc=0.6734 | test_acc=0.6690 | test_bAcc=0.6724
# Q1 | Epoch 025/60 | loss=0.843265 | train_acc=0.6732 | test_acc=0.6687 | test_bAcc=0.6727
# Q1 | Epoch 026/60 | loss=0.840091 | train_acc=0.6610 | test_acc=0.6621 | test_bAcc=0.6675
# Q1 | Epoch 027/60 | loss=0.842032 | train_acc=0.6639 | test_acc=0.6661 | test_bAcc=0.6712
# Q1 | Epoch 028/60 | loss=0.840025 | train_acc=0.6589 | test_acc=0.6451 | test_bAcc=0.6451
# Q1 | Epoch 029/60 | loss=0.841016 | train_acc=0.6750 | test_acc=0.6735 | test_bAcc=0.6767
# Q1 | Epoch 030/60 | loss=0.840654 | train_acc=0.6668 | test_acc=0.6523 | test_bAcc=0.6536
# Q1 | Epoch 031/60 | loss=0.841184 | train_acc=0.6737 | test_acc=0.6685 | test_bAcc=0.6722
# Q1 | Epoch 032/60 | loss=0.840937 | train_acc=0.6721 | test_acc=0.6659 | test_bAcc=0.6697
# Q1 | Epoch 033/60 | loss=0.840764 | train_acc=0.6741 | test_acc=0.6733 | test_bAcc=0.6770
# Q1 | Epoch 034/60 | loss=0.840415 | train_acc=0.6723 | test_acc=0.6752 | test_bAcc=0.6797
# Q1 | Epoch 035/60 | loss=0.841476 | train_acc=0.6703 | test_acc=0.6678 | test_bAcc=0.6722
# Q1 | Epoch 036/60 | loss=0.840697 | train_acc=0.6692 | test_acc=0.6692 | test_bAcc=0.6740
# Q1 | Epoch 037/60 | loss=0.839966 | train_acc=0.6641 | test_acc=0.6663 | test_bAcc=0.6717
# Q1 | Epoch 038/60 | loss=0.840214 | train_acc=0.6726 | test_acc=0.6702 | test_bAcc=0.6744
# Q1 | Epoch 039/60 | loss=0.840107 | train_acc=0.6562 | test_acc=0.6551 | test_bAcc=0.6609
# Q1 | Epoch 040/60 | loss=0.839123 | train_acc=0.6751 | test_acc=0.6714 | test_bAcc=0.6746
# Q1 | Epoch 041/60 | loss=0.841251 | train_acc=0.6678 | test_acc=0.6671 | test_bAcc=0.6721
# Q1 | Epoch 042/60 | loss=0.839639 | train_acc=0.6674 | test_acc=0.6671 | test_bAcc=0.6717
# Q1 | Epoch 043/60 | loss=0.838595 | train_acc=0.6713 | test_acc=0.6718 | test_bAcc=0.6765
# Q1 | Epoch 044/60 | loss=0.839970 | train_acc=0.6604 | test_acc=0.6604 | test_bAcc=0.6660
# Q1 | Epoch 045/60 | loss=0.839668 | train_acc=0.6667 | test_acc=0.6635 | test_bAcc=0.6681
# Q1 | Epoch 046/60 | loss=0.839504 | train_acc=0.6490 | test_acc=0.6501 | test_bAcc=0.6561
# Q1 | Epoch 047/60 | loss=0.839901 | train_acc=0.6747 | test_acc=0.6697 | test_bAcc=0.6732
# Q1 | Epoch 048/60 | loss=0.838879 | train_acc=0.6715 | test_acc=0.6578 | test_bAcc=0.6594
# Q1 | Epoch 049/60 | loss=0.838618 | train_acc=0.6734 | test_acc=0.6706 | test_bAcc=0.6735
# Q1 | Epoch 050/60 | loss=0.839463 | train_acc=0.6705 | test_acc=0.6694 | test_bAcc=0.6736
# Q1 | Epoch 051/60 | loss=0.839214 | train_acc=0.6710 | test_acc=0.6668 | test_bAcc=0.6709
# Q1 | Epoch 052/60 | loss=0.838834 | train_acc=0.6740 | test_acc=0.6780 | test_bAcc=0.6821
# Q1 | Epoch 053/60 | loss=0.837896 | train_acc=0.6658 | test_acc=0.6628 | test_bAcc=0.6670
# Q1 | Epoch 054/60 | loss=0.837742 | train_acc=0.6568 | test_acc=0.6549 | test_bAcc=0.6607
# Q1 | Epoch 055/60 | loss=0.837884 | train_acc=0.6685 | test_acc=0.6680 | test_bAcc=0.6726
# Q1 | Epoch 056/60 | loss=0.839693 | train_acc=0.6681 | test_acc=0.6697 | test_bAcc=0.6748
# Q1 | Epoch 057/60 | loss=0.839885 | train_acc=0.6734 | test_acc=0.6683 | test_bAcc=0.6717
# Q1 | Epoch 058/60 | loss=0.838418 | train_acc=0.6685 | test_acc=0.6637 | test_bAcc=0.6658
# Q1 | Epoch 059/60 | loss=0.837325 | train_acc=0.6746 | test_acc=0.6790 | test_bAcc=0.6831
# Q1 | Epoch 060/60 | loss=0.838975 | train_acc=0.6722 | test_acc=0.6606 | test_bAcc=0.6618
#
# Mejor test balanced accuracy:
# 0.6831279091780769
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_1q.pt
#
# Resultado final Q 1
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6746126340882003, 'balanced_accuracy': 0.6786413164982761, 'f1': 0.5911949685534591, 'confusion_matrix': [[7372, 862], [4598, 3948]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6789799809342231, 'balanced_accuracy': 0.6831279091780769, 'f1': 0.5934198611530335, 'confusion_matrix': [[1866, 193], [1154, 983]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q2
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 2
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q2 | Epoch 001/50 | loss=0.829901 | train_acc=0.6753 | test_acc=0.6716 | test_bAcc=0.6751
# Q2 | Epoch 002/50 | loss=0.818399 | train_acc=0.6709 | test_acc=0.6566 | test_bAcc=0.6580
# Q2 | Epoch 003/50 | loss=0.811940 | train_acc=0.6768 | test_acc=0.6771 | test_bAcc=0.6812
# Q2 | Epoch 004/50 | loss=0.804554 | train_acc=0.6849 | test_acc=0.6814 | test_bAcc=0.6844
# Q2 | Epoch 005/50 | loss=0.799944 | train_acc=0.6572 | test_acc=0.6501 | test_bAcc=0.6498
# Q2 | Epoch 006/50 | loss=0.797659 | train_acc=0.6815 | test_acc=0.6742 | test_bAcc=0.6766
# Q2 | Epoch 007/50 | loss=0.794384 | train_acc=0.6829 | test_acc=0.6759 | test_bAcc=0.6785
# Q2 | Epoch 008/50 | loss=0.792071 | train_acc=0.6838 | test_acc=0.6730 | test_bAcc=0.6753
# Q2 | Epoch 009/50 | loss=0.789947 | train_acc=0.6847 | test_acc=0.6818 | test_bAcc=0.6858
# Q2 | Epoch 010/50 | loss=0.788301 | train_acc=0.6830 | test_acc=0.6725 | test_bAcc=0.6744
# Q2 | Epoch 011/50 | loss=0.786276 | train_acc=0.6874 | test_acc=0.6826 | test_bAcc=0.6856
# Q2 | Epoch 012/50 | loss=0.785281 | train_acc=0.6867 | test_acc=0.6833 | test_bAcc=0.6870
# Q2 | Epoch 013/50 | loss=0.785108 | train_acc=0.6816 | test_acc=0.6692 | test_bAcc=0.6703
# Q2 | Epoch 014/50 | loss=0.784812 | train_acc=0.6880 | test_acc=0.6814 | test_bAcc=0.6854
# Q2 | Epoch 015/50 | loss=0.783776 | train_acc=0.6825 | test_acc=0.6761 | test_bAcc=0.6779
# Q2 | Epoch 016/50 | loss=0.784059 | train_acc=0.6781 | test_acc=0.6678 | test_bAcc=0.6688
# Q2 | Epoch 017/50 | loss=0.782087 | train_acc=0.6868 | test_acc=0.6854 | test_bAcc=0.6893
# Q2 | Epoch 018/50 | loss=0.780989 | train_acc=0.6865 | test_acc=0.6864 | test_bAcc=0.6900
# Q2 | Epoch 019/50 | loss=0.781680 | train_acc=0.6877 | test_acc=0.6859 | test_bAcc=0.6901
# Q2 | Epoch 020/50 | loss=0.780369 | train_acc=0.6902 | test_acc=0.6861 | test_bAcc=0.6890
# Q2 | Epoch 021/50 | loss=0.780587 | train_acc=0.6826 | test_acc=0.6699 | test_bAcc=0.6714
# Q2 | Epoch 022/50 | loss=0.780266 | train_acc=0.6798 | test_acc=0.6652 | test_bAcc=0.6660
# Q2 | Epoch 023/50 | loss=0.779759 | train_acc=0.6903 | test_acc=0.6864 | test_bAcc=0.6899
# Q2 | Epoch 024/50 | loss=0.779920 | train_acc=0.6891 | test_acc=0.6866 | test_bAcc=0.6894
# Q2 | Epoch 025/50 | loss=0.779872 | train_acc=0.6887 | test_acc=0.6842 | test_bAcc=0.6875
# Q2 | Epoch 026/50 | loss=0.778687 | train_acc=0.6897 | test_acc=0.6852 | test_bAcc=0.6893
# Q2 | Epoch 027/50 | loss=0.778461 | train_acc=0.6879 | test_acc=0.6876 | test_bAcc=0.6916
# Q2 | Epoch 028/50 | loss=0.777803 | train_acc=0.6757 | test_acc=0.6563 | test_bAcc=0.6563
# Q2 | Epoch 029/50 | loss=0.777093 | train_acc=0.6878 | test_acc=0.6818 | test_bAcc=0.6847
# Q2 | Epoch 030/50 | loss=0.777503 | train_acc=0.6836 | test_acc=0.6714 | test_bAcc=0.6730
# Q2 | Epoch 031/50 | loss=0.777206 | train_acc=0.6873 | test_acc=0.6818 | test_bAcc=0.6840
# Q2 | Epoch 032/50 | loss=0.777821 | train_acc=0.6877 | test_acc=0.6871 | test_bAcc=0.6913
# Q2 | Epoch 033/50 | loss=0.777027 | train_acc=0.6873 | test_acc=0.6876 | test_bAcc=0.6904
# Q2 | Epoch 034/50 | loss=0.776926 | train_acc=0.6884 | test_acc=0.6835 | test_bAcc=0.6859
# Q2 | Epoch 035/50 | loss=0.777328 | train_acc=0.6846 | test_acc=0.6823 | test_bAcc=0.6847
# Q2 | Epoch 036/50 | loss=0.776696 | train_acc=0.6892 | test_acc=0.6878 | test_bAcc=0.6913
# Q2 | Epoch 037/50 | loss=0.776153 | train_acc=0.6916 | test_acc=0.6897 | test_bAcc=0.6934
# Q2 | Epoch 038/50 | loss=0.776393 | train_acc=0.6883 | test_acc=0.6876 | test_bAcc=0.6900
# Q2 | Epoch 039/50 | loss=0.776643 | train_acc=0.6871 | test_acc=0.6871 | test_bAcc=0.6912
# Q2 | Epoch 040/50 | loss=0.775042 | train_acc=0.6893 | test_acc=0.6866 | test_bAcc=0.6895
# Q2 | Epoch 041/50 | loss=0.776940 | train_acc=0.6891 | test_acc=0.6866 | test_bAcc=0.6905
# Q2 | Epoch 042/50 | loss=0.776022 | train_acc=0.6869 | test_acc=0.6873 | test_bAcc=0.6908
# Q2 | Epoch 043/50 | loss=0.774862 | train_acc=0.6878 | test_acc=0.6847 | test_bAcc=0.6871
# Q2 | Epoch 044/50 | loss=0.776226 | train_acc=0.6916 | test_acc=0.6897 | test_bAcc=0.6934
# Q2 | Epoch 045/50 | loss=0.775383 | train_acc=0.6885 | test_acc=0.6899 | test_bAcc=0.6937
# Q2 | Epoch 046/50 | loss=0.775616 | train_acc=0.6857 | test_acc=0.6861 | test_bAcc=0.6904
# Q2 | Epoch 047/50 | loss=0.775945 | train_acc=0.6909 | test_acc=0.6907 | test_bAcc=0.6935
# Q2 | Epoch 048/50 | loss=0.774920 | train_acc=0.6875 | test_acc=0.6837 | test_bAcc=0.6862
# Q2 | Epoch 049/50 | loss=0.774863 | train_acc=0.6876 | test_acc=0.6814 | test_bAcc=0.6835
# Q2 | Epoch 050/50 | loss=0.775927 | train_acc=0.6877 | test_acc=0.6876 | test_bAcc=0.6912
#
# Mejor test balanced accuracy:
# 0.6937222547847393
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_2q.pt
#
# Resultado final Q 2
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6884982121573302, 'balanced_accuracy': 0.6922645573902277, 'f1': 0.6155769655070972, 'confusion_matrix': [[7368, 866], [4361, 4185]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6899428026692088, 'balanced_accuracy': 0.6937222547847393, 'f1': 0.6170150132469826, 'confusion_matrix': [[1847, 212], [1089, 1048]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q3
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 3
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q3 | Epoch 001/50 | loss=0.775031 | train_acc=0.6899 | test_acc=0.6892 | test_bAcc=0.6924
# Q3 | Epoch 002/50 | loss=0.773337 | train_acc=0.6869 | test_acc=0.6756 | test_bAcc=0.6778
# Q3 | Epoch 003/50 | loss=0.773352 | train_acc=0.6883 | test_acc=0.6859 | test_bAcc=0.6893
# Q3 | Epoch 004/50 | loss=0.771265 | train_acc=0.6931 | test_acc=0.6888 | test_bAcc=0.6917
# Q3 | Epoch 005/50 | loss=0.770684 | train_acc=0.6824 | test_acc=0.6728 | test_bAcc=0.6735
# Q3 | Epoch 006/50 | loss=0.771799 | train_acc=0.6884 | test_acc=0.6826 | test_bAcc=0.6848
# Q3 | Epoch 007/50 | loss=0.770860 | train_acc=0.6908 | test_acc=0.6840 | test_bAcc=0.6866
# Q3 | Epoch 008/50 | loss=0.770710 | train_acc=0.6856 | test_acc=0.6837 | test_bAcc=0.6858
# Q3 | Epoch 009/50 | loss=0.769429 | train_acc=0.6918 | test_acc=0.6895 | test_bAcc=0.6931
# Q3 | Epoch 010/50 | loss=0.769074 | train_acc=0.6896 | test_acc=0.6785 | test_bAcc=0.6803
# Q3 | Epoch 011/50 | loss=0.768197 | train_acc=0.6926 | test_acc=0.6914 | test_bAcc=0.6944
# Q3 | Epoch 012/50 | loss=0.767667 | train_acc=0.6912 | test_acc=0.6907 | test_bAcc=0.6941
# Q3 | Epoch 013/50 | loss=0.767852 | train_acc=0.6859 | test_acc=0.6718 | test_bAcc=0.6727
# Q3 | Epoch 014/50 | loss=0.768867 | train_acc=0.6921 | test_acc=0.6918 | test_bAcc=0.6955
# Q3 | Epoch 015/50 | loss=0.767942 | train_acc=0.6901 | test_acc=0.6826 | test_bAcc=0.6843
# Q3 | Epoch 016/50 | loss=0.768412 | train_acc=0.6881 | test_acc=0.6778 | test_bAcc=0.6792
# Q3 | Epoch 017/50 | loss=0.766995 | train_acc=0.6924 | test_acc=0.6897 | test_bAcc=0.6934
# Q3 | Epoch 018/50 | loss=0.766326 | train_acc=0.6923 | test_acc=0.6892 | test_bAcc=0.6927
# Q3 | Epoch 019/50 | loss=0.767994 | train_acc=0.6936 | test_acc=0.6911 | test_bAcc=0.6951
# Q3 | Epoch 020/50 | loss=0.766543 | train_acc=0.6921 | test_acc=0.6911 | test_bAcc=0.6939
# Q3 | Epoch 021/50 | loss=0.766885 | train_acc=0.6880 | test_acc=0.6778 | test_bAcc=0.6792
# Q3 | Epoch 022/50 | loss=0.767220 | train_acc=0.6884 | test_acc=0.6740 | test_bAcc=0.6749
# Q3 | Epoch 023/50 | loss=0.767118 | train_acc=0.6940 | test_acc=0.6940 | test_bAcc=0.6973
# Q3 | Epoch 024/50 | loss=0.767277 | train_acc=0.6927 | test_acc=0.6883 | test_bAcc=0.6910
# Q3 | Epoch 025/50 | loss=0.767782 | train_acc=0.6915 | test_acc=0.6880 | test_bAcc=0.6911
# Q3 | Epoch 026/50 | loss=0.766560 | train_acc=0.6934 | test_acc=0.6902 | test_bAcc=0.6941
# Q3 | Epoch 027/50 | loss=0.766579 | train_acc=0.6928 | test_acc=0.6909 | test_bAcc=0.6947
# Q3 | Epoch 028/50 | loss=0.765922 | train_acc=0.6828 | test_acc=0.6621 | test_bAcc=0.6626
# Q3 | Epoch 029/50 | loss=0.765630 | train_acc=0.6900 | test_acc=0.6871 | test_bAcc=0.6898
# Q3 | Epoch 030/50 | loss=0.765991 | train_acc=0.6886 | test_acc=0.6842 | test_bAcc=0.6864
# Q3 | Epoch 031/50 | loss=0.765918 | train_acc=0.6901 | test_acc=0.6864 | test_bAcc=0.6884
# Q3 | Epoch 032/50 | loss=0.766701 | train_acc=0.6942 | test_acc=0.6885 | test_bAcc=0.6923
# Q3 | Epoch 033/50 | loss=0.765998 | train_acc=0.6902 | test_acc=0.6876 | test_bAcc=0.6901
# Q3 | Epoch 034/50 | loss=0.766042 | train_acc=0.6923 | test_acc=0.6866 | test_bAcc=0.6887
# Q3 | Epoch 035/50 | loss=0.766365 | train_acc=0.6870 | test_acc=0.6852 | test_bAcc=0.6875
# Q3 | Epoch 036/50 | loss=0.765666 | train_acc=0.6937 | test_acc=0.6914 | test_bAcc=0.6946
# Q3 | Epoch 037/50 | loss=0.765112 | train_acc=0.6932 | test_acc=0.6947 | test_bAcc=0.6979
# Q3 | Epoch 038/50 | loss=0.765600 | train_acc=0.6940 | test_acc=0.6916 | test_bAcc=0.6939
# Q3 | Epoch 039/50 | loss=0.766209 | train_acc=0.6932 | test_acc=0.6907 | test_bAcc=0.6944
# Q3 | Epoch 040/50 | loss=0.764513 | train_acc=0.6926 | test_acc=0.6940 | test_bAcc=0.6969
# Q3 | Epoch 041/50 | loss=0.766539 | train_acc=0.6946 | test_acc=0.6902 | test_bAcc=0.6938
# Q3 | Epoch 042/50 | loss=0.765439 | train_acc=0.6928 | test_acc=0.6876 | test_bAcc=0.6909
# Q3 | Epoch 043/50 | loss=0.764033 | train_acc=0.6916 | test_acc=0.6823 | test_bAcc=0.6841
# Q3 | Epoch 044/50 | loss=0.765655 | train_acc=0.6946 | test_acc=0.6954 | test_bAcc=0.6987
# Q3 | Epoch 045/50 | loss=0.764518 | train_acc=0.6954 | test_acc=0.6899 | test_bAcc=0.6934
# Q3 | Epoch 046/50 | loss=0.764877 | train_acc=0.6938 | test_acc=0.6892 | test_bAcc=0.6929
# Q3 | Epoch 047/50 | loss=0.764802 | train_acc=0.6942 | test_acc=0.6911 | test_bAcc=0.6939
# Q3 | Epoch 048/50 | loss=0.764177 | train_acc=0.6924 | test_acc=0.6904 | test_bAcc=0.6931
# Q3 | Epoch 049/50 | loss=0.764206 | train_acc=0.6921 | test_acc=0.6907 | test_bAcc=0.6929
# Q3 | Epoch 050/50 | loss=0.765299 | train_acc=0.6934 | test_acc=0.6916 | test_bAcc=0.6950
#
# Mejor test balanced accuracy:
# 0.698678184025165
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_3q.pt
#
# Resultado final Q 3
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6945768772348033, 'balanced_accuracy': 0.6976957659191785, 'f1': 0.6386519072128605, 'confusion_matrix': [[7126, 1108], [4017, 4529]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6954242135367016, 'balanced_accuracy': 0.698678184025165, 'f1': 0.636518771331058, 'confusion_matrix': [[1799, 260], [1018, 1119]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q4
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 4
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q4 | Epoch 001/50 | loss=0.764885 | train_acc=0.6943 | test_acc=0.6907 | test_bAcc=0.6936
# Q4 | Epoch 002/50 | loss=0.764036 | train_acc=0.6925 | test_acc=0.6897 | test_bAcc=0.6923
# Q4 | Epoch 003/50 | loss=0.764580 | train_acc=0.6912 | test_acc=0.6888 | test_bAcc=0.6917
# Q4 | Epoch 004/50 | loss=0.763046 | train_acc=0.6937 | test_acc=0.6964 | test_bAcc=0.6993
# Q4 | Epoch 005/50 | loss=0.762641 | train_acc=0.6908 | test_acc=0.6835 | test_bAcc=0.6850
# Q4 | Epoch 006/50 | loss=0.763978 | train_acc=0.6911 | test_acc=0.6859 | test_bAcc=0.6882
# Q4 | Epoch 007/50 | loss=0.763709 | train_acc=0.6922 | test_acc=0.6885 | test_bAcc=0.6906
# Q4 | Epoch 008/50 | loss=0.764193 | train_acc=0.6909 | test_acc=0.6904 | test_bAcc=0.6929
# Q4 | Epoch 009/50 | loss=0.762961 | train_acc=0.6943 | test_acc=0.6933 | test_bAcc=0.6965
# Q4 | Epoch 010/50 | loss=0.762805 | train_acc=0.6906 | test_acc=0.6847 | test_bAcc=0.6866
# Q4 | Epoch 011/50 | loss=0.762768 | train_acc=0.6943 | test_acc=0.6949 | test_bAcc=0.6980
# Q4 | Epoch 012/50 | loss=0.762326 | train_acc=0.6924 | test_acc=0.6930 | test_bAcc=0.6966
# Q4 | Epoch 013/50 | loss=0.762717 | train_acc=0.6922 | test_acc=0.6878 | test_bAcc=0.6896
# Q4 | Epoch 014/50 | loss=0.763682 | train_acc=0.6927 | test_acc=0.6961 | test_bAcc=0.6994
# Q4 | Epoch 015/50 | loss=0.762776 | train_acc=0.6925 | test_acc=0.6866 | test_bAcc=0.6886
# Q4 | Epoch 016/50 | loss=0.763136 | train_acc=0.6887 | test_acc=0.6847 | test_bAcc=0.6867
# Q4 | Epoch 017/50 | loss=0.762104 | train_acc=0.6938 | test_acc=0.6940 | test_bAcc=0.6975
# Q4 | Epoch 018/50 | loss=0.761409 | train_acc=0.6954 | test_acc=0.6938 | test_bAcc=0.6970
# Q4 | Epoch 019/50 | loss=0.763283 | train_acc=0.6941 | test_acc=0.6980 | test_bAcc=0.7017
# Q4 | Epoch 020/50 | loss=0.761851 | train_acc=0.6926 | test_acc=0.6930 | test_bAcc=0.6958
# Q4 | Epoch 021/50 | loss=0.762227 | train_acc=0.6914 | test_acc=0.6852 | test_bAcc=0.6871
# Q4 | Epoch 022/50 | loss=0.762572 | train_acc=0.6911 | test_acc=0.6876 | test_bAcc=0.6891
# Q4 | Epoch 023/50 | loss=0.762370 | train_acc=0.6970 | test_acc=0.6971 | test_bAcc=0.7002
# Q4 | Epoch 024/50 | loss=0.762380 | train_acc=0.6955 | test_acc=0.6933 | test_bAcc=0.6960
# Q4 | Epoch 025/50 | loss=0.762977 | train_acc=0.6934 | test_acc=0.6918 | test_bAcc=0.6949
# Q4 | Epoch 026/50 | loss=0.761708 | train_acc=0.6944 | test_acc=0.6954 | test_bAcc=0.6992
# Q4 | Epoch 027/50 | loss=0.762010 | train_acc=0.6940 | test_acc=0.6954 | test_bAcc=0.6990
# Q4 | Epoch 028/50 | loss=0.761338 | train_acc=0.6880 | test_acc=0.6761 | test_bAcc=0.6771
# Q4 | Epoch 029/50 | loss=0.761034 | train_acc=0.6909 | test_acc=0.6902 | test_bAcc=0.6928
# Q4 | Epoch 030/50 | loss=0.761253 | train_acc=0.6921 | test_acc=0.6866 | test_bAcc=0.6889
# Q4 | Epoch 031/50 | loss=0.761216 | train_acc=0.6906 | test_acc=0.6876 | test_bAcc=0.6895
# Q4 | Epoch 032/50 | loss=0.761949 | train_acc=0.6955 | test_acc=0.6928 | test_bAcc=0.6964
# Q4 | Epoch 033/50 | loss=0.761447 | train_acc=0.6918 | test_acc=0.6916 | test_bAcc=0.6942
# Q4 | Epoch 034/50 | loss=0.761508 | train_acc=0.6912 | test_acc=0.6895 | test_bAcc=0.6915
# Q4 | Epoch 035/50 | loss=0.761937 | train_acc=0.6874 | test_acc=0.6828 | test_bAcc=0.6848
# Q4 | Epoch 036/50 | loss=0.760974 | train_acc=0.6947 | test_acc=0.6933 | test_bAcc=0.6964
# Q4 | Epoch 037/50 | loss=0.760585 | train_acc=0.6948 | test_acc=0.6959 | test_bAcc=0.6990
# Q4 | Epoch 038/50 | loss=0.761227 | train_acc=0.6927 | test_acc=0.6911 | test_bAcc=0.6933
# Q4 | Epoch 039/50 | loss=0.761943 | train_acc=0.6942 | test_acc=0.6954 | test_bAcc=0.6990
# Q4 | Epoch 040/50 | loss=0.760137 | train_acc=0.6936 | test_acc=0.6966 | test_bAcc=0.6994
# Q4 | Epoch 041/50 | loss=0.762253 | train_acc=0.6949 | test_acc=0.6940 | test_bAcc=0.6975
# Q4 | Epoch 042/50 | loss=0.761095 | train_acc=0.6935 | test_acc=0.6895 | test_bAcc=0.6926
# Q4 | Epoch 043/50 | loss=0.759626 | train_acc=0.6902 | test_acc=0.6835 | test_bAcc=0.6852
# Q4 | Epoch 044/50 | loss=0.761447 | train_acc=0.6959 | test_acc=0.6973 | test_bAcc=0.7005
# Q4 | Epoch 045/50 | loss=0.760271 | train_acc=0.6945 | test_acc=0.6945 | test_bAcc=0.6980
# Q4 | Epoch 046/50 | loss=0.760559 | train_acc=0.6952 | test_acc=0.6935 | test_bAcc=0.6971
# Q4 | Epoch 047/50 | loss=0.760335 | train_acc=0.6946 | test_acc=0.6938 | test_bAcc=0.6965
# Q4 | Epoch 048/50 | loss=0.759887 | train_acc=0.6944 | test_acc=0.6892 | test_bAcc=0.6918
# Q4 | Epoch 049/50 | loss=0.759931 | train_acc=0.6933 | test_acc=0.6942 | test_bAcc=0.6967
# Q4 | Epoch 050/50 | loss=0.760908 | train_acc=0.6946 | test_acc=0.6954 | test_bAcc=0.6987
#
# Mejor test balanced accuracy:
# 0.7016596050574501
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_4q.pt
#
# Resultado final Q 4
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6941001191895113, 'balanced_accuracy': 0.6976289739716612, 'f1': 0.6283935423152103, 'confusion_matrix': [[7307, 927], [4206, 4340]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.698045757864633, 'balanced_accuracy': 0.7016596050574501, 'f1': 0.6311499272197962, 'confusion_matrix': [[1845, 214], [1053, 1084]], 'split': 'test', 'n_samples': 4196}
#
# ================================================================================
# ENTRENAMIENTO PROGRESIVO Q5
# ================================================================================
#
# Entrenando DR-QNN
# Qubits: 5
# Epochs: 50
# LR: 0.003
# TRAIN_BATCH_SIZE_TORCH: 32
# Q5 | Epoch 001/50 | loss=0.762062 | train_acc=0.6942 | test_acc=0.6942 | test_bAcc=0.6971
# Q5 | Epoch 002/50 | loss=0.761531 | train_acc=0.6931 | test_acc=0.6942 | test_bAcc=0.6968
# Q5 | Epoch 003/50 | loss=0.762225 | train_acc=0.6922 | test_acc=0.6880 | test_bAcc=0.6910
# Q5 | Epoch 004/50 | loss=0.760977 | train_acc=0.6946 | test_acc=0.6980 | test_bAcc=0.7010
# Q5 | Epoch 005/50 | loss=0.760650 | train_acc=0.6917 | test_acc=0.6859 | test_bAcc=0.6875
# Q5 | Epoch 006/50 | loss=0.762169 | train_acc=0.6926 | test_acc=0.6899 | test_bAcc=0.6923
# Q5 | Epoch 007/50 | loss=0.761938 | train_acc=0.6936 | test_acc=0.6904 | test_bAcc=0.6925
# Q5 | Epoch 008/50 | loss=0.762439 | train_acc=0.6923 | test_acc=0.6923 | test_bAcc=0.6948
# Q5 | Epoch 009/50 | loss=0.761252 | train_acc=0.6953 | test_acc=0.6949 | test_bAcc=0.6981
# Q5 | Epoch 010/50 | loss=0.761129 | train_acc=0.6912 | test_acc=0.6857 | test_bAcc=0.6875
# Q5 | Epoch 011/50 | loss=0.761199 | train_acc=0.6949 | test_acc=0.6978 | test_bAcc=0.7008
# Q5 | Epoch 012/50 | loss=0.760748 | train_acc=0.6936 | test_acc=0.6940 | test_bAcc=0.6975
# Q5 | Epoch 013/50 | loss=0.761097 | train_acc=0.6928 | test_acc=0.6885 | test_bAcc=0.6903
# Q5 | Epoch 014/50 | loss=0.762058 | train_acc=0.6936 | test_acc=0.6964 | test_bAcc=0.6996
# Q5 | Epoch 015/50 | loss=0.761121 | train_acc=0.6920 | test_acc=0.6907 | test_bAcc=0.6926
# Q5 | Epoch 016/50 | loss=0.761492 | train_acc=0.6899 | test_acc=0.6849 | test_bAcc=0.6870
# Q5 | Epoch 017/50 | loss=0.760527 | train_acc=0.6936 | test_acc=0.6938 | test_bAcc=0.6972
# Q5 | Epoch 018/50 | loss=0.759738 | train_acc=0.6964 | test_acc=0.6947 | test_bAcc=0.6980
# Q5 | Epoch 019/50 | loss=0.761720 | train_acc=0.6955 | test_acc=0.6971 | test_bAcc=0.7006
# Q5 | Epoch 020/50 | loss=0.760289 | train_acc=0.6936 | test_acc=0.6949 | test_bAcc=0.6977
# Q5 | Epoch 021/50 | loss=0.760621 | train_acc=0.6911 | test_acc=0.6866 | test_bAcc=0.6885
# Q5 | Epoch 022/50 | loss=0.761046 | train_acc=0.6925 | test_acc=0.6866 | test_bAcc=0.6881
# Q5 | Epoch 023/50 | loss=0.760773 | train_acc=0.6968 | test_acc=0.6995 | test_bAcc=0.7025
# Q5 | Epoch 024/50 | loss=0.760697 | train_acc=0.6948 | test_acc=0.6926 | test_bAcc=0.6952
# Q5 | Epoch 025/50 | loss=0.761423 | train_acc=0.6927 | test_acc=0.6902 | test_bAcc=0.6931
# Q5 | Epoch 026/50 | loss=0.760153 | train_acc=0.6956 | test_acc=0.6947 | test_bAcc=0.6984
# Q5 | Epoch 027/50 | loss=0.760499 | train_acc=0.6933 | test_acc=0.6945 | test_bAcc=0.6980
# Q5 | Epoch 028/50 | loss=0.759812 | train_acc=0.6869 | test_acc=0.6709 | test_bAcc=0.6717
# Q5 | Epoch 029/50 | loss=0.759518 | train_acc=0.6914 | test_acc=0.6880 | test_bAcc=0.6907
# Q5 | Epoch 030/50 | loss=0.759679 | train_acc=0.6931 | test_acc=0.6868 | test_bAcc=0.6891
# Q5 | Epoch 031/50 | loss=0.759627 | train_acc=0.6910 | test_acc=0.6876 | test_bAcc=0.6894
# Q5 | Epoch 032/50 | loss=0.760433 | train_acc=0.6962 | test_acc=0.6933 | test_bAcc=0.6968
# Q5 | Epoch 033/50 | loss=0.759968 | train_acc=0.6912 | test_acc=0.6914 | test_bAcc=0.6940
# Q5 | Epoch 034/50 | loss=0.760072 | train_acc=0.6918 | test_acc=0.6871 | test_bAcc=0.6890
# Q5 | Epoch 035/50 | loss=0.760525 | train_acc=0.6911 | test_acc=0.6823 | test_bAcc=0.6842
# Q5 | Epoch 036/50 | loss=0.759599 | train_acc=0.6958 | test_acc=0.6938 | test_bAcc=0.6969
# Q5 | Epoch 037/50 | loss=0.759238 | train_acc=0.6942 | test_acc=0.6933 | test_bAcc=0.6963
# Q5 | Epoch 038/50 | loss=0.759886 | train_acc=0.6931 | test_acc=0.6914 | test_bAcc=0.6935
# Q5 | Epoch 039/50 | loss=0.760568 | train_acc=0.6952 | test_acc=0.6973 | test_bAcc=0.7009
# Q5 | Epoch 040/50 | loss=0.758806 | train_acc=0.6947 | test_acc=0.6959 | test_bAcc=0.6987
# Q5 | Epoch 041/50 | loss=0.760987 | train_acc=0.6946 | test_acc=0.6985 | test_bAcc=0.7020
# Q5 | Epoch 042/50 | loss=0.759790 | train_acc=0.6948 | test_acc=0.6911 | test_bAcc=0.6942
# Q5 | Epoch 043/50 | loss=0.758321 | train_acc=0.6907 | test_acc=0.6818 | test_bAcc=0.6835
# Q5 | Epoch 044/50 | loss=0.760232 | train_acc=0.6952 | test_acc=0.6966 | test_bAcc=0.6997
# Q5 | Epoch 045/50 | loss=0.759084 | train_acc=0.6959 | test_acc=0.6938 | test_bAcc=0.6972
# Q5 | Epoch 046/50 | loss=0.759339 | train_acc=0.6944 | test_acc=0.6909 | test_bAcc=0.6943
# Q5 | Epoch 047/50 | loss=0.759060 | train_acc=0.6951 | test_acc=0.6930 | test_bAcc=0.6956
# Q5 | Epoch 048/50 | loss=0.758677 | train_acc=0.6952 | test_acc=0.6868 | test_bAcc=0.6893
# Q5 | Epoch 049/50 | loss=0.758772 | train_acc=0.6942 | test_acc=0.6928 | test_bAcc=0.6951
# Q5 | Epoch 050/50 | loss=0.759708 | train_acc=0.6945 | test_acc=0.6949 | test_bAcc=0.6982
#
# Mejor test balanced accuracy:
# 0.7025404975315238
# Checkpoint guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Resultado final Q 5
# TRAIN: {'threshold': 0.5, 'accuracy': 0.6968414779499404, 'balanced_accuracy': 0.6998192666744392, 'f1': 0.6445391656767522, 'confusion_matrix': [[7081, 1153], [3934, 4612]], 'split': 'train', 'n_samples': 16780}
# TEST : {'threshold': 0.5, 'accuracy': 0.6994756911344138, 'balanced_accuracy': 0.7025404975315238, 'f1': 0.6456869907277325, 'confusion_matrix': [[1786, 273], [988, 1149]], 'split': 'test', 'n_samples': 4196}

# %% [markdown]
# ## 9.2 — Unir historiales de entrenamiento

# %%
history_all_df = pd.concat([df.assign(n_qubits=n_qubits)for n_qubits, df in training_histories.items()], ignore_index=True)
HISTORY_PATH = os.path.join(RESULTS_DIR, "training_history_q1_to_q5.csv")
history_all_df.to_csv(HISTORY_PATH, index=False)

print("\nHistorial completo guardado en:")
print(HISTORY_PATH)
# Out:
# Historial completo guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\training_history_q1_to_q5.csv

# %% [markdown]
# ## 9.3 — Tabla final de métricas

# %%
metrics_summary_df = pd.DataFrame(list(final_metrics_rows.values()))
metrics_summary_df = metrics_summary_df.sort_values("n_qubits").reset_index(drop=True)
metrics_summary_df.to_csv(METRICS_PATH, index=False)

print("\nResumen final de métricas:")
display(metrics_summary_df)

print("\nMétricas guardadas en:")
print(METRICS_PATH)
# Out:
# Resumen final de métricas:
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         1        0.674613                 0.678641  0.591195       0.678980
# 1         2        0.688498                 0.692265  0.615577       0.689943
# 2         3        0.694577                 0.697696  0.638652       0.695424
# 3         4        0.694100                 0.697629  0.628394       0.698046
# 4         5        0.696841                 0.699819  0.644539       0.699476
#
#    test_balanced_accuracy   test_f1  \
# 0                0.683128  0.593420
# 1                0.693722  0.617015
# 2                0.698678  0.636519
# 3                0.701660  0.631150
# 4                0.702540  0.645687
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# Métricas guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\metrics_summary.csv

# %% [markdown]
# ## 9.4 — Guardar predicciones/scores por split y número de qubits

# %%
prediction_rows = []

for n_qubits in QUBITS_LIST:
    train_scores = final_scores[n_qubits]["train_scores"]
    test_scores = final_scores[n_qubits]["test_scores"]

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_train_idx_qml, y_train_qml, train_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "train",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

    for idx_local, (idx_original, y_true, score) in enumerate(zip(original_test_idx_qml, y_test_qml, test_scores)):
        prediction_rows.append(
            {
                "n_qubits": int(n_qubits),
                "split": "test",
                "local_idx": int(idx_local),
                "original_idx": int(idx_original),
                "y_true": int(y_true),
                "score_class1": float(score),
                "y_pred_05": int(score >= 0.5),
            }
        )

predictions_df = pd.DataFrame(prediction_rows)
predictions_df.to_csv(PREDICTIONS_PATH, index=False)

print("\nPredicciones guardadas en:")
print(PREDICTIONS_PATH)
# Out:
# Predicciones guardadas en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\predictions.csv

# %% [markdown]
# ## 9.5 — Guardar resumen final JSON

# %%
FINAL_SUMMARY_PATH = os.path.join(RESULTS_DIR, "final_summary.json")

final_summary = {
    "experiment_name": EXPERIMENT_NAME,
    "method": METHOD,
    "fold": int(FOLD),
    "k": int(K),
    "q_list": [
        int(q)
        for q in QUBITS_LIST
    ],
    "data_path": DATA_PATH,
    "results_dir": RESULTS_DIR,
    "history_path": HISTORY_PATH,
    "metrics_path": METRICS_PATH,
    "predictions_path": PREDICTIONS_PATH,
    "checkpoints": {
        str(k): v
        for k, v in CHECKPOINT_PATHS.items()
    },
    "metrics_summary": metrics_summary_df.to_dict(orient="records"),
    "created_at": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
}

with open(FINAL_SUMMARY_PATH, "w", encoding="utf-8") as f:
    json.dump(final_summary, f, indent=4, ensure_ascii=False)

print("\nResumen final guardado en:")
print(FINAL_SUMMARY_PATH)
# Out:
# Resumen final guardado en:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\final_summary.json

# %% [markdown]
# ## 9.6 — Seleccionar mejor modelo por test balanced accuracy

# %%
best_row = metrics_summary_df.loc[
    metrics_summary_df[
        "test_balanced_accuracy"
    ].idxmax()
]

BEST_N_QUBITS = int(
    best_row["n_qubits"]
)

BEST_CHECKPOINT_PATH = CHECKPOINT_PATHS[
    BEST_N_QUBITS
]

print("\nMejor modelo:")
print("Qubits:", BEST_N_QUBITS)
print("Test bAcc:", best_row["test_balanced_accuracy"])
print("Checkpoint:", BEST_CHECKPOINT_PATH)

print("\nSección 9 lista.")
print("Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.")
# Out:
# Mejor modelo:
# Qubits: 5
# Test bAcc: 0.7025404975315238
# Checkpoint: C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Sección 9 lista.
# Entrenamiento progresivo Q1 → Q5 terminado y resultados guardados.

# %% [markdown]
# # **10**

# %% [markdown]
# ## 10.1 — Imports para visualización

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    ConfusionMatrixDisplay,
    confusion_matrix
)

# %% [markdown]
# ## 10.2 — Cargar historial completo

# %%
history_df = pd.read_csv(HISTORY_PATH)

print("Historial cargado:")
print(history_df.shape)

display(history_df.head())
# Out:
# Historial cargado:
# (260, 9)
#    n_qubits  epoch      loss  train_accuracy  train_balanced_accuracy  \
# 0         1      1  0.902415        0.661263                 0.664108
# 1         1      2  0.860172        0.657032                 0.657932
# 2         1      3  0.858568        0.655542                 0.659431
# 3         1      4  0.855380        0.665793                 0.668368
# 4         1      5  0.854329        0.632300                 0.630890
#
#    train_f1  test_accuracy  test_balanced_accuracy   test_f1
# 0  0.605825       0.647521                0.650409  0.588595
# 1  0.644160       0.637512                0.638455  0.622861
# 2  0.571089       0.651335                0.655163  0.567544
# 3  0.617567       0.655386                0.657988  0.604918
# 4  0.661918       0.628217                0.626724  0.659537

# %% [markdown]
# ## 10.3 — Curvas de Loss

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["loss"], label=f"Q{q}" )

plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.4 — Curvas de Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]

    plt.plot(subset["epoch"], subset["test_accuracy"], label=f"Q{q}")

plt.title("Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.5 — Curvas de Balanced Accuracy

# %%
plt.figure(figsize=(8, 5))

for q in sorted(
    history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_balanced_accuracy"], label=f"Q{q}")

plt.title("Test Balanced Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Balanced Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.6 — Curvas de F1

# %%
plt.figure(figsize=(8, 5))

for q in sorted(history_df["n_qubits"].unique()):
    subset = history_df[history_df["n_qubits"] == q]
    plt.plot(subset["epoch"], subset["test_f1"], label=f"Q{q}")

plt.title("Test F1")
plt.xlabel("Epoch")
plt.ylabel("F1")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.7 — Ranking final

# %%
metrics_summary_df = pd.read_csv(METRICS_PATH)

ranking_df = metrics_summary_df.sort_values(
    "test_balanced_accuracy",
    ascending=False
).reset_index(
    drop=True
)

print("\nRanking final")

display(ranking_df)
# Out:
# Ranking final
#    n_qubits  train_accuracy  train_balanced_accuracy  train_f1  test_accuracy  \
# 0         5        0.696841                 0.699819  0.644539       0.699476
# 1         4        0.694100                 0.697629  0.628394       0.698046
# 2         3        0.694577                 0.697696  0.638652       0.695424
# 3         2        0.688498                 0.692265  0.615577       0.689943
# 4         1        0.674613                 0.678641  0.591195       0.678980
#
#    test_balanced_accuracy   test_f1  \
# 0                0.702540  0.645687
# 1                0.701660  0.631150
# 2                0.698678  0.636519
# 3                0.693722  0.617015
# 4                0.683128  0.593420
#
#                                      checkpoint_path
# 0  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 1  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 2  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 3  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...
# 4  C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN...

# %% [markdown]
# ## 10.8 — Comparación visual Q1–Q5

# %%
plt.figure(figsize=(10, 5))
x = np.arange(len(ranking_df))
width = 0.25
plt.bar(x - width, ranking_df["test_accuracy"], width=width, label="Accuracy")
plt.bar(x, ranking_df["test_balanced_accuracy"], width=width, label="Balanced Accuracy")
plt.bar(x + width, ranking_df["test_f1"], width=width, label="F1")
plt.xticks(x, [f"Q{q}" for q in ranking_df["n_qubits"]])
plt.ylabel("Score")
plt.title("Comparación Final Q1–Q5")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 10.9 — Matriz de confusión del mejor modelo

# %%
best_q = int(ranking_df.iloc[0]["n_qubits"])
print("\nMejor modelo: Q", best_q)
best_predictions = predictions_df[(predictions_df["n_qubits"] == best_q) & (predictions_df["split"] == "test")]

cm = confusion_matrix(best_predictions["y_true"], best_predictions["y_pred_05"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title(f"Confusion Matrix - Q{best_q}")
plt.show()
# Out:
# Mejor modelo: Q 5

# %% [markdown]
# ## 10.10 — Resumen final

# %%
best_row = ranking_df.iloc[0]
print("\n" + "=" * 80)
print("MEJOR MODELO")
print("=" * 80)
print("Qubits:", int(best_row["n_qubits"]))
print("Test Accuracy:",  round(best_row["test_accuracy"], 6))
print("Test Balanced Accuracy:", round(best_row["test_balanced_accuracy"], 6))
print("Test F1:", round(best_row["test_f1"], 6))
print("\nCheckpoint:")
print(CHECKPOINT_PATHS[int(best_row["n_qubits"])])
print("\nNotebook finalizado.")
# Out:
# ================================================================================
# MEJOR MODELO
# ================================================================================
# Qubits: 5
# Test Accuracy: 0.699476
# Test Balanced Accuracy: 0.70254
# Test F1: 0.645687
#
# Checkpoint:
# C:\Users\lapic\QML5\BCAM_B_QML5\Results\DR_QNN_z64_reductions_batched\DR_QNN_BATCHED_ICA_z3_fold0\best_dr_qnn_5q.pt
#
# Notebook finalizado.
